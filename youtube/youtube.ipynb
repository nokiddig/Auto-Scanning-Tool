# %% [markdown]
# ### Get link

# %% [markdown]
# Doc: https://developers.google.com/youtube/v3/docs/search/list?hl=vi

# %%
import certifi
certifi.where()
cert_path = certifi.where()

# %% [markdown]
# ### Logger

# %%
with open('../common/logger.py') as f:
    exec(f.read())

logger = get_logger(name='youtube')
logger.info('Start crawl youtube')

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import os
import sys
import importlib

# %%
def get_module(module_name, file_name):
    name = file_name.split('.')[0]

    module_path = os.path.join(os.getcwd(), '..', module_name, file_name)
    spec = importlib.util.spec_from_file_location(name, module_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
variable_module = get_module('internal', 'variable.py')
API_KEY = variable_module.API_KEY
CHROMEDRIVER_PATH = variable_module.CHROMEDRIVER_PATH

# %%
driver_module = get_module('common', 'web_driver.py')
get_driver = driver_module.get_driver

# %%
driver = get_driver()

# %%
# limit time query
from datetime import datetime
from dateutil.relativedelta import relativedelta

def get_previous_date(month, day):
    today = datetime.now()

    # Lấy ngày của tháng trước
    previous_month_date = today - relativedelta(months=month, days=day)

    # Chuyển đổi sang định dạng yêu cầu "YYYY-MM-DDTHH:MM:SSZ"
    formatted_date = previous_month_date.strftime("%Y-%m-%dT%H:%M:%SZ")

    return formatted_date

# %%
import urllib.parse
import json
from time import sleep


# URL của API YouTube
API_URL = 'https://www.googleapis.com/youtube/v3/search'

def search_youtube(query, before, after):
    headers = {
        'Content-Type': 'application/json',
        'accept': 'application/json',
    }
    params = {
        'q': query,
        'part': 'snippet',
        'type': 'video',
        'order': 'date',
        'publishedBefore': before,
        'publishedAfter': after,
        'maxResults': 50,
        'key': API_KEY
    }
    
    # response = requests.get(API_URL, params=params, headers=headers, verify=False)
    # response.raise_for_status()  # Raise an exception for HTTP errors
    # items = response.json()['items']

    param_string = urllib.parse.urlencode(params)
    driver.get(f"{API_URL}?{param_string}")
    sleep(2)
    
    json_res = driver.find_element(By.TAG_NAME, 'pre').text
    response = json.loads(json_res)  # Convert the JSON string to a Python dictionary
    items = response['items']
    return items

# %%
query = "samsung+kg+mdm+unlock"
before_date = get_previous_date(month=0, day=0) # end
after_date = get_previous_date(month=1, day=0) # start

search_result = search_youtube(query= query, before=before_date, after=after_date)

# %%
search_result
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'PshRcuS7df3SUs5H64SE0yOThXs',
#   'id': {'kind': 'youtube#video', 'videoId': 'cMH6BLFjo80'},
#   'snippet': {'publishedAt': '2024-10-02T16:56:30Z',
#    'channelId': 'UCgHWgA5JfUA1sGnbZHrxdDg',
#    'title': 'MDM fix tool Samsung A33 5G Android 14 KG Remove✅ All CPU support ✅ QC MTK Exynos Spd 2024',
#    'description': 'MDM fix tool Samsung A33 5G Android 14 KG Remove✓ All CPU support ✓ QC MTK Exynos Spd ✓Join my group team ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cMH6BLFjo80/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/cMH6BLFjo80/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/cMH6BLFjo80/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Kg Unlock King 24k views . 2 hours ago',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-10-02T16:56:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'd8XAfxKgLgprE1tMISjHQvhoOlw',
#   'id': {'kind': 'youtube#video', 'videoId': 'wAb_ZqDnDLE'},
#   'snippet': {'publishedAt': '2024-10-02T12:54:17Z',
#    'channelId': 'UCLdGDcby8qwMN05_M1psGPQ',
#    'title': 'Samsung a035f kg lock | #shorts #shortvideo #samsung #realmefrpunlocknewtrick2022 #factoryresetphone',
#    'description': 'Samsung kg lock | all Samsung Android 14 kg unlock | Samsung a23 5g kg unlock | Samsung a236e u7 kg #samsung #frplock ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wAb_ZqDnDLE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wAb_ZqDnDLE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wAb_ZqDnDLE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ajay technical',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-10-02T12:54:17Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'cZnoMq1H9ugE253cmUbdDpOaRmg',
#   'id': {'kind': 'youtube#video', 'videoId': '3LDBz6G86eI'},
#   'snippet': {'publishedAt': '2024-10-02T07:59:59Z',
#    'channelId': 'UCLdGDcby8qwMN05_M1psGPQ',
#    'title': 'Samsung kg lock | all Samsung Android 14 kg unlock | Samsung a23 5g kg unlock | Samsung a236e u7 kg',
#    'description': 'Samsung kg lock | all Samsung Android 14 kg unlock | Samsung a23 5g kg unlock | Samsung a236e u7 kg #samsung #frplock ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3LDBz6G86eI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3LDBz6G86eI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3LDBz6G86eI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ajay technical',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-10-02T07:59:59Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'QSvCVKhpEnbqBykQ7mAsAXPcuaA',
#   'id': {'kind': 'youtube#video', 'videoId': 'q_aQ5HFurr0'},
#   'snippet': {'publishedAt': '2024-10-01T16:47:40Z',
#    'channelId': 'UCLdGDcby8qwMN05_M1psGPQ',
#    'title': 'Samsung kg unlock 2024 | all Samsung Android 14 kg unlock |  unlock new method | Samsung kg solution',
#    'description': 'Samsung kg unlock 2024 | all Samsung Android 14 kg unlock | unlock new method | Samsung kg solution join my group ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q_aQ5HFurr0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/q_aQ5HFurr0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/q_aQ5HFurr0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ajay technical',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-10-01T16:47:40Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-h309lg-LNZlEh8lkXNlGTUJaAQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'sN4PuQa3Clk'},
#   'snippet': {'publishedAt': '2024-10-01T12:07:12Z',
#    'channelId': 'UCgHWgA5JfUA1sGnbZHrxdDg',
#    'title': 'Samsung A04s💥 Free KG remove parmanent ✅ Samsung Android 13 MDM lock free remove finance lock',
#    'description': 'Join my group team ✨ ✓whatsapp group link https://chat.whatsapp.com/C83MY1ocDNCE33n81V61O7 ✓whatsapp channel ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sN4PuQa3Clk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/sN4PuQa3Clk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/sN4PuQa3Clk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Kg Unlock King 24k views . 2 hours ago',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-10-01T12:07:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'UBvqKfYkP4EEgbylDj2OXahARwc',
#   'id': {'kind': 'youtube#video', 'videoId': 'kc3zE0t_H1c'},
#   'snippet': {'publishedAt': '2024-09-29T03:57:32Z',
#    'channelId': 'UCKSUvMaM35qtOuuw3XRj9Og',
#    'title': 'MDM fix tool Samsung Android 14 KGG Remove✅ All CPU support ✅ QC MTK Exynos Spd Mdm fix tool 2024 kg',
#    'description': 'MDM fix tool Samsung Android 14 KGG Remove✓ All CPU support ✓ QC MTK Exynos Spd Mdm fix tool 2024 kg #samsung ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kc3zE0t_H1c/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/kc3zE0t_H1c/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/kc3zE0t_H1c/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'AsikMobile',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-29T03:57:32Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '8Hm3tUUpEhdT3kWXd0ZAECEbIag',
#   'id': {'kind': 'youtube#video', 'videoId': 'eD3emCE3Z3Y'},
#   'snippet': {'publishedAt': '2024-09-27T11:37:43Z',
#    'channelId': 'UCaSCq-kz37DoIxQorMVK5bg',
#    'title': 'PL Tool V1.0  Qualcomm Samsung Unlock Tool  FRP, MDM, KG, Screenlock  Remove',
#    'description': 'mobilesoftwareSolution PL Tool V1.0 Qualcomm Samsung Unlock Tool FRPMDMKG, Screenlock Remove unlock tool crack ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eD3emCE3Z3Y/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eD3emCE3Z3Y/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eD3emCE3Z3Y/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'mobile software Solution',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-27T11:37:43Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'AueiUSGvbpi6B3PQ_0Mh-mJ52Xo',
#   'id': {'kind': 'youtube#video', 'videoId': 'pzPQ5H9YMWQ'},
#   'snippet': {'publishedAt': '2024-09-26T19:22:18Z',
#    'channelId': 'UCpa-xJidirHA5Tr5z8cyXpQ',
#    'title': 'COMO CONFIGURAR NETPATCH PARA KG O MDM SAMSUNG - PASO A PASO 2024',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pzPQ5H9YMWQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pzPQ5H9YMWQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pzPQ5H9YMWQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Unlock MX',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-26T19:22:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'mQpzeNpSl8VBQ5yew51le0Eg_0A',
#   'id': {'kind': 'youtube#video', 'videoId': 'dNZ_bwqEf-A'},
#   'snippet': {'publishedAt': '2024-09-26T11:13:30Z',
#    'channelId': 'UCm6SfWCmPz4IwIR1aTuaMxw',
#    'title': 'SAMSUNG A14 5G KG BYPASS ANDROID 14 MDM FIXD TOOL 2024',
#    'description': 'teligram group https://t.me/+O6xAwO_QAZE5NWVl WhatsApp group https://chat.whatsapp.com/IofusW8fngcAHMbJUEiCpl ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dNZ_bwqEf-A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/dNZ_bwqEf-A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/dNZ_bwqEf-A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'ASSOFTWERE78',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-26T11:13:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'b6qr_QJ1D3ShICeOTqED2ECDOHo',
#   'id': {'kind': 'youtube#video', 'videoId': '5TcTwXvfZBo'},
#   'snippet': {'publishedAt': '2024-09-26T07:32:55Z',
#    'channelId': 'UCKSUvMaM35qtOuuw3XRj9Og',
#    'title': 'Samsung Octoplus tool Big Update 🔥 Released Android 14 KGG permanent Big Update 🔥KGG mdm lock 2024 ✅',
#    'description': 'Samsung Octoplus tool Big Update Released Android 14 KGG permanent Big Update KGG mdm lock 2024 ✓ #samsung ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5TcTwXvfZBo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5TcTwXvfZBo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5TcTwXvfZBo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'AsikMobile',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-26T07:32:55Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Y3yt-1VgTUbmHIPiqKGcxtDn9CM',
#   'id': {'kind': 'youtube#video', 'videoId': 'yaJIBYh22lg'},
#   'snippet': {'publishedAt': '2024-09-25T19:24:42Z',
#    'channelId': 'UCdxV5jSqpFLiehLhUdT5rnA',
#    'title': 'World First Free Samsung Android 14 KG MDM Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD',
#    'description': 'World First Free Samsung Android 14 KG MDM Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD World- First ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yaJIBYh22lg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yaJIBYh22lg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yaJIBYh22lg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Google Chacha G',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-25T19:24:42Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '4NGlVC7FPApclD6Jjkw8ieFK1ys',
#   'id': {'kind': 'youtube#video', 'videoId': 'gVV2D-Wd0SI'},
#   'snippet': {'publishedAt': '2024-09-25T16:11:52Z',
#    'channelId': 'UCLdGDcby8qwMN05_M1psGPQ',
#    'title': 'Samsung a15 5g kg unlock | A15 5g Android 14 kg unlock | Samsung a15 5g MDM unlock | @UFixer',
#    'description': 'Samsung a15 5g kg unlock | A15 5g Android 14 kg unlock | Samsung a15 5g MDM unlock | kg bypass new Join my group friends ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gVV2D-Wd0SI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/gVV2D-Wd0SI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/gVV2D-Wd0SI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ajay technical',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-25T16:11:52Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'UXe0zhSKle2p3jT4ttVMWEmdcAs',
#   'id': {'kind': 'youtube#video', 'videoId': 'rSaSOds7AKA'},
#   'snippet': {'publishedAt': '2024-09-24T22:00:04Z',
#    'channelId': 'UC9LHQpEEeBnWx6Z2g7xcajw',
#    'title': 'SAMSUNG SM-A055F REMOVE KG-LOCKED ALL BINARY 2024 UPDATE || ALL ANDROID 14 REMOVED KG LOCKED',
#    'description': 'In this video, I will show you how to remove Kg locked mkofa from Samsung Galaxy A05 SM-A055F for all binary with usb cable, ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rSaSOds7AKA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/rSaSOds7AKA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/rSaSOds7AKA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'MH Gsm Clinic',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-24T22:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ki28puksri9TwjZxl5f2941Et_E',
#   'id': {'kind': 'youtube#video', 'videoId': 'eNVdCElQChY'},
#   'snippet': {'publishedAt': '2024-09-24T11:33:36Z',
#    'channelId': 'UCS18bsaTzqPDs1gp-vP-O8g',
#    'title': 'Samsung Galaxy A23 SM-A235F KG / Finance Parmanent Unlock With MDM Fix Tool Done By BJ Software Sol',
#    'description': 'My WhatsApp Number⋆⋆⋆ +917385905229 ▭▭▭▭▭▭▭▭▭▭▭▭▭▭▭▭▭▭▭ #SamsungGalaxyA23 #GalaxyA23 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eNVdCElQChY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eNVdCElQChY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eNVdCElQChY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'BJ Software Solution ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-24T11:33:36Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'gKGEMyxKV-UcoaEqRg6eYY8AHH0',
#   'id': {'kind': 'youtube#video', 'videoId': 'MkOdQwb9VxY'},
#   'snippet': {'publishedAt': '2024-09-24T07:32:23Z',
#    'channelId': 'UCbyTHHeyX86ajSAodackE2A',
#    'title': 'Samsung a14 A145f u7 os14 Device Control Done 2024\\2025',
#    'description': 'Samsung a14 A145f u7 Device Control Done 2024\\2025 Thanks alot for watching do subscribe Queries +27745326217 samsung ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MkOdQwb9VxY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/MkOdQwb9VxY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/MkOdQwb9VxY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'gsm wolf ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-24T07:32:23Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'GodaU8mHPNTnF69dLqkeViZl7zY',
#   'id': {'kind': 'youtube#video', 'videoId': '-XMhUzes_wA'},
#   'snippet': {'publishedAt': '2024-09-23T21:00:16Z',
#    'channelId': 'UCKGE7uGAqkDBZS6dUyhSEJg',
#    'title': 'Como quitar bloqueo por falta de pago en samsung',
#    'description': 'quitar mdm samsung a42 5g, Como quitar bloqueo por falta de pago samsung, quitar mdm samsung a24, guitar mdm samsung ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-XMhUzes_wA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-XMhUzes_wA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-XMhUzes_wA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'ANDROIDETV',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-23T21:00:16Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'atUJ5h_OdlFWNxgdvLKFZE7pN9w',
#   'id': {'kind': 'youtube#video', 'videoId': 'ROzQG1we7Bs'},
#   'snippet': {'publishedAt': '2024-09-22T18:53:28Z',
#    'channelId': 'UCKSUvMaM35qtOuuw3XRj9Og',
#    'title': 'Samsung Android 14 KGG Factory reset problem❌ Samsung Android 14 Wap data factory reset option hide',
#    'description': 'Samsung Android 14 KGG Factory reset problem❌ Samsung Android 14 Wap data factory reset option hide Follow the ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ROzQG1we7Bs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ROzQG1we7Bs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ROzQG1we7Bs/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'AsikMobile',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-22T18:53:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'bvrbcLrPEZfcA1qDUCyA2raRB9E',
#   'id': {'kind': 'youtube#video', 'videoId': '0QpvYsi_k6A'},
#   'snippet': {'publishedAt': '2024-09-22T16:02:41Z',
#    'channelId': 'UCVhWMxoNuPcOsndhnKoLg8Q',
#    'title': 'Samsung A22 (A225f) kg lock Mdm permanent unlock||MDM can&#39;t error download Error fix ||',
#    'description': "Samsung A22 (A225f) kg lock Mdm permanent unlock||MDM can't error download Error fix || #samsung_a22_kg_lock ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0QpvYsi_k6A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0QpvYsi_k6A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0QpvYsi_k6A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Gsm Line king',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-22T16:02:41Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '6SLfUDrVKMKFD68jmaolw36ay7U',
#   'id': {'kind': 'youtube#video', 'videoId': 'vC-r9YwbOVc'},
#   'snippet': {'publishedAt': '2024-09-22T14:30:17Z',
#    'channelId': 'UC5bVlUsO3cr2b09tZZkY7Ow',
#    'title': 'KG Unlock | Mdm Unlock | All Samsung Galaxy | Samsung A34, A15, A33, A22, A54, A03, S24 Ultra, OS 14',
#    'description': 'KG Unlock | Mdm Unlock | All Samsung Galaxy | Samsung A34, A33, A22, A54, A03, S24 Ultra, OS 14 KG Unlock | Mdm Unlock ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vC-r9YwbOVc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vC-r9YwbOVc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vC-r9YwbOVc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Google Chacha',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-22T14:30:17Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '05NOqbiPAOCOKdWUraxMPObfiKg',
#   'id': {'kind': 'youtube#video', 'videoId': 'vl6fVCET49o'},
#   'snippet': {'publishedAt': '2024-09-21T12:00:16Z',
#    'channelId': 'UChtvSDEXR3KMUZISRK4YRhg',
#    'title': 'S21 FE 5G Finance Plus 2024/Samsung Frp Bypass/New Security ADB Enable 2024_Samsung Finance Unlock',
#    'description': 'Samsung Finance Plus 2023/Samsung Frp Bypass/New Security ADB Enable 2023_Samsung Finance Unlock Samsung A05s Kg ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vl6fVCET49o/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vl6fVCET49o/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vl6fVCET49o/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'GSM King',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-21T12:00:16Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'SDDJcJ6ECmsonUYMtQGkATgMHZo',
#   'id': {'kind': 'youtube#video', 'videoId': 'cPIsUb7rl9w'},
#   'snippet': {'publishedAt': '2024-09-20T14:56:23Z',
#    'channelId': 'UCOh5Zxh6ZunsSwOFfG3zKnQ',
#    'title': 'Samsung A032f  A03 Core A035f U1 U7 MTN  South Africa Lock Free Kg Mdm Unlock  Method With File',
#    'description': 'work and money trabalho e pago para desbloquear a rede de seu celular smartphone entre em contato conosco aqui liga meu ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cPIsUb7rl9w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/cPIsUb7rl9w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/cPIsUb7rl9w/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'VilazaTutoriais Moz',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-20T14:56:23Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'svO9ZdSFUFL4LdNQkUPvbYlsmm4',
#   'id': {'kind': 'youtube#video', 'videoId': 'EmXYfgfX35E'},
#   'snippet': {'publishedAt': '2024-09-20T09:05:26Z',
#    'channelId': 'UCjWGHrT9ul9XjIDUAyoyT7w',
#    'title': 'SAMSUNG A54 5G [A546E] 2024 FINANCE MDM KG KNOX OFF REMOVE PERMANENTLY BY CHIMERA TOOL',
#    'description': 'SAMSUNG A54 5G [A546E] 2024 FINANCE MDM KG KNOX OFF REMOVE PERMANENTLY BY CHIMERA TOOL samsung a54 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EmXYfgfX35E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EmXYfgfX35E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EmXYfgfX35E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SNZONE UNLOCKER ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-20T09:05:26Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ecouOLXzJ1yjLbM7bK0a4ajeDFE',
#   'id': {'kind': 'youtube#video', 'videoId': 'pzexSG2uSLM'},
#   'snippet': {'publishedAt': '2024-09-20T06:03:44Z',
#    'channelId': 'UCylR2CFWJC_9ub5YG36wDJg',
#    'title': 'Samsung Galaxy s24 Ultra kg lock bypass permanent / Samsung s24 finance lock bypass permanent #new 😱',
#    'description': 'Samsung Galaxy s24 Ultra kg lock bypass permanent / Samsung s24 finance lock bypass permanent #new ❣️❣️❣️ thank ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pzexSG2uSLM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pzexSG2uSLM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pzexSG2uSLM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Technicalsolutiona2z',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-20T06:03:44Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'PheGykGuTo0p6LyW1vChka6X_P4',
#   'id': {'kind': 'youtube#video', 'videoId': 'j83EaO9YX4E'},
#   'snippet': {'publishedAt': '2024-09-19T06:27:09Z',
#    'channelId': 'UCjWGHrT9ul9XjIDUAyoyT7w',
#    'title': 'FREE SAMSUNG S20 FE [G781B] U10 FINANCE KG UNLOCK 2024 | ANDROID 14 | BY MDMFIX TOOL 🔧',
#    'description': 'FREE SAMSUNG S20 FE [G781B] U10 FINANCE KG UNLOCK 2024 | ANDROID 14 | BY MDMFIX TOOL Supported Model List ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j83EaO9YX4E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/j83EaO9YX4E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/j83EaO9YX4E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SNZONE UNLOCKER ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-19T06:27:09Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'WZjXZq6fEVUu1F0_ZOkyg-fpHB4',
#   'id': {'kind': 'youtube#video', 'videoId': 'CSPtp0KuDQ4'},
#   'snippet': {'publishedAt': '2024-09-18T17:59:28Z',
#    'channelId': 'UCFdqKBsqP5luRNALxF3Fggw',
#    'title': 'iPhone iCloud, Erase Frp,Factory Reset, Bootloader, kg,MDM, imei Repair With Griffin Unlocker',
#    'description': 'iPhone iCloud, Erase Frp,Factory Reset, Bootloader Unlock, kg unlock,mdm unlock,imei Repair With Griffin Unlocker Preload Auth ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CSPtp0KuDQ4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/CSPtp0KuDQ4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/CSPtp0KuDQ4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Buner Tech',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-18T17:59:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'EadvVzpQYmjkyNa7XoHYVFl6V5I',
#   'id': {'kind': 'youtube#video', 'videoId': 'yrY0kchm4uk'},
#   'snippet': {'publishedAt': '2024-09-18T13:00:52Z',
#    'channelId': 'UCwsjZljt7j5qsNOf0huooEA',
#    'title': 'how to Samsung S21 FE Unlock Android 14 u7 u8 /Mdm Fix Tool 2024 (G990b2) MDM Lock Removal',
#    'description': 'GSM GULFAM how to Samsung S21 FE Unlock Android 14 u7 u8 /Mdm Fix Tool 2024 (G990b2) MDM Lock Removal ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yrY0kchm4uk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yrY0kchm4uk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yrY0kchm4uk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'GSM Gulfam',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-18T13:00:52Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'tXyEiEd5AwGxSeM9CCUfsyQXVWo',
#   'id': {'kind': 'youtube#video', 'videoId': 'vv5UGgcTqm8'},
#   'snippet': {'publishedAt': '2024-09-18T06:30:53Z',
#    'channelId': 'UCjWGHrT9ul9XjIDUAyoyT7w',
#    'title': 'ALL SAMSUNG FINANCE MDM LOCK PERMANENTLY REMOVE 2024 | ANDROID 14 | SAMSUNG A23 5G KG LOCK BY MDMFIX',
#    'description': 'ALL SAMSUNG FINANCE MDM LOCK PERMANENTLY REMOVE 2024 | ANDROID 14 | SAMSUNG A23 5G KG LOCK BY ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vv5UGgcTqm8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vv5UGgcTqm8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vv5UGgcTqm8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SNZONE UNLOCKER ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-18T06:30:53Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'qLxDoGPX2wVnhlnOhYfRKBc5CMQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'uEQhcRMgRvM'},
#   'snippet': {'publishedAt': '2024-09-17T19:26:41Z',
#    'channelId': 'UCmI7d8k_GGgbYePLmMv6xZQ',
#    'title': 'Samsung galaxy A05S U3 BIT kg/MDM LOCK DEVICE CONTROL LOCK BYPASS MDMFIX TOOl💪',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uEQhcRMgRvM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/uEQhcRMgRvM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/uEQhcRMgRvM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Abbas Gsm Work',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T19:26:41Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'W9iBC61IfbVEuoEhIss4og5yFEo',
#   'id': {'kind': 'youtube#video', 'videoId': 'UsfEfvLv42I'},
#   'snippet': {'publishedAt': '2024-09-17T17:42:19Z',
#    'channelId': 'UCKSUvMaM35qtOuuw3XRj9Og',
#    'title': 'MdmfixTool, Big Update🔥 Released🔥🚀  MdmfixTool World-First Innovation World- First Android-14 KG MDM',
#    'description': 'MdmfixTool, Big Update   Released     MdmfixTool World-First Innovation World- First Android-14 KG MDM Follow the ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UsfEfvLv42I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/UsfEfvLv42I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/UsfEfvLv42I/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'AsikMobile',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T17:42:19Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Zl9KOHH837jMDsxbtnQJ-xqOWjs',
#   'id': {'kind': 'youtube#video', 'videoId': 'VHDpBnc5zjE'},
#   'snippet': {'publishedAt': '2024-09-17T17:38:35Z',
#    'channelId': 'UCmI7d8k_GGgbYePLmMv6xZQ',
#    'title': 'Samsung galaxy A05 U3 kg / MDM lock and Device control lock bypass MDMFIX TOOL',
#    'description': 'Samsung galaxy A05 KG UNLOCK mdmfix tool https://youtu.be/mQDzcsZmDgM?si=eCWgrt5hOSVZPjbW ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VHDpBnc5zjE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VHDpBnc5zjE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VHDpBnc5zjE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Abbas Gsm Work',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T17:38:35Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'iJ094My03bKgVlh-tCBkgHU4y6g',
#   'id': {'kind': 'youtube#video', 'videoId': 'seq09jc98k8'},
#   'snippet': {'publishedAt': '2024-09-17T17:35:32Z',
#    'channelId': 'UCoaxBzBUU8QiUnJs4Q6dxCg',
#    'title': 'TSM Pro Tool Activation - Samsung KG lock MDM FRP Remove Xiaomi LG Huawei more',
#    'description': 'https://www.asunlocker.com WhatsApp: +8801721672766 https://t.me/asunlocker https://fb.com/groups/asunlocker Free Firmware ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/seq09jc98k8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/seq09jc98k8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/seq09jc98k8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Asunlocker Solution',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T17:35:32Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ZEBtI1SBadt0-uGY1kBAHBfQ828',
#   'id': {'kind': 'youtube#video', 'videoId': 'EaEr_-MwwW0'},
#   'snippet': {'publishedAt': '2024-09-17T13:04:25Z',
#    'channelId': 'UCkjZB7uZX2rLorM2I7DmCYA',
#    'title': 'SAMSUNG A15  KG LOCKED FRP ON MDM KG BYPASS ALL BINARY',
#    'description': 'EPATELETECH is exerting visit to view and learn knowledge Download Tool here ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EaEr_-MwwW0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EaEr_-MwwW0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EaEr_-MwwW0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Epateletech',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T13:04:25Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'u9uQxqw-HJF1DOZ5sv0bbGgYMu8',
#   'id': {'kind': 'youtube#video', 'videoId': 'HaVkO8hvCcI'},
#   'snippet': {'publishedAt': '2024-09-17T04:45:35Z',
#    'channelId': 'UCwsjZljt7j5qsNOf0huooEA',
#    'title': 'ALL SAMSUNG A35 LOCK REMOVE FULL PROCESS ONE INFORMATION A14 5G ALL BIT Samsung Android 14',
#    'description': 'GSM GULFAM ALL SAMSUNG A35 LOCK REMOVE FULL PROCESS ONE INFORMATION A14 5G ALL BIT Samsung Android 14 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HaVkO8hvCcI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HaVkO8hvCcI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HaVkO8hvCcI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'GSM Gulfam',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-17T04:45:35Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '6S4EevDOlxQ0nj-j1CHEWUi26qA',
#   'id': {'kind': 'youtube#video', 'videoId': '7wwzW0Naiq8'},
#   'snippet': {'publishedAt': '2024-09-16T16:50:01Z',
#    'channelId': 'UCXc-MB1AYEUqysYbkKQxFZQ',
#    'title': 'New SAMSUNG KG Relock Fix Tool | All Models Supported | KG,MDM,Finance Lock Remove,Relock Fix 2024',
#    'description': 'Dear Technical Atif Bilal Subscribers .!! In this video New SAMSUNG KG Relock Fix Tool | All Models Supported | KG,MDM ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7wwzW0Naiq8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7wwzW0Naiq8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7wwzW0Naiq8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Technical Atif Bilal',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T16:50:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'iM6SCv5ep5RgVl5PQQJf917K_28',
#   'id': {'kind': 'youtube#video', 'videoId': 'OqIo2oRnSL0'},
#   'snippet': {'publishedAt': '2024-09-16T16:03:25Z',
#    'channelId': 'UCBMByWQqzyMSNGwNsTZztmg',
#    'title': 'Gsm Power tool / Samsung Frp Remove Tool Android Version 12/13/14',
#    'description': 'Gsm Power tool / Samsung Frp Remove Tool Android Version 12/13/14 tool https://shorturl.at/jx44b Unlock your Samsung device ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OqIo2oRnSL0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OqIo2oRnSL0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OqIo2oRnSL0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Gsm Team 360',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T16:03:25Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'mdSstWQsFKFktqU0v0OBbf-CGf8',
#   'id': {'kind': 'youtube#video', 'videoId': 'Cg9WSahD4B4'},
#   'snippet': {'publishedAt': '2024-09-16T15:59:53Z',
#    'channelId': 'UCFdqKBsqP5luRNALxF3Fggw',
#    'title': 'Samsung KG &amp; MDM Reset | Restore imei ,Erase FRP,Format Safe Bootloader Unlock TSM Tool One Click',
#    'description': 'Samsung KG & MDM Reset | Restore imei ,Erase FRP,Format Safe Bootloader Unlock TSM Tool One Click Without Box or Dongle ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Cg9WSahD4B4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Cg9WSahD4B4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Cg9WSahD4B4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Buner Tech',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T15:59:53Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'uc_018LRvHAldOtGFXeW_aIMOzw',
#   'id': {'kind': 'youtube#video', 'videoId': '5-g_vdWlK8M'},
#   'snippet': {'publishedAt': '2024-09-16T15:59:03Z',
#    'channelId': 'UC9FtoUVnDExEF4ToSKh2ARQ',
#    'title': 'Samsung A34 5g  Kg lock Remove  Parmanent ||100% work EASY STEP &amp; Online work #mdmfixtool',
#    'description': 'all tool rent low price watp cont +919024280280 Samsung A34 5g [ A346E ] Kg lock Remove Samsung A34 5g [ A346E ] Kg lock ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5-g_vdWlK8M/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5-g_vdWlK8M/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5-g_vdWlK8M/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Jaanam-Gsm',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T15:59:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '2-WPA6Q4WFFK1ijTIc9DowkOyN0',
#   'id': {'kind': 'youtube#video', 'videoId': 'wxvCv86Ivnk'},
#   'snippet': {'publishedAt': '2024-09-16T11:32:49Z',
#    'channelId': 'UCjWGHrT9ul9XjIDUAyoyT7w',
#    'title': 'WORLD 🌎 FIRST FREE SAMSUNG ANDROID 13,14 KG MDM UNLOCK 2024 ALL MODEL  MTK-EXYNOS- QUALCOMM-SPD',
#    'description': 'WORLD FIRST FREE SAMSUNG ANDROID 13,14 KG MDM UNLOCK 2024 ALL MODEL MTK-EXYNOS- QUALCOMM-SPD ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wxvCv86Ivnk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wxvCv86Ivnk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wxvCv86Ivnk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SNZONE UNLOCKER ',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T11:32:49Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'zUC0BoCqkNgF6m2aVhnfoGQa3YE',
#   'id': {'kind': 'youtube#video', 'videoId': '8BVEKskQAUA'},
#   'snippet': {'publishedAt': '2024-09-16T10:29:20Z',
#    'channelId': 'UC1ncxeqiMjTzYYBaSLg1kHA',
#    'title': 'Sansung A05 Android 14 Permanently Kg Unlock 2024#mdmfixtool #samsung #a05',
#    'description': 'Sansung A05 Android 14 Permanently Kg Unlock 2024 A05 kg unlock samsung A05 kg unlock mdm A05 kg unlock app A055F kg ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8BVEKskQAUA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8BVEKskQAUA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8BVEKskQAUA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Sk Mobile',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T10:29:20Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'GuLgRJRNlbKisIILhalZdZaDG-o',
#   'id': {'kind': 'youtube#video', 'videoId': 'OdjN5fhV5Zo'},
#   'snippet': {'publishedAt': '2024-09-16T10:15:07Z',
#    'channelId': 'UC0MDrA9gl2nQj2sjYOO2RRQ',
#    'title': 'MDM Tool Fix Solution Pour Bypass TECNO/INFINIX Bloquer Sur MDM/KG LOCK SAMSUNG',
#    'description': 'Je vous invite donc a regarder pour découvrir Mes Contact : WhatsApp: +243 840775102 www.unlock-app.shop AUTRES ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OdjN5fhV5Zo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OdjN5fhV5Zo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OdjN5fhV5Zo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'UNLOCK_APP',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T10:15:07Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '228mGzXYXwJVu_Jt4DQ6raBNZKY',
#   'id': {'kind': 'youtube#video', 'videoId': '93wazAhCRu0'},
#   'snippet': {'publishedAt': '2024-09-16T02:21:31Z',
#    'channelId': 'UCJEQV09Ue_4jZZ3zzblaj0w',
#    'title': 'SAMSUNG A05S A057F U4 MDM| MKOPA| WATU LOANS REMOVE SEMI-PERMANENT 2024| KG ERROR(00) BY UNLOCKTOOL',
#    'description': 'Disclaimer . THIS VIDEO IS STRICTLY FOR EDUCATIONAL PURPOSE . The author of the topic and the site is not responsible for ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/93wazAhCRu0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/93wazAhCRu0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/93wazAhCRu0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ramah Soft Solutions',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-16T02:21:31Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'XYFWO01PehIhbVRqAr7otYaPa-w',
#   'id': {'kind': 'youtube#video', 'videoId': 'bIsLlQhIMqc'},
#   'snippet': {'publishedAt': '2024-09-15T15:15:49Z',
#    'channelId': 'UC5bVlUsO3cr2b09tZZkY7Ow',
#    'title': 'Samsung Galaxy S23 FE Kg Lock Remove All Android Any BiT 2024 Sept Update Os 14 Exynos Cpu',
#    'description': 'Samsung Galaxy S23 FE Kg Lock Remove All Android Any BiT 2024 Sept Update Os 14 Exynos Cpu Game Over | Kg Lock ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bIsLlQhIMqc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/bIsLlQhIMqc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/bIsLlQhIMqc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Google Chacha',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T15:15:49Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ERZDJtoRVteIGvqopq5gDlSmsXU',
#   'id': {'kind': 'youtube#video', 'videoId': '7YJZDBDnOpE'},
#   'snippet': {'publishedAt': '2024-09-15T13:56:50Z',
#    'channelId': 'UCwsjZljt7j5qsNOf0huooEA',
#    'title': 'Free Samsung A34 U5.U6.U7.Android 14 KG  Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD',
#    'description': 'GSM GULFAM Free Samsung A34 U5.U6.U7.Android 14 KG Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7YJZDBDnOpE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7YJZDBDnOpE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7YJZDBDnOpE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'GSM Gulfam',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T13:56:50Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0EOIr0nRX_RHyl1lc92DZRuJAhY',
#   'id': {'kind': 'youtube#video', 'videoId': 'bZB8hBD4emM'},
#   'snippet': {'publishedAt': '2024-09-15T13:44:18Z',
#    'channelId': 'UCoaxBzBUU8QiUnJs4Q6dxCg',
#    'title': 'MDMFix Tool Tutorial Samsung all model KG lock , IT Admin , MDM Removal all others brands',
#    'description': 'https://www.asunlocker.com WhatsApp: +8801721672766 https://t.me/asunlocker https://fb.com/groups/asunlocker Free Firmware ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bZB8hBD4emM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/bZB8hBD4emM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/bZB8hBD4emM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Asunlocker Solution',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T13:44:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'nUCm7cJ2-TTLLvbL0LOW-qY20iI',
#   'id': {'kind': 'youtube#video', 'videoId': '0bP7_BNroBs'},
#   'snippet': {'publishedAt': '2024-09-15T13:18:23Z',
#    'channelId': 'UCuc7HWrPM2k78k5o6jIDttA',
#    'title': 'Samsung A05 U3 Kg Lock Remove With Mdm Fix Tool 🔥 #SONU_WARRAICH',
#    'description': 'Samsung A05 U3 Kg Lock Remove With Mdm Fix Tool #SONU_WARRAICH.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0bP7_BNroBs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0bP7_BNroBs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0bP7_BNroBs/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SONU_WARRAICH',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T13:18:23Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'PlDAWwLIiPz6bNHRCUoDx3-2WTA',
#   'id': {'kind': 'youtube#video', 'videoId': 'lxcSiE0cKlc'},
#   'snippet': {'publishedAt': '2024-09-15T06:54:36Z',
#    'channelId': 'UCak1xRa_qJdK3Dv6iGtWCew',
#    'title': 'DR PHONE',
#    'description': 'World First Free Samsung Android 14 KG MDM Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD World- First ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lxcSiE0cKlc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/lxcSiE0cKlc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/lxcSiE0cKlc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Doctor Phone',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T06:54:36Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'y2DDnN4DLJdseQ7WG6re6bp7N4I',
#   'id': {'kind': 'youtube#video', 'videoId': 'g5ZE4YSLe5I'},
#   'snippet': {'publishedAt': '2024-09-15T05:19:08Z',
#    'channelId': 'UCKvROSSaMtnaNvET_P68h9A',
#    'title': 'A047F Samsung A04S PERMANENT MDM U1 U4 UNLOCK MDM A04S MDM',
#    'description': 'SM-A047F #A04s #Samsung SM-A047F A04s Permanent How to remove MDM Lock SM-A047F A04s step by step 100% Done IF ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g5ZE4YSLe5I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/g5ZE4YSLe5I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/g5ZE4YSLe5I/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'ALBAX3DMDM',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T05:19:08Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'tHSl_G0JVROr3vnGkB9DTNucWqs',
#   'id': {'kind': 'youtube#video', 'videoId': 'hCvByVm-goY'},
#   'snippet': {'publishedAt': '2024-09-15T00:57:43Z',
#    'channelId': 'UCJEQV09Ue_4jZZ3zzblaj0w',
#    'title': 'SAMSUNG A05 A055F U1 U2 U3 U4 U5| ALL BINARY MDM REMOVE WITHOUT ISP SEMI-PERMANENT SOLUTION 2024 SEC',
#    'description': 'Disclaimer . THIS VIDEO IS STRICTLY FOR EDUCATIONAL PURPOSE . The author of the topic and the site is not responsible for ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hCvByVm-goY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/hCvByVm-goY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/hCvByVm-goY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Ramah Soft Solutions',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-15T00:57:43Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'X-BmMaEFFlU9mt9As7TDnSGr2dE',
#   'id': {'kind': 'youtube#video', 'videoId': 'S03QQ6IHrZE'},
#   'snippet': {'publishedAt': '2024-09-14T19:19:27Z',
#    'channelId': 'UCa5qaRy5VvLylrCxQ7hntrw',
#    'title': 'UNLOCK ANDROID 13 &amp; 14 Samsung KG unlock Octopus 2024 / MDM UNLOCK ANDROID 14 /KG lock be removed',
#    'description': 'kglock #mdmlock #samsunggalaxy #free #lock #kglock #samsunglock #android14update #android13update UNLOCK ANDROID ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/S03QQ6IHrZE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/S03QQ6IHrZE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/S03QQ6IHrZE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': '𝐒𝐇𝐔𝐊𝐋𝐀 𝐓𝐄𝐂𝐇𝐍𝐎𝐋𝐎𝐆𝐘',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-14T19:19:27Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0FCllgBztGmUR7nphViKU_H8KXg',
#   'id': {'kind': 'youtube#video', 'videoId': 'Zgxuk_akpGU'},
#   'snippet': {'publishedAt': '2024-09-14T14:28:35Z',
#    'channelId': 'UCylR2CFWJC_9ub5YG36wDJg',
#    'title': 'World First Free Samsung Android 14 KG MDM Unlock All Model  in MdmFixTool  MTK-Exynos-Qualcomm-SPD',
#    'description': 'World First Free Samsung Android 14 KG MDM Unlock All Model in MdmFixTool MTK-Exynos-Qualcomm-SPD ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zgxuk_akpGU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Zgxuk_akpGU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Zgxuk_akpGU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Technicalsolutiona2z',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2024-09-14T14:28:35Z'}}]

# %%
video_ids = [item['id']['videoId'] for item in search_result]

# %% [markdown]
# ### Get data API

# %%
# get video id
from urllib.parse import urlparse, parse_qs

def get_video_id(url):
    parsed_url = urlparse(url)
    query_params = parse_qs(parsed_url.query)
    return query_params.get('v', [None])[0]

# %%
#print json
import json

def prinJson(data):
    formatted_json = json.dumps(data, indent=4, ensure_ascii=False)
    print(formatted_json)

# %%
COL_TYPE = 'Type'
COL_LINK = 'Link'
COL_TITLE = 'Title'
COL_PUBLISHED = 'Published at'
COL_DES = 'Short description'
COL_CONTENT = 'Web content'
COL_SUMMARY = 'Summary'

# %%
import requests
from time import sleep
# requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS = 'ALL:@SECLEVEL=1'

# URL của API YouTube
API_URL_VIDEO_INFO = 'https://www.googleapis.com/youtube/v3/videos'

def get_video_info(video_id):
    headers = {
        'Content-Type': 'application/json',
        'accept': 'application/json',
    }

    params = {
        'part': 'snippet,contentDetails,statistics',
        'id': video_id,
        'key': API_KEY
    }
    # response = requests.get(API_URL_VIDEO_INFO, params=params, headers=headers, verify=False)
    # response.raise_for_status()  # Raise an exception for HTTP errors
    
    # video_info = response.json()['items'][0]

    param_string = urllib.parse.urlencode(params)
    driver.get(f"{API_URL_VIDEO_INFO}?{param_string}")
    # print(f"{API_URL_VIDEO_INFO}?{param_string}")
    sleep(2)
    
    json_res = driver.find_element(By.TAG_NAME, 'pre').text
    response = json.loads(json_res)  # Convert the JSON string to a Python dictionary
    video_info = response['items'][0]

    return video_info

def get_data(link, video_info):
    title = video_info['snippet']['title']
    description = video_info['snippet']['description']
    published_at = video_info['snippet']['publishedAt']
    res = {
        COL_TYPE: 'youtube',
        COL_LINK: link,
        COL_PUBLISHED: published_at,
        COL_TITLE: title,
        COL_DES: description
    }
    return res

# %%
#ignore title
ignore_word = ["T Mobile", "US Cellular", "Sprint USA", "Unlock Service", "Xfinity USA", "Cricket USA", "FRP", "Boost USA", "Verizon USA", "Spectrum", "Lost mode", "Huawei",
                   "Xiaomi", "screen lock", "TFN", "iphone", "icloud"]
def checkContain(title):
    title = title.lower()
    for word in ignore_word:
        if word.lower() in title:
            return True
    else:
        return False

# %%
data = []
try:
    for i, video_id in enumerate(video_ids):
        video_info = get_video_info(video_id)
        link = f"https://www.youtube.com/watch?v={video_id}"
        data_row = get_data(link, video_info)
        title = data_row[COL_TITLE]
        if checkContain(title = title):
            data.append(data_row)
            print (f'{i} {data_row[COL_TITLE]}')
    logger.info(f'Get video info success')
except Exception as e:
    logger.error(f'Get video info err: {e}')
# Out:
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=cMH6BLFjo80&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=wAb_ZqDnDLE&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 1 Samsung a035f kg lock | #shorts #shortvideo #samsung #realmefrpunlocknewtrick2022 #factoryresetphone
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=3LDBz6G86eI&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=q_aQ5HFurr0&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=sN4PuQa3Clk&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=kc3zE0t_H1c&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=eD3emCE3Z3Y&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 6 PL Tool V1.0  Qualcomm Samsung Unlock Tool  FRP, MDM, KG, Screenlock  Remove
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=pzPQ5H9YMWQ&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=dNZ_bwqEf-A&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=5TcTwXvfZBo&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=yaJIBYh22lg&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=gVV2D-Wd0SI&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=rSaSOds7AKA&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=eNVdCElQChY&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=MkOdQwb9VxY&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=-XMhUzes_wA&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=ROzQG1we7Bs&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=0QpvYsi_k6A&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vC-r9YwbOVc&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vl6fVCET49o&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 19 S21 FE 5G Finance Plus 2024/Samsung Frp Bypass/New Security ADB Enable 2024_Samsung Finance Unlock
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=cPIsUb7rl9w&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=EmXYfgfX35E&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=pzexSG2uSLM&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=j83EaO9YX4E&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=CSPtp0KuDQ4&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 24 iPhone iCloud, Erase Frp,Factory Reset, Bootloader, kg,MDM, imei Repair With Griffin Unlocker
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=yrY0kchm4uk&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=vv5UGgcTqm8&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=uEQhcRMgRvM&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=UsfEfvLv42I&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=VHDpBnc5zjE&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=seq09jc98k8&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 30 TSM Pro Tool Activation - Samsung KG lock MDM FRP Remove Xiaomi LG Huawei more
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=EaEr_-MwwW0&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 31 SAMSUNG A15  KG LOCKED FRP ON MDM KG BYPASS ALL BINARY
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=HaVkO8hvCcI&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=7wwzW0Naiq8&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=OqIo2oRnSL0&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 34 Gsm Power tool / Samsung Frp Remove Tool Android Version 12/13/14
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Cg9WSahD4B4&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# 35 Samsung KG & MDM Reset | Restore imei ,Erase FRP,Format Safe Bootloader Unlock TSM Tool One Click
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=5-g_vdWlK8M&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=wxvCv86Ivnk&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=8BVEKskQAUA&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=OdjN5fhV5Zo&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=93wazAhCRu0&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=bIsLlQhIMqc&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=7YJZDBDnOpE&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=bZB8hBD4emM&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=0bP7_BNroBs&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=lxcSiE0cKlc&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=g5ZE4YSLe5I&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=hCvByVm-goY&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=S03QQ6IHrZE&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=Zgxuk_akpGU&key=AIzaSyCCNntXp6zMa9dV-RLVC-dhp2ipv6O9Vqo

# %% [markdown]
# # GENAI

# %%
genai_module = get_module('common', 'genai.py')
Genai = genai_module.Genai

# %%
genai = Genai()
# Out:
# Open list conversation

# %%
for i, row in enumerate(data):
    try:
        summary  = genai.search(row[COL_DES])
        print(summary)
        print(f"{i}. -----------------------------")
        row[COL_SUMMARY] = summary

    except Exception as e:
        logger.error(f'Query genai fail: {e}')
        row[COL_SUMMARY] = ''
# Out:
# Fail
# 0. -----------------------------
# Fail
# 1. -----------------------------
# Fail
# 2. -----------------------------
# Fail
# 3. -----------------------------
# Fail
# 4. -----------------------------
# Fail
# 5. -----------------------------
# Fail
# 6. -----------------------------
# Fail
# 7. -----------------------------

# %% [markdown]
# ### Save data

# %%
data
# Out:
# [{'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=wAb_ZqDnDLE',
#   'Published at': '2024-10-02T12:54:17Z',
#   'Title': 'Samsung a035f kg lock | #shorts #shortvideo #samsung #realmefrpunlocknewtrick2022 #factoryresetphone',
#   'Short description': 'Samsung kg lock | all Samsung Android 14 kg unlock | Samsung a23 5g kg unlock | Samsung a236e u7 kg #samsung #frplock #how #mobilephone #mobilesolution #realme #realmemobiles #samsungmobile #security #umt \nJoin my group \nhttps://chat.whatsapp.com/Hlt1pDpVHqg6eJb1NOiBgJ\nTelegram \nhttps://t.me/Ajaytechnicalsoftwearsolution\nfrplock #how #mobilephone #mobilesolution #realme #realmemobiles #samsung #samsungmobile #security #umt\nMDM fix tool Samsung Android 14 kg Remove✅ All CPU support ✅ QC MTK Exynos Spd Mdm fix tool 2024 kg #samsung\u200b #mdm\u200b #androidphone\u200b #tech\u200b #frp\u200b #frpbypass\u200b #repai\u200b #samsunggalaxy\u200b #vivo\u200b #frpsolution\u200b\n#samsung\u200b #vivoy16frpbypassandroid12\u200b #mdm\u200b #tech\u200b #frp\u200b #androidphone\u200b #mdmfixtool\u200b #mdm\u200b \n#Samsung\u200b A03s  KG Parmanent remove, Samsung A135f Kg Lock remove parmanent #MDM\u200b without credit 2024 \nSamsung F12 KG Lock Remove Permanently with credit SM F127G ASamsung KG Lock remove 2024 Finance MDM\nSamsung A34 5g KG Lock Remove Permanently without credit - SM-A34 Samsung KG Lock remove 2024 Finance\nSamsung KG Lock Remove Permanently without credit - Samsung KG Lock remove\nsamsung finance lock,\nsamsung finance lock remove,\n#samsung\u200b finance lock unlock tool,\nsamsung finance lock remove tool,\nsamsung finance lock bypass,\nsamsung finance lock malayalam,\nsamsung finance lock ko kaise kholen,\nsamsung finance lock solution,\nsamsung finance lock remove umt,\nsamsung finance lock unlock kaise kare,\nsamsung finance lock kaise tode,\nsamsung a23 finance lock kaise tode,\nsamsung a13 finance lock kaise tode,\nsamsung a12 finance lock unlock tool,\nsamsung a135f finance lock remove,\nsamsung a13 finance lock remove,\nsamsung a03s finance lock remove,\nsamsung a13 finance lock,\nsamsung a53 finance lock,\nsamsung a13 finance lock unlock tool,\nsamsung a53 finance lock bypass,\nsamsung a13 samsung finance lock remove,\nsamsung a14 5g finance lock kaise tode,\nhow to pay samsung finance emi after lock,\nsamsung a13 ka finance lock kaise tode,\nsamsung a14 5g ka finance lock kaise tode,\nsamsung bajaj finance lock kaise tode,\nsamsung a12 finance lock bypass,\nsamsung finance plus lock bypass,\nsamsung a13 finance lock bypass,\nsamsung a135f finance lock remove ufi box,\nsamsung a23 bajaj finance lock kaise tode,\nhow to break samsung finance lock,\nhow to bypass samsung finance lock,\nhow to bypass samsung finance plus lock,\nsamsung finance lock crack,\nsamsung a03 core finance lock,\nsamsung a03 core finance lock unlock tool,\nsamsung finance company ka lock kaise tode,\ndmi finance samsung lock open,\nsamsung dmi finance ka lock kaise tode,\nsamsung finance plus lock remove without emi pay,\nsamsung finance plus emi lock kaise tode,\nsamsung emi finance lock malayalam\nsamsung emi finance lock,\nhow to remove samsung finance plus lock without paying emi,\nhow to unlock samsung finance lock without paying emi,\nhow to pay samsung finance emi after lock malayalam,\nhow to pay samsung finance emi after lock telugu,\nsamsung s20 fe 5g finance lock,\nsamsung f13 finance lock kaise tode,\nsamsung f41 finance lock remove,\nsamsung galaxy finance lock kaise tode,\nsamsung galaxy a13 ka finance lock kaise tode,\nsamsung galaxy a33 finance lock kaise tode,\nsamsung galaxy ka finance lock kaise tode,\nsamsung galaxy a22 finance lock kaise tode,\nsamsung galaxy a13 finance lock,\nhow to unlock samsung finance lock without payment,\n samsung,\nsamsung finance lock kaise toda jata hai,\nsamsung finance ka lock kaise toda jata hai,\nsamsung finance lock kaise tutata hai,\nsamsung finance lock kaise,\nsamsung finance ka lock kaise tutata hai,\nsamsung finance ka lock todna,\nsamsung finance plus ka lock kaise tode,\nsamsung finance lock mdm lock bypass,\nsamsung finance lock mobile,\nsamsung kg lock remove android 14,samsung android 14 kg lock remove,samsung,samsung a14 5g,samsung kg unlock andr ...
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=eD3emCE3Z3Y',
#   'Published at': '2024-09-27T11:37:43Z',
#   'Title': 'PL Tool V1.0  Qualcomm Samsung Unlock Tool  FRP, MDM, KG, Screenlock  Remove',
#   'Short description': '#mobilesoftwareSolution\nPL Tool V1.0  Qualcomm Samsung\n Unlock Tool  FRPMDMKG, Screenlock  Remove\nunlock tool crack\nunlock tool crack 2022\nhow to setup tft unlock tool freely\nunlock tool\nhow to install tft unlock tool\ntft unlock tool included models\nunlock tool latest setup\nhow to use tft unlock tool\nsamsung a13 frp bypass tool\numt tool new update samsung\nsamsung\nsamsung a13 frp bypass talkback not working\nmobile tools,software tools\nhardware tools\nsamsung a13 frp bypass latest version\nsamsung a13 frp bypass enable adb failed\nsamsung frp unlock\nsamsung frp tool\nunlock tool\nsamsung frp unlock 2024\nsamsung frp tool 2024\nsamsung frp\nsamsung frp bypass\nsamsung unlock\nsamsung frp bypass tool\nsamsung,samsung one click frp tool\nsamsung frp bypass 2024\nunlock tool free\nfrp all samsung adb method\nbmb unlock tool qualcomm module\ntft unlock tool qualcomm module 2024\neasy samsung frp tool\nqualcomm snapdragon frp unlock\nsamsung a51 frp unlock tool\nGet this tool 👇\nhttps://gsmsoftwarehub.blogspot.com/2024/08/pl-tool-10-free-download-latest-version.html\n\n\n\n\n\nDisclaimer\nThis Video is Only For Educational purpose, This Video is not made for doing any illegal activities, All Contents provided by this channel is only and only for Educational purpose, Please do not miss-use of any content from this video.\n\nCopyright Disclaimer under section 107 of the Copyright Act of 1976, allowance is made for “fair use” for purposes such as criticism, comment, news reporting, teaching, scholarship, Programing Language, Mobile Software Solution, education, and research. Fair use is a use permitted by copyright statute that might otherwise be infringing.',
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=vl6fVCET49o',
#   'Published at': '2024-09-21T12:00:16Z',
#   'Title': 'S21 FE 5G Finance Plus 2024/Samsung Frp Bypass/New Security ADB Enable 2024_Samsung Finance Unlock',
#   'Short description': 'Samsung Finance Plus 2023/Samsung Frp Bypass/New Security ADB Enable 2023_Samsung Finance Unlock\n\n\nSamsung A05s Kg mdm Unlock Permanent New Secusirty Via Usb Cable Only Free tool | New Security Kg\n\nIn This video you will watch get helpful\nPlease:\nLike,Share,Comment\nFor More Videos Subcribed My Channel    \n\n@gsmking786 \n#samsung \n#samsung_kg \n#samsung_frp_bypass_android_14 \n#gsmking\n#finance \n#samsung_mdm\n                        . . . .  NOTE......\n\n\n\nAnyone who wants this command should share the whatsapp number in the comment\n\nIf You Contact me So join Our Telegram Group also Here also Provide many free Tools and Many Files And Many More Solution I also Provide Online Service Like\n👉Unlocking\n👉Flashing\n👉Frp Removing\n👉Imei Repair\n👉Tools Sharing\n👉ICloud Remove \n👉Apple Unlock \nAnd Many More\n\nGroup Link : telegram(gsmking0977)\n\n                               WARNING:\n\nJust for Education purpose\nnote IMEI change is illegal do all it on your own risk\n                                          DISCLAIMER:\nChanging of IMEI is illegal in some Countries\nI will not be held responsible for any illegal ACTS \n caused by viewer/visitors of this video. \nAccording to the Digital Millennium CopyRight Act its illegal\nRemember to write down your original IMEI number and keer it SAFE.\nAlso, backup your original IMEI in-case anything goes wrong, Then revert using the above procedures for CHANGING........\n\n#mdm \n#mdmfixtool\n#kg \n#samsung \n#finance                                             \n#it_admin\n#samsung_kg\n\n                                         "GSMKING "\n\n🤫 *ALL BRANDS FINANCE LOCK ORDER ACCEPT PERMANENT & BYPASS*\n\n*ORDER ALL OVER WORLD ACCEPT* 🙂\n\nPAYMENT METHOD.\nBINANCE PAY \nINDIAN PAY\nPAKISTAN PAY\n\nUnlock tool \nDft pro\nPandora latest\nChimera Both\nMdm Fix\nZ3X\nCm2 v2.51\nOctoplus all\nAvenger\nGc Pro\nTfm tool\n\nAll tool Availavle for rent in Low Price😜\n\nActivation and Working Service available also\n\nContact Me\n\nKg Mdm It admin also remove Permenant and Bypass\n#samsung \n#samsung_kg \n#samsung_frp_bypass_android_14',
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=CSPtp0KuDQ4',
#   'Published at': '2024-09-18T17:59:28Z',
#   'Title': 'iPhone iCloud, Erase Frp,Factory Reset, Bootloader, kg,MDM, imei Repair With Griffin Unlocker',
#   'Short description': "iPhone iCloud, Erase Frp,Factory Reset, Bootloader Unlock, kg unlock,mdm unlock,imei Repair With Griffin Unlocker Preload Auth FREE.\nIf Yoi Need this Tool Watch full video to get Griffin Unlocker Latest Version life time FREE Update. \n\nGriffin Unlocker Is Powerful GSM Software Tool You can easily Unlock iCloud, Reset frp Lock, Password Unlock, Bootloader Unlock, Original imei repair, Flashing etc All  Android Mobile devices without Box. \n\nAll iPhone,iPads iCloud bypass Tool. \nVivo frp bypass 2024 new Security Preload Authentication. \nOppo Password Unlock Meta Mode. \nHuawei frp and Huawei I'd Remove. \nTecno/ infinix MDM Lock Unlock. \nSamsung Galaxy new Security frp bypass. \nAll SPd Android Mobile devices frp or factory Reset with Griffin Unlocker tool.\nAll Mediatek CPU Type Android Mobile devices frp ,Password Unlock without data Lose. \nAll Spd Android Mobile devices Supported for frp Unlock and Flashing new Security Base Update. \n\n#griffinunlocker #frpunlocktool #passwordreset #bunertech",
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=seq09jc98k8',
#   'Published at': '2024-09-17T17:35:32Z',
#   'Title': 'TSM Pro Tool Activation - Samsung KG lock MDM FRP Remove Xiaomi LG Huawei more',
#   'Short description': 'https://www.asunlocker.com\nWhatsApp: +8801721672766\nhttps://t.me/asunlocker\nhttps://fb.com/groups/asunlocker\nFree Firmware , Box dongle buy https://www.asfirmware.com\n\njoin Whatsapp group\nhttps://chat.whatsapp.com/LgsrLzmqjxIDqVpUVzT4Ly\n\njoin whatsapp channel\nhttps://www.whatsapp.com/channel/0029VafXUAw0bIdgrbw1rF3I\n\n\nSamsung FRP Remove any model\nhttps://youtu.be/9yNM4z6GNWA\n\nTeno Infinix MDM Remove solution\nhttps://youtu.be/vBjDj2ZIKcg\n\nXiaomi Mi Account lock remove\nhttps://youtu.be/QVN-a4PyGyo\n\nXiaomi FRP Remove any model\nhttps://youtu.be/bGvJ7q9WHOA\n\nFree iCloud Bypass tutorial\nhttps://youtu.be/Ix3ohHSnR0k\n\niHello HFZ tool iCloud Bypass\nhttps://youtu.be/-MvKuRW6HDc\n\nNokia HMD Screen lock , FRP Remove , Flash \nhttps://youtu.be/oRTjMBdDdJ8\nhttps://youtu.be/oRTjMBdDdJ8\n\nunlock tool Activation\nhttps://youtu.be/0GeECubQihE\n\nZ3X pandora Activation 1  year no need box dongle \nhttps://youtu.be/Q2IRG2vPbu0\n\nDFT Pro Activation and features ( no need box dongle )\nhttps://youtu.be/QXwlGDI0TzM\nhttps://youtu.be/dBMbtvldhKM\n\niPhone ios 15/16 iCloud bypass sim working \nhttps://youtu.be/P5egHdoOBN8\n\nSamsung FRP remove , samsung account remove \nhttps://youtu.be/ZtsgnaHP3cs\nhttps://youtu.be/7kz_Wk8p6Og\n\nCF Tool Activation\nhttps://youtu.be/zRmegDxR3uI\n\nNokia Screen lock+ FRP remove \nhttps://youtu.be/3PKBWbW3PXc\n\nOnePlus Screen lock, FRP, Demo remove, flash \nhttps://youtu.be/ob0zN0r8WvE\n\noppo screen lock, FRP, Demo remove , Flash \nhttps://youtu.be/5iwzPp_bNqY\n\nMEID iPhone iCloud bypass SIM working\nSupport: 5s To X all Model \nhttps://youtu.be/t5T4CRCherE\n\niPhone Jailbreak Without Mac by Windows\nhttps://youtu.be/nQsK6XFFMJo\n\niPhone 6+ iCloud bypass SIM Working\nhttps://youtu.be/t5T4CRCherE\n\nSamsung Remove Tool SAMHub Tool\nhttps://youtu.be/inuLhL3xDVA\n\nsamsung frp / google account unlock \nhttps://youtu.be/kxEQl-nSYQw\n\nsamsung network unlock \nhttps://youtu.be/-yI_P5Ap_WU\n\noppo network unlock \nhttps://youtu.be/H1aZJoyHmaM\n\nhuawei frp \nhttps://youtu.be/E0b0cv0tNAI\nhttps://youtu.be/ka-l5Osa9p4\n\niphone network unlock \nasunlocker.com\nhttps://www.youtube.com/watch?v=DBvY-tuT9eQ\n\niphone icloud bypass \nhttps://youtu.be/a_B4KatAOD0\n\niphone icloud remove password lock /disable phone \nhttps://youtu.be/iZw-OSZfOCQ\n\nMEID iCloud Bypass\nhttps://youtu.be/Vn8-06Ocgyg\n\niPhone SIM Not Valid Solution\nhttps://youtu.be/BIdZaeSAyZg\n\niPhone Jailbreak 14.4\nhttps://youtu.be/c4VtX4VCjwM\n\niCloud bypass free\nhttps://youtu.be/Geo-61rHcGY\n\niphone icloud remove open menu set proxy and inform me \nhttps://youtu.be/22sTkOg88Cs\n\n\nhttps://www.asunlocker.com\nWhatsApp: +8801721672766\nhttps://t.me/asunlockerupdate\nhttps://www.whatsapp.com/channel/0029VafXUAw0bIdgrbw1rF3I\nhttps://chat.whatsapp.com/LgsrLzmqjxIDqVpUVzT4Ly\nfacebook.com/groups/asunlocker',
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=EaEr_-MwwW0',
#   'Published at': '2024-09-17T13:04:25Z',
#   'Title': 'SAMSUNG A15  KG LOCKED FRP ON MDM KG BYPASS ALL BINARY',
#   'Short description': 'EPATELETECH is exerting visit to view and learn knowledge\nDownload Tool here https://epateletech.com/2024/09/14/samsung-a15-a155f-u2-mdm-bypass/',
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=OqIo2oRnSL0',
#   'Published at': '2024-09-16T16:03:25Z',
#   'Title': 'Gsm Power tool / Samsung Frp Remove Tool Android Version 12/13/14',
#   'Short description': "Gsm Power tool / Samsung Frp Remove Tool Android Version 12/13/14 \n\ntool  https://shorturl.at/jx44b\n\n\nUnlock your Samsung device effortlessly with our comprehensive guide on using the Samsung FRP Bypass Tool for Android versions 12, 13, and 14. In this video, we will walk you through the step-by-step process to seamlessly remove FRP (Factory Reset Protection) from your Samsung smartphone or tablet. Whether you’ve forgotten your Google account credentials or purchased a second-hand device that’s locked, this tool is your solution for bypassing FRP quickly and efficiently. \n\nWhat you'll learn in this video:\n- Overview of the Samsung FRP Bypass Tool\n- Compatibility with Android 12, 13, and 14\n- Detailed instructions on how to use the tool\n- Troubleshooting tips for common issues\n- Safety precautions to take during the process\n\nDon’t let FRP lock hinder your access to your device. Watch now and regain control of your Samsung device in no time! Remember to subscribe for more helpful tech tutorials and tips. \nsamsung kg lock bypass\nsamsung frp bypass\nsamsung kg lock\nkg lock\nsamsung finance lock\nsamsung\nsamsung kg lock remove\nsamsung finance plus unlock\nsamsung kg lock unlock\nsamsung kg locked unlock tool\ngriffin-unlocker\nsamsung frp\nsamsung android 13 frp bypass\nsamsung finance unlock\nsamsung frp bypass 2024\na032f kg lock\nsamsung frp tool\nhow to remove kg lock\nkg lock bypass\nsamsung kg lock remove adb\nsamsung finance lock unlock\nunlock kg samsung\nmdm lock\nbypass samsung kg lock\nremove kg samsung qualcomm\nsamsung a13 kg lock remove unlock tool\nsamsung android 14 frp bypass\nsamsung frp bypass *#0*# not working\nsamsung frp bypass tool\nsamsung mdm lock bypass\nufixer\nsamsung frp remove 2024\nkg samsung\nkg status locked 01\nkg status active 01\nsamsung mdm lock\nsamsung frp remove\nsamsung frp bypass adb enable fail\nsamsung frp enable adb failed\nsamsung frp unlock\nsamsung frp unlock 2024\nsamsung knox security\nsamsung enable adb qr code\nsamsung new frp tool 2024\nsamsung a13 kg lock bypass\nsamsung frp 2024 adb not enable\nfrp samsung bypass new security 2024\nsamsung android 13 frp bypass enable adb fail\nbypass frp lock\nqr code generator frp\n\nsamsung frp bypass 2024,samsung android 13 frp bypass,samsung frp bypass,samsung android 14 frp bypass,samsung frp tool 2024,samsung frp bypass 2024 adb enable fail,samsung frp bypass 2024 android 14,samsung frp remove 2024,samsung frp tool,samsung frp bypass adb enable fail,samsung frp unlock 2024,samsung frp,samsung frp bypass android 13 2024,samsung frp bypass *#0*# not working,samsung frp bypass android 14,samsung frp bypass android 13,samsung frp remove",
#   'Summary': 'Fail'},
#  {'Type': 'youtube',
#   'Link': 'https://www.youtube.com/watch?v=Cg9WSahD4B4',
#   'Published at': '2024-09-16T15:59:53Z',
#   'Title': 'Samsung KG & MDM Reset | Restore imei ,Erase FRP,Format Safe Bootloader Unlock TSM Tool One Click',
#   'Short description': 'Samsung KG & MDM Reset | Restore imei ,Erase FRP,Format Safe Bootloader Unlock TSM Tool One Click Without Box or Dongle Life Time FREE GCT Team. \n\nTSM Tool is Powerful GSM Software Tool You can easily Unlock and Flash Your Own Any Android Mobile devices without Box. \n\nFor More information Watch full video To Get \n\nSupported Modules:\nSamsung Galaxy Full Supported. \nOppo \nVivo\nHuawei \nXiaomi \nTecno \nInfinix \nLenovo \nWiko\nEtc Android Mobile devices Supported TSM Tool.\n\nTSM Tool Features:\nFactory Reset without Data Lose. \nErase frp Lock. \nBootloader Unlock \nRelock Bootloader \nRestore Orange state error \nRepair Original imei number if Null.\nFlashing Qualcomm, MTK Hissilicon CPU Type Android Mobile devices. \nEtc features available in TSM Tool. \n\n\n#androidbypass #kglock #mdmunlock #frpbypass #imeirepair #factoryreset #bunertech #cracked #frptool #flashing',
#   'Summary': 'Fail'}]

# %%
import pandas as pd
import os
from datetime import datetime
from openpyxl import load_workbook
try:
    today = datetime.today().date()
    df = pd.DataFrame(data)

    file_path = f'..//output//output_{today}.xlsx'
    sheet_name = f'youtube_{today}'

    if os.path.exists(file_path):
        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='new') as writer:
            if sheet_name in writer.book.sheetnames:
            # Xóa sheet cũ
                writer.book.remove(writer.book[sheet_name])
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    logger.info(f'Export {len(data)} data successful')
except Exception as e:
    logger.error(f"Save data fail: {e}")

# %%
print('Success')
# Out:
# Success

# %% [markdown]
# query"
# ("Samsung Knox Guard" OR "Samsung MDM" OR "Samsung KG") AND ("unlock" OR "unfasten" OR "unbolt" OR "open" OR "release" OR "unlatch" OR "disengage" OR "free" OR "unseal" OR "uncover" OR "access") AND ("bypass" OR "circumvent" OR "avoid" OR "sidestep" OR "evade" OR "skip" OR "dodge" OR "work around" OR "ignore" OR "overcome" OR "elude") AND ("removal" OR "elimination" OR "deletion" OR "eradication" OR "extraction" OR "withdrawal" OR "dismissal" OR "expulsion" OR "displacement" OR "ouster" OR "exclusion") AND ("tool" OR "software" OR "method" OR "technique" OR "unlocker" OR "key generator" OR "exploit" OR "vulnerability" OR "APK") AND ("ADB" OR "flash firmware") AND ("guide" OR "tutorial" OR "step-by-step" OR "how-to") AND ("legal" OR "issues" OR "compatibility" OR "support") AND ("community forums" OR "troubleshooting") AND ("2024" OR "updated methods") AND ("Galaxy S-series" OR "Note-series" OR "latest security patch") AND (date:2024-08)
#
# 32 words only for google search:
# ("Samsung Knox Guard" OR "Samsung MDM" OR "Samsung KG") AND ("unlock" OR "bypass" OR "removal") AND ("tool" OR "method" OR "software" OR "guide") AND ("August 2024" OR "latest update")
