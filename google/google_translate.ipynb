# %% [markdown]
# ### Translation using Google

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import importlib.util
import os

# %%
def get_module(module_name, file_name):
    name = file_name.split('.')[0]

    module_path = os.path.join(os.getcwd(), '..', module_name, file_name)
    spec = importlib.util.spec_from_file_location(name, module_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
driver_module = get_module('common', 'web_driver.py')
get_driver = driver_module.get_driver

translate_module = get_module('common', 'translate.py')
Translate = translate_module.Translate

# %%
driver = get_driver()

# %%
translator = Translate(driver)

# %%
from langdetect import detect
import requests

# %%
COUNTRIES = ['Ghana', 'Kenya', 'Liberia', 
             'Malawi', 'Mauritania', 'Morocco',
             'Mozambique', 'Nigeria', 'Sierra Leone', 
             'Somalia', 'South Africa', 'Tanzania', 
             'Zambia', 'Thailand']

LANGUAGES = {
    'Ghana': ['English'],
    'Kenya': ['English', 'Swahili'],
    'Liberia': ['English'],
    'Malawi': ['Chichewa', 'English'],
    'Mauritania': ['Arabic'],
    'Morocco': ['Arabic'],
    'Mozambique': ['Portuguese'],
    'Nigeria': ['English'],
    'Sierra Leone': ['English'],
    'Somalia': ['Somali'],
    'South Africa': ['Afrikaans', 'English', 'Zulu'],
    'Tanzania': ['Swahili', 'English'],
    'Zambia': ['English'],
    'Thailand': ['Thai']
}

LANGUAGES_CODES = {
    'English': 'en',
    'Swahili': 'sw',
    'Arabic': 'ar',
    'Portuguese': 'pt',
    'Somali': 'so',
    'Afrikaans': 'af',
    'Chichewa': 'ny',
    'Northern Sotho': 'ns',
    'Ndebele': 'nr',
    'Siswati': 'ss',
    'Tswana': 'tn',
    'Tsonga': 'ts',
    'Venda': 've',
    'Xhosa': 'xh',
    'Zulu': 'zu',
    'Thai': 'th'
}

COUNTRY_CODES = {
    'Ghana': 'GH',
    'Kenya': 'KE',
    'Liberia': 'LR',
    'Malawi': 'MW',
    'Mauritania': 'MR',
    'Morocco': 'MA',
    'Mozambique': 'MZ',
    'Nigeria': 'NG',
    'Sierra Leone': 'SL',
    'Somalia': 'SO',
    'South Africa': 'ZA',
    'Tanzania': 'TZ',
    'Zambia': 'ZM',
    'Thailand': 'TH'
}

# %%
def getAPIURL(text, from_lang, to_lang):
    return f"https://api.mymemory.translated.net/get?q={text}&langpair={from_lang}%7C{to_lang}"

# %%
def translate_using_google(text):
    return translator.translate(text)

# %%
def translateUsingApi(text):
    from_lang = detect(text)
    url = getAPIURL(text, from_lang, 'en')
    response = requests.get(url, verify=False)
    data = response.json()
    response.raise_for_status() # Raise an exception for HTTP errors
    data['responseData']['translatedText']
    return data['responseData']['translatedText']

# %%
translate_using_google("مرحبًا بالجميع، أتمنى لكم يومًا جديدًا مليئًا بالطاقة والحظ.")

# %%
translate_using_google("ซัมซุงกับโกดักนั้นมีปัญหากันอยู่ในกรณีสิทธิบัตรนี้ ก่อนหน้านี้ โกดักก็ได้ร้องเรียนกับหน่วยงานเดียวกันนี้ ว่าซัมซุงและแอลจีละเมิดสิทธิบัตรของโกดัก ซึ่งคณะกรรมการก็ได้รับเรื่องร้องเรียนนั้นไว้พิจารณา คณะกรรมการนี้มีอำนาจในการหยุดการนำเข้าสินค้าที่ละเมิดสิทธิบัตร จึงทำให้เป็นช่องทางที่มักใช้ในการร้องเรียนเรื่องนี้")

# %% [markdown]
# ### Google Scanner

# %%
with open('../common/logger.py') as f:
    exec(f.read())

logger = get_logger(name='google')
logger.info('Start crawl multi-country google')
logger
# Out:
# <Logger google (DEBUG)>

# %%
from time import sleep
google_count = 0
def get_google(url):
    google_count += 1
    if google_count % 40 == 0:
        sleep(60)
    driver.get(url)

# %%
TAT_CA_CAC_TU = 'bypass knox samsung'
CUM_TU_CHINH_XAC = ''
BAT_KY_TU_NAO = ''
KHONG_TU_NAO = ''

# %%
TAT_CA_CAC_TU = 'samsung'
CUM_TU_CHINH_XAC = '"bypass KNOX" OR "bypass samsung"' # chua 1 trong cac cum tu
BAT_KY_TU_NAO = 'KNOX KG hack bypass attack' # chưa 1 trong cac tu nay
KHONG_TU_NAO = ''

# %%
FROM_DAY = 15
FROM_MONTH = 4
FROM_YEAR = 2024
TO_DAY = 15
TO_MONTH = 10
TO_YEAR = 2024

# %%
try:
    get_google("https://www.google.com/advanced_search")
    elems = driver.find_elements(By.TAG_NAME, "input")
    elems[0].send_keys(TAT_CA_CAC_TU)
    elems[1].send_keys(CUM_TU_CHINH_XAC)
    elems[2].send_keys(BAT_KY_TU_NAO)
    elems[3].send_keys(KHONG_TU_NAO)
    elems[14].send_keys(Keys.ENTER)
except Exception as e:
    logger.error(f'Selenium google search advanced: {e}')

# %%
# INPUT = "samsung AND (unlock OR hacking OR bypass OR crack OR furid OR jabsasho OR ka gudubid OR jebin) AND (Knox guard OR knoxguard OR KG OR MDM OR Maareynta Aaladaha Gacanta)"
INPUTS = ["\"samsung\" \"knox\" \"guard\" hack",
         "\"samsung\" \"knox\" \"guard\" crack",
         "\"samsung\" \"knox\" \"guard\" bypass",
         "\"samsung\" \"knox\" \"guard\" unlock",
         "\"samsung\" \"mdm\" hack",
         "\"samsung\" \"mdm\" crack",
         "\"samsung\" \"mdm\" bypass",
         "\"samsung\" \"mdm\" unlock",
         "\"samsung\" \"kg\" hack",
         "\"samsung\" \"kg\" crack",
         "\"samsung\" \"kg\" bypass",
         "\"samsung\" \"kg\" unlock",
         "\"samsung\" \"finance\" plus hack",
         "\"samsung\" \"finance\" plus crack",
         "\"samsung\" \"finance\" plus bypass",
         "\"samsung\" \"finance\" plus unlock"
         ]

INPUT = "\"samsung\" (\"knox\" \"guard\" OR \"MDM\" OR \"KG\" OR \"finance\") (\"hack\" OR \"crack\" OR \"bypass\" OR \"unlock\")"

# %%
urlByCountry = []
COUNTRYY = ['Thailand']

# %%
def getUrlByCountry():
    url = driver.current_url
    for country in COUNTRYY:
        new_url = url + "&cr=country" + COUNTRY_CODES[country]
        urlByCountry.append(new_url)

# %%
# driver.get("https://www.google.com/search?q="+INPUT)
# getUrlByCountry()

for input in INPUTS:
    get_google("https://www.google.com/search?q="+input)
    getUrlByCountry()

urlByCountry
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 5
#       1 # driver.get("https://www.google.com/search?q="+INPUT)
#       2 # getUrlByCountry()
#       4 for input in INPUTS:
# ----> 5     get_google("https://www.google.com/search?q="+input)
#       6     getUrlByCountry()
#       8 urlByCountry
#
# Cell In[14], line 4, in get_google(url)
#       3 def get_google(url):
# ----> 4     google_count += 1
#       5     if google_count % 40 == 0:
#       6         sleep(60)
#
# UnboundLocalError: cannot access local variable 'google_count' where it is not associated with a value

# %%
len(urlByCountry)
# Out:
# 16

# %%
def preprocess():
    try:
        cur_url = driver.current_url
        # driver.get(cur_url+"&udm=14&tbs=qdr:w")
        get_google(cur_url+f"&udm=14&tbs=cdr%3A1%2Ccd_min%3A{FROM_MONTH}%2F{FROM_DAY}%2F{FROM_YEAR}%2Ccd_max%3A{TO_MONTH}%2F{TO_DAY}%2F{TO_YEAR}")
    except Exception as e:
        logger.error(f'Selenium google filter search result: {e}')

# %%
def process():    
    list_ignore = ['youtube.com', 'samsung.com']
    try:
        while(1):
            elem = driver.find_elements(By.CSS_SELECTOR, 'div.g')
            for e in elem:
                title       = e.find_element(By.TAG_NAME, 'h3').text
                link        = e.find_element(By.TAG_NAME, 'a').get_attribute("href")
                elem        = e.find_elements(By.TAG_NAME, 'span')
                website     = elem[2].text 
                elem        = e.find_element(By.TAG_NAME, 'div')
                elem        = elem.find_elements(By.TAG_NAME, 'div')
                description = elem[-2].text
                if all(ignore not in link for ignore in list_ignore):
                    google_links.append({'title': title, 'link': link, 'description': description, 'website': website})

            # next page    
            elem = driver.find_element(By.ID, "pnnext")
            elem.click()

    except NoSuchElementException:
        logger.info('Searched all pages!')
    except Exception as e:
        logger.info(f'Selenium search filter many pages: {e}')

# %%
google_links = []
def getAllGoogleLinks():
    for url in urlByCountry:
        get_google(url)
        preprocess()
        process()

# %%
def remove_duplicate_links():
    seen_links = set()
    result = []
    
    for link in google_links:
        if link['link'] not in seen_links:
            result.append(link)
            seen_links.add(link['link'])
    
    return result

# %%
getAllGoogleLinks()
google_links_all = google_links
google_links = remove_duplicate_links()
google_links
# Out:
# [{'title': 'Sandee Phoenix',
#   'link': 'https://www.facebook.com/paviwat.suwannasansak/?locale=th_TH',
#   'description': '2024. 5. 29. — ... Knox Guard MDM/KG and IT admin restrictions on various Samsung Galaxy smartphone models. Supported models include Galaxy Z Fold, Z Flip, S series, Note ...',
#   'website': 'Facebook'},
#  {'title': 'T-Tool Team',
#   'link': 'https://www.facebook.com/photo.php?fbid=2938584213119832&id=2027539344224328&set=a.2036003380044591&locale=th_TH',
#   'description': '2024. 7. 8. — ... samsung knox Guard (KG) status (4 cases) ✔️KG Prenormal ✔️KG Locked ✔️KG Completed ✔️KG Checking Wipe userdata & Reset UserLocks [7 Methods] ✔️ ...',
#   'website': 'Facebook'},
#  {'title': 'Clean IMEI',
#   'link': 'https://www.facebook.com/phonereform/?locale=th_TH',
#   'description': '2024. 7. 5. — Samsung #kg Removal. CLEANIMEI.COM. Samsung KG (Knox Guard) Lock Removal Service ... for Samsung Unlock, Samsung IMEI Repair, and. Samsung FRP Unlock services ...',
#   'website': 'Facebook'},
#  {'title': 'ปลดล็อคโทรศัพท์ติดโปรศูนย์ทรู',
#   'link': 'https://pantip.com/topic/39500035/desktop',
#   'description': '2일 전 — Samsung Galaxy A50 Samsung ... ซื้อเครื่องมือสองมา J6+ พอเปิดเครื่องมันขึ้นว่าเครื่องจะล็อคหากไม่มีการชำระค่าบริการ (น่าจะเบอร์รายเดือนของเจ้าของเดิม) หาข้อมูลบอกว่าเป็นระบบ knox guard ปัจจุบัน ...',
#   'website': 'Pantip'},
#  {'title': 'GSM WORLDWIDE',
#   'link': 'https://www.facebook.com/groups/1445374475482583/?locale=th_TH',
#   'description': '2024. 6. 28. — ✡️SAMSUNG A245F KG MDM UNLOCK DONE✓ ✡️SEND YOUR ORDER INBOX REMOTELY WORK ========================================== @highlight #highlights2024',
#   'website': 'Facebook'},
#  {'title': 'Azer Qarayev',
#   'link': 'https://www.facebook.com/p/Azer-Qarayev-61552679021494/?locale=th_TH',
#   'description': '2024. 10. 4. — ... hack WiFi hacking Network hacking Camera hacking ... SAMSUNG FRP ON✅️ @aze009 NOKIA PIN FRP ON✅️ XIAOMI FRP MI ACCOUNT WW✅️ TECNO INFINIX ITEL  ...',
#   'website': 'Facebook'},
#  {'title': 'Blognone | ข่าวไอที เทคโนโลยี มือถือ เกม ความปลอดภัย โอเพน ...',
#   'link': 'https://www.blognone.com/node?page=47&k=man%20sucking%20shemale%20cock',
#   'description': '2024. 8. 6. — Samsung เริ่มสายการผลิตหลักแรม LPDDR5X 12GB และ 16GB ที่บาง 0.65 มิลลิเมตร ... MDM. Node Thumbnail. เซิร์ฟเวอร์ของบริษัท Mobile Guardian ผู้ให้บริการ mobile device ...',
#   'website': 'Blognone'},
#  {'title': 'ไดเรกทอรีบทความ',
#   'link': 'https://th.linkedin.com/directory/articles',
#   'description': '2024. 5. 31. — ช่องโหว่ในโทรศัพท์ Samsung ถูกเพิ่มในรายการ Must Patch ของ CISA เนื่องจากการ ... Master Data management (MDM) · การ “ลาออก” กับดาต้า สถิติที่ HR ควรรู้ ...',
#   'website': 'LinkedIn'},
#  {'title': 'Unlock Tool Crack Free',
#   'link': 'https://www.facebook.com/groups/unlocktoolscracks/?locale=th_TH',
#   'description': '2024. 10. 8. — TFT Unlock Tools 2024 V3.3.0.0 UnlockTool Free ⚡Samsung⚡ Huawei ⚡Update⚡ Downgrade ⚡MDM REMOVE⚡ Reset FRP Download https://www.aligsmlab.com/2024/03/TFT- Unlock ...',
#   'website': 'Facebook'},
#  {'title': 'Mz mobiles software',
#   'link': 'https://www.facebook.com/p/Mz-mobiles-software-100066643181377/?locale=th_TH',
#   'description': '2024. 7. 6. — ... Samsung MTK phones - Added support Samsung phones SM-A136B, SM-A136M ... Unlock MDM (April 2023) operation! Added support for Android 11 if Method ...',
#   'website': 'Facebook'},
#  {'title': 'MobileSea Service Tool',
#   'link': 'https://www.facebook.com/photo.php?fbid=195332783332248&id=100085665815355&set=a.122342080631319&locale=th_TH',
#   'description': '2024. 7. 21. — ... Samsung Module ⚡️Added New Method ... added MDM bypass iphone 5s to 14 pro mac (all ios) added block ota update ...',
#   'website': 'Facebook'},
#  {'title': 'Easyfixunlocker',
#   'link': 'https://www.facebook.com/nasujon76/?locale=th_TH',
#   'description': '2024. 7. 24. — Easyfixunlocker, คูมิลลา. ถูกใจ 597 คน · 1 คนกำลังพูดถึงสิ่งนี้. Frp Network unlock, KG Bypass,MDM Unlock,Flash,, etc. ... Samsung T505N MDM Unlock Send order Samsung CPID ...',
#   'website': 'Facebook'},
#  {'title': 'FiX TecH CR ซ่อมมือถือเชียงราย ปลดล็อคออนไลน์ ขายส่งอะไหล่ ...',
#   'link': 'http://fixtechcr.lnwshop.com/',
#   'description': '7일 전 — รุ่นที่รองรับการปลดล็อครายเดือน Samsung Finance,Samsung Grab,Samsung ... ฟรี❗❗ ปลดล็อคเครื่องรายเดือน Note 10 Plus ค้างชำระค่าบริการ N975F Bypass MDM No PC FREE❗❗',
#   'website': 'LnwShop'},
#  {'title': 'โปรแกรมซ่อมมือถือ MDM FIXTOOL Activation 1ปี จัดส่งทางแช ...',
#   'link': 'https://www.lazada.co.th/products/mdm-fixtool-activation-1-i5330044126.html',
#   'description': 'THB 4,000.00',
#   'website': 'Lazada'},
#  {'title': 'Mobile Legends',
#   'link': 'https://www.facebook.com/photo.php?fbid=1813878382097301&id=820751558076660&set=a.821649767986839&locale=th_TH',
#   'description': '4일 전 — Kg hoki. Cmn 200rb aj.. ไม่มีคำอธิบายรูปภาพ. 5 ปี. Mobile Legends: Bang Bang ... Samsung J7):* 5. 【Waktu Registrasi】 akun kamu yang di-Hack* : (tutor ...',
#   'website': 'Facebook'},
#  {'title': 'LOG Dergisi - -Günümüzde birçok farklı hack yöntemi ...',
#   'link': 'https://www.facebook.com/photo.php?fbid=676607844505007&id=100064673924545&set=a.551153823717077&locale=th_TH',
#   'description': '2024. 6. 26. — aldığı M5\'ten daha ağır olan (1.971 kg vs 2.445 kg) araç, gücü standart ... İddia: "Samsung Galaxy S25 ailesinde bir MediaTek işlemci de olabilir ...',
#   'website': 'Facebook'},
#  {'title': 'Samsung',
#   'link': 'https://www.facebook.com/photo.php?fbid=855178053318383&id=100064785873719&set=a.690140856488771&locale=th_TH',
#   'description': '2024. 6. 6. — 8 kg price? 4 เดือน. Samsung. \U000f188f. Hello Sabbir Khan, Our 8 kg capacity of front-loading category washing machines are available at BDT 63,900 to BDT 70,900.',
#   'website': 'Facebook'},
#  {'title': 'Pectin from Durian (Durio zibethinus Murray) Peel',
#   'link': 'https://tis.wu.ac.th/index.php/tis/article/download/7627/874',
#   'description': 'W Kheowmung 저술 · 2024 · 2회 인용 — Long lab-lae is ovoid-oblong to nearly round shaped with an average weight between 0.5 and 3.5 kg. The peel is green to yellowish brown, thick and semi ...',
#   'website': 'Trends in Sciences'},
#  {'title': 'ไวน์กับคนไทย เรื่องดีๆที่คอไวน์ต้องรู้',
#   'link': 'https://www.wineyou.com/%E0%B8%84%E0%B8%AD%E0%B9%84%E0%B8%A7%E0%B8%99%E0%B9%8C%E0%B8%95%E0%B9%89%E0%B8%AD%E0%B8%87%E0%B8%A3%E0%B8%B9%E0%B9%89/%E0%B9%84%E0%B8%A7%E0%B8%99%E0%B9%8C%E0%B8%81%E0%B8%B1%E0%B8%9A%E0%B8%84%E0%B8%99%E0%B9%84%E0%B8%97%E0%B8%A2/',
#   'description': '2024. 6. 28. — planeta-alvi.es/carcasa-rigida-samsung-j5-2017-2629.html ... The weight of the parcel ehappynews.com can be up to 20 kg, and its format must correspond to the ...',
#   'website': 'wineyou.com'},
#  {'title': 'Mobishop',
#   'link': 'https://www.facebook.com/photo.php?fbid=849046233890261&id=100063546758149&set=a.476205261174362&locale=th_TH',
#   'description': '2024. 7. 4. — SAMSUNG KG LOCKED PERMANENT REMOVE No Need Test Mode /Adb/Anything Just Connect Usb redirector with Mtp Mode instant. Services All Androids 8,9,10,11,12,13, ...',
#   'website': 'Facebook'},
#  {'title': 'Fastgsm Fix',
#   'link': 'https://www.facebook.com/fastgsmfix2/?locale=th_TH',
#   'description': '2024. 6. 5. — Samsung S23 Ultra One UI Version: 6.1 KG Lock Full bypass done No relock after format ✓ Auto update disabled ✓ ... รูปโปรไฟล์ของ Fastgsm Fix · Fastgsm Fix. 27 ...',
#   'website': 'Facebook'},
#  {'title': 'UPS Zircon ZC-EP 30kVA 3:3p',
#   'link': 'https://modernsave.com/ups-/27262-ups-zircon-zc-ep-30kva-33p.html',
#   'description': '2024. 6. 19. — SAMSUNG · SKD · SteelSeries · Syndome · Synology · TP-LINK · Ubiquiti · Unitec · Vertex ... Shipping weight (kg), 371. Standards, Safety, IEC/EN62040-1,IEC/ ...',
#   'website': 'Modernsave'},
#  {'title': 'Panasonic Lumix GH7 - BIGCamera : ศูนย์รวมกล้องดิจิตอลที่มี ...',
#   'link': 'https://www.bigcamera.co.th/panasonic-lumix-gh7?srsltid=AfmBOoqvLCxVPAZ49yWc8PoUUC3X1b0mDPXkOlNOrWyrQBri2G8qZMmc',
#   'description': 'THB 75,991.00 · 재고 없음',
#   'website': 'bigcamera.co.th'},
#  {'title': 'กล้อง Lumix G Mirrorless DC-GH7GA',
#   'link': 'https://www.panasonic.com/th/consumer/camera-camcorder/lumix-g-camera/lumix-g-mirrorless-camera/dc-gh7ga.html',
#   'description': 'THB 79,990.00',
#   'website': 'Panasonic'},
#  {'title': 'แผนปฏิบัติการ ประจำปีงบประมาณ 2566',
#   'link': 'https://srth.go.th/news/MyResize/9srthplain.pdf',
#   'description': '2024. 6. 28. — ... kg. 60.00. 120.00. 58 กลุ่มภำรกิจด้ำนบริกำรทุติยภูมิและตติยภูมิ. งำนกำยอุปกรณ์ ... Samsung รุ่น MLT-3310ND. 376 ตลับ. 390.00. 146,640.00. 47 กลุ่มภารกิจด้านอ้า ...',
#   'website': ''},
#  {'title': 'ATEN 4 Port HDMI/USB KVM Switch with USB2.0 and Audio',
#   'link': 'https://www.mc.co.th/eshop/4-port-hdmi-kvm-switch/2932-4-port-usb-hdmiaudio-kvm-switch-with-usb20-and-audio.html',
#   'description': '4일 전 — 0.53 kg ( 1.17 lb ). Dimensions (L x W x H), 26.23 x 7.68 x 4.40 cm (10.33 x ... Samsung Thai Engineer การรถไฟ วิทยาลัยนานาชาติ มหาวิทยาลัยมหิดล สถาบัน ...',
#   'website': 'MacroCare'},
#  {'title': '🩷For rent 🩷Condo for rent Modiz Rhyme Ramkamheng, ...',
#   'link': 'https://www.livinginsider.com/livingdetail_en/2203797/%F0%9F%A9%B7For-rent-%F0%9F%A9%B7Condo-for-rent-Modiz-Rhyme-Ramkamheng-Duplex-room-very-beautiful-ready-to-view-the-roo.html',
#   'description': 'THB 19,000.00',
#   'website': 'Livinginsider'},
#  {'title': 'MERC-1300W-P ตัวเพิ่มประสิทธิภาพพลังงาน Huawei Smart PV ...',
#   'link': 'https://insidersystem.co.th/product/merc-1300w-p-%E0%B8%95%E0%B8%B1%E0%B8%A7%E0%B9%80%E0%B8%9E%E0%B8%B4%E0%B9%88%E0%B8%A1%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%9E/',
#   'description': '2024. 5. 30. — Samsung (1). Intercom (11). Hikvision (11). Apartment Outdoor Station (4) ... 1.0 kg (2.2 lb.) Installation part (optional), PV Module Frame Plate/T-shaped ...',
#   'website': 'insidersystem.co.th'},
#  {'title': 'รวมประกาศเช่าคอนโดกรุงเทพและทั่วประเทศ',
#   'link': 'https://zmyhome.com/rent/condo',
#   'description': '2024. 9. 3. — ... Samsung Inverter - ไมโครเวฟ Samsung - เครื่องกรองน้ำ Mizuma ระบบ Reverse ... เครื่องซักผ้า Electrolux 9 kg 4. TV Panasonic 55 นิ้ว 5. ไมโครเวฟ 6.โซฟา 7 ...',
#   'website': 'ZmyHome.com'},
#  {'title': 'เครื่องพิมพ์มัลติฟังก์ชันอิงค์แท็งก์ Brother DCP-T520W',
#   'link': 'https://www.smart-smc.com/Printer_Und_ink_Und_tank_Und_Brother_Und_DCP-T520Witoplanding/5931455c948e6500015bf57a/595077946920f900018ad38e/Products_607d01931af952001224cf2c/5934f9a6948e6500015c0e0e',
#   'description': '2024. 8. 30. — Samsung · Ricoh · ปริ้นเตอร์อิงค์เจ็ท · Brother · Canon · HP · Epson · หมึกพิมพ์ ... Net Weight 7.30 KG • รับประกันออนไลน์จาก Brother 2 ปี หรือ 30,000แผ่น ขึ้น ...',
#   'website': 'smart-smc.com'},
#  {'title': 'UPS 1000VA VERTIV PSA1000-SOHO',
#   'link': 'https://itexpo.advice.co.th/product/ups-%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B8%AA%E0%B8%B3%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%84%E0%B8%9F-/vertiv/ups-1000va-vertiv-psa1000-soho',
#   'description': '2024. 7. 9. — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 13.20 KG. Package Dimension, (W x D x H) : 12.70 x 38.50 x 28.00 cm. Gross ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'MERC-1100W-P ตัวเพิ่มประสิทธิภาพพลังงาน Huawei Smart PV ...',
#   'link': 'https://insidersystem.co.th/product/merc-1100w-p-%E0%B8%95%E0%B8%B1%E0%B8%A7%E0%B9%80%E0%B8%9E%E0%B8%B4%E0%B9%88%E0%B8%A1%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%9E/',
#   'description': '2024. 5. 30. — Samsung (1). Intercom (11). Hikvision (11). Apartment Outdoor Station (4) ... 1.0 kg (2.2 lb.) Installation part (optional), PV Module Frame Plate/T-shaped ...',
#   'website': 'insidersystem.co.th'},
#  {'title': "UPS 1000VA 'SYNDOME' ECO ll 1000i",
#   'link': 'https://itexpo.advice.co.th/product/ups-%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B8%AA%E0%B8%B3%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%84%E0%B8%9F-/syndome/ups-1000va-syndome-eco-ii-1000i',
#   'description': '2024. 7. 10. — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 4.50 KG. Package Dimension, (W x D x H) : 15.00 x 33.00 x 20.00 cm. Gross ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'Griffin-Unlocker',
#   'link': 'https://www.facebook.com/photo.php?fbid=439217445538675&id=100083512682681&set=a.122341517226271&locale=th_TH',
#   'description': '2024. 6. 28. — Griffin-Unlocker Released V2024.06.10 Released =====================> ✓ Add New QUALCOMM SAMSUNG MODELS AND PATCH LEVELS ✓ Improved SAMSUNG KG To...',
#   'website': 'Facebook'},
#  {'title': 'AI, ML, DL, and the Growing Relevance of AI PCs',
#   'link': 'https://www.coolermaster.com/th-th/guide-and-resources/ai-pc/',
#   'description': '2024. 7. 1. — One of the main reasons behind the rising interest in AI PC aligns with why companies like Apple, Spotify, Samsung ... kg (5.5 lbs) due to the additional cooling ...',
#   'website': 'Cooler Master'},
#  {'title': 'Nanoleaf Outdoor String Lights | RGBWIC Smart LED Bulbs',
#   'link': 'https://nanoleaf.me/en-TH/products/essentials/outdoor/multicolor-string-lights/',
#   'description': '2024. 5. 9. — 15m Smarter Kit: 3.16kg 30m Smarter Kit: 6.09kg 15m Expansion Pack: 2.93 ... Sold Out! matter; apple-home; google-home; samsung-smartthings; alexa. Elevate ...',
#   'website': 'Nanoleaf'},
#  {'title': 'ThinkPad T14s Gen 5 (14″ Intel)',
#   'link': 'https://www.lenovo.com/th/en/p/laptops/thinkpad/thinkpadt/lenovo-thinkpad-t14s-gen-5-(14-inch-intel)/len101t0092?srsltid=AfmBOoozVQvJQnDImcuTQV4IMPhj3pcpeKN9qUfyxCVPUKsJyw1TPASH',
#   'description': '4.4\n(9)',
#   'website': 'Lenovo'},
#  {'title': 'Smart Phone & Tablet',
#   'link': 'https://www.sisthai.com/sis/images/web_navi/EU%20PRICE/6D0022E9F16D0022E9F1smart%20phone&tablet_en_04_24.pdf',
#   'description': '2024. 4. 26. — Weight. 0.34 kg. 0.46 kg. 0.46 kg. Color. Arctic Grey. Gray. Gray. Warranty. 1 Year ... Samsung Galaxy Xcover 7 EE 5G. Samsung Galaxy Xcover 6 Pro EE 5G. SSG ...',
#   'website': 'SiS Distribution (Thailand)'},
#  {'title': 'SMIGGLE | Cool stationery & accessories for Kids from ...',
#   'link': 'https://www.central.co.th/en/smiggle',
#   'description': '7일 전 — and weight not exceeding 5 kg. To avoid keeping you waiting, we may send ... SAMSUNG, APPLE, NINTENDO, LENOVO, SONY. :: Gift card. :: Home Applicance ...',
#   'website': 'Central Online'},
#  {'title': 'TS-632X | Cost-effective 6-bay 10GbE NAS, designed to ...',
#   'link': 'https://www.qnap.com/th-th/product/ts-632x',
#   'description': '2024. 7. 8. — Volume type：6 x Samsung 860 PRO 512GB, RAID 5, thick volume. Client PC ... Weight: 0.29 (kg). Please check the M.2 SSD compatibility list and QM2 ...',
#   'website': 'QNAP'},
#  {'title': 'L eg3nd Elite',
#   'link': 'https://www.aquamaster.net/wp-content/uploads/2024/09/Catalogue-09-2024-price-update.pdf',
#   'description': '2024. 9. 4. — All sizes are capable of holding up to 30 lbs / 13.5 kg of lead weight. • Optional accessories include the Airsource, Squeeze lock knife and reflector kit. The ...',
#   'website': 'Aquamaster Thailand'},
#  {'title': 'NOTEBOOK (โน้ตบุ๊ค) DELL XPS 16 9640- ...',
#   'link': 'https://www.jib.co.th/web/product/readProduct/67692/NOTEBOOK--%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84--DELL-XPS-16-9640-CXN9640CTO02GTH--PLATINUM-',
#   'description': '2024. 5. 31. — Samsung · Skyworth · Viewsonic · Xiaomi · Zowie · ขาตั้งจอ · Ergonoz · Ergotrend · Anda ... 4.1 kg. Dimension (W/H/D). 466 x 365 x 110 mm. รายละเอียดสินค้า.',
#   'website': 'JIB'},
#  {'title': 'กลับมาอีกครั้งกับโปรโมชั่นสุดร้อนแรง เก่าแลกใหม่ Key master ...',
#   'link': 'https://pollert.com/product/trade-in-key-master-dp-new-key-master-g3-key-programmer-2024/',
#   'description': '2024. 7. 10. — ... Samsung QM6SM6 models. 8. Paid software activation service for Cluster ... 1.5kg (main unit). Dimension, 254mm*174mm*35mm, 270.5mm*165mm*39mm. Functions ...',
#   'website': 'อุตสาหกรรมผลเลิศ'},
#  {'title': 'NOTEBOOK (โน้ตบุ๊ค) MSI SWORD 16 HX B14VGKG- ...',
#   'link': 'https://www.jib.co.th/web/product/readProduct/67620',
#   'description': '2024. 6. 7. — Samsung · Skyworth · Viewsonic · Xiaomi · Zowie · ขาตั้งจอ · Ergonoz · Ergotrend · Anda Seat ... 2.3 kg. color. Gray. Additional. Microsoft Office Home and Student ...',
#   'website': 'JIB'},
#  {'title': 'New Key Master G3 Key Programmer 2024 for Car/ HD',
#   'link': 'https://pollert.com/product/new-key-master-g3-key-programmer-2024/',
#   'description': 'THB 14,500.00 ~ THB 52,800.00',
#   'website': 'อุตสาหกรรมผลเลิศ'},
#  {'title': 'Chiang Mai Old City Laundry',
#   'link': 'https://www.chiangmailaundry.com/chiang-mai-old-city-laundry',
#   'description': '8일 전 — Are You Tired Of 1 Kg Coffee Beans? 10 Inspirational Ideas To Revive Your ... Samsung Galaxy, OnePlus, Xiaomi, iPhone, iPad. 메이저사이트 순위 says ...',
#   'website': ''},
#  {'title': 'Absen LED Wall CPS Series P2.5 (Indoor)',
#   'link': 'https://www.projector.co.th/h-product-screen/absen-ledwall-cps-series-p25-indoor.html?srsltid=AfmBOoq11MPXbBb8x3qAPSuJh4PkBTuqFCK-GtoZOIAxdLFV6S1wh6Iw',
#   'description': '2024. 7. 26. — Samsung · Sony · ViewSonic · VERTEX · Viewsonic · VIVITEK · InterActive · Short Throw ... Cabinet Weight : 1.75 Kg. รับประกัน 1 ปี Onsite Service. SKU, Absen LED ...',
#   'website': 'Projector Outlet'},
#  {'title': 'NOTEBOOK (โน้ตบุ๊ค) Acer Aspire Go AG15-31P-30EJ Pure ...',
#   'link': 'https://www.thaimartonline.com/product/218276-222796/notebook-%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-acer-aspire-go-ag15-31p-30ej-pure-silver',
#   'description': '2024. 4. 30. — THAIMART EXPO 2024 · Thaimart Solar cell · รวมเครื่องเย็นตู้เย็นตู้แช่ · SAMSUNG TV FINANCE PLUS ... Net Weight : 1.7 KG; Warranty : 2 Year By Acer. Acer Aspire Go AG15- ...',
#   'website': 'thaimartonline.com'},
#  {'title': 'UsurfaceⅣ',
#   'link': 'http://www.iodigitech.com/category/214/led-display/unilumin/dooh-creative/usurface%E2%85%B3',
#   'description': '2024. 9. 2. — Unlock Ultimate Energy-saving ExperienceUsurfaceIV4/UsurfaceIV6/UsurfaceIV8/UsurfaceIV10 33.5kg/㎡, Die-casting aluminum Immersive Viewing Experience E ...  ...',
#   'website': 'iodigitech'},
#  {'title': 'สมาร์ทโฟน Xiaomi Redmi Note 13 Pro+ 5G (8/256GB)',
#   'link': 'https://www.wpnmobile.com/product/48918-68210/%E0%B8%AA%E0%B8%A1%E0%B8%B2%E0%B8%A3%E0%B9%8C%E0%B8%97%E0%B9%82%E0%B8%9F%E0%B8%99-xiaomi-redmi-note-13-pro-5g-ram-8gb-rom-256gb',
#   'description': 'THB 13,990.00',
#   'website': 'wpnmobile.com'},
#  {'title': 'ZTE Nubia Music (4+128GB) Zeel Orange',
#   'link': 'https://itexpo.advice.co.th/product/smartphone/smartphone-zte/zte-nubia-music-4plus128gb-zeel-orange',
#   'description': '2024. 7. 11. — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 0.19 KG. Package Dimension, (W x D x H) : 8.80 x 18.00 x 5.40 cm. Gross Weight ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'Adata RAM SODIMM 8 GB DDR4/3200 16Chip แรมโน้ตบุ๊ค ...',
#   'link': 'https://techwarehouse.co.th/product/adata-ram-sodimm-8-gb-ddr4-3200-16chip-%E0%B9%81%E0%B8%A3%E0%B8%A1%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B9%81%E0%B8%97%E0%B9%89/',
#   'description': '2024. 7. 24. — Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic ... Gross Weight 0.03 KG. เงื่อนไขการรับประกัน. 1.หากสินค้ามี ...',
#   'website': 'TechWarehouse.co.th'},
#  {'title': 'Adata RAM SODIMM 32 GB DDR4/3200 16Chip แรมโน้ตบุ๊ค ...',
#   'link': 'https://techwarehouse.co.th/product/adata-ram-sodimm-32-gb-ddr4-3200-16chip-%E0%B9%81%E0%B8%A3%E0%B8%A1%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B9%81%E0%B8%97%E0%B9%89/',
#   'description': '2024. 7. 25. — Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic ... Gross Weight 0.05 KG. เงื่อนไขการรับประกัน. 1.หากสินค้ามี ...',
#   'website': 'TechWarehouse.co.th'},
#  {'title': 'สมาชิก ลูกศิษย์ เพื่อนครู พระคุณเจ้า มาเยี่ยมเยือนที่บ้าน, เที่ยว ...',
#   'link': 'https://www.mahamodo.com/webmaster_special/yymmdd_text/25540520.aspx?id=55',
#   'description': '2024. 10. 1. — ... Kg ใช้แบตเตอรี่ 12 V. 4 ลูก ใช้สายพานฉุดมูเล่ย์เคลื่อนที่ (ใช้โซ่จะมีเสียง ... samsung xpress m2020 wireless setup https://www.skijanje.hr/hr/skijanje ...',
#   'website': ''},
#  {'title': 'ราคา เครื่องเสียง Onkyo โฮมเธียเตอร์',
#   'link': 'https://www.priceza.com/s/%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%AA%E0%B8%B5%E0%B8%A2%E0%B8%87-onkyo-%E0%B9%82%E0%B8%AE%E0%B8%A1%E0%B9%80%E0%B8%98%E0%B8%B5%E0%B8%A2%E0%B9%80%E0%B8%95%E0%B8%AD%E0%B8%A3%E0%B9%8C',
#   'description': '6일 전 — ... kg SPEAKER SPECIFICATIONS Speaker Type (Front) 2-Way bass-reflex, 12 cm ... ชุดโฮมเธียเตอร์jvc ชุดเครื่องเสียง Sony ชุดโฮมเธียเตอร์ Sony ชุดโฮมเธียเตอร์ Yamaha Samsung ...',
#   'website': 'Priceza'},
#  {'title': 'Nuc Celeron เช็คราคาล่าสุด ราคาถูก ราคาปัจจุบัน',
#   'link': 'https://www.priceza.com/s/%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/nuc-celeron',
#   'description': '4일 전 — ... KG Package Dimension (W x D x H) : 17.50 x 16.50 x 10.00 cm Gross ... Rtx 3060 การ์ดจอมือสอง Rtx 3060 Notebook Samsung Gtx 1070 Gtx 1050 Gtx 1080 ...',
#   'website': 'Priceza'},
#  {'title': 'Public Girls Sen. Sec.School Old Rajpura',
#   'link': 'https://www.facebook.com/groups/1067172696657946/?locale=th_TH',
#   'description': "2024. 9. 28. — ... Samsung #Phone A51 & A71 with Rs.700/- & 11 #EMI's on Bajaj Finserv Card ... Web Designing | #PHP | HR | Marketing | Finance | #Digital_Marketing | SEO/SMO | ...",
#   'website': 'Facebook'},
#  {'title': 'XdA-YeMeN-DeVeLoPerS | السلام عليكم',
#   'link': 'https://m.facebook.com/groups/XdAYeMeN/permalink/2411811712191519/?locale=th_TH',
#   'description': '2024. 9. 4. — Remove Samsung FRP Galaxy A02s Model: SM-A025U BIT1 ... Finance Plus. อาจเป็นรูปภาพของ ข้อความ.',
#   'website': ''}]

# %%
for link in google_links:
    try:
        if(detect(link["description"])!= 'en'):
            original = link["description"]
            translate = translate_using_google(original)
            link["description"] = "Translate by API: " + translate + "\nOriginal: " + original
    except:
        pass
    try:
        if(detect(link["title"])!= 'en'):
            original = link["title"]
            translate = translate_using_google(original)
            link["title"] = "Translate by API: " + translate + "\nOriginal: " + original
    except:
        pass
# Out:
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.mymemory.translated.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
google_links
# Out:
# [{'title': 'Clean IMEI',
#   'link': 'https://www.facebook.com/phonereform/?locale=th_TH',
#   'description': '5 thg 7, 2024 — Samsung #kg Removal. CLEANIMEI.COM. Samsung KG (Knox Guard) Lock Removal Service ... for Samsung Unlock, Samsung IMEI Repair, and. Samsung FRP services ...',
#   'website': 'Facebook'},
#  {'title': 'T-Tool Team',
#   'link': 'https://www.facebook.com/photo.php?fbid=2938584213119832&id=2027539344224328&set=a.2036003380044591&locale=th_TH',
#   'description': '8 thg 7, 2024 — ... samsung knox Guard (KG) status (4 cases) ✔️KG Prenormal ✔️KG Locked ✔️KG Completed ✔️KG Checking Wipe userdata & Reset UserLocks [7 Methods] ✔️ ...',
#   'website': 'Facebook'},
#  {'title': 'Translate by API: Unlock True Center Pro Phone\nOriginal: ปลดล็อคโทรศัพท์ติดโปรศูนย์ทรู',
#   'link': 'https://pantip.com/topic/39500035/desktop',
#   'description': 'Translate by API: 1 ngày trảc — Samsung Galaxy A50 Samsung... bought a second tool, J6. When it turns on, it appears that the device will lock if the service fee is not paid (probably the monthly number of the original owner). Find out if it is the current system...\nOriginal: 1 ngày trước — Samsung Galaxy A50 Samsung ... ซื้อเครื่องมือสองมา J6+ พอเปิดเครื่องมันขึ้นว่าเครื่องจะล็อคหากไม่มีการชำระค่าบริการ (น่าจะเบอร์รายเดือนของเจ้าของเดิม) หาข้อมูลบอกว่าเป็นระบบ ปัจจุบัน ...',
#   'website': 'Pantip'},
#  {'title': 'Translate by API: GSM WORLDWIDE\nOriginal: GSM WORLDWIDE',
#   'link': 'https://www.facebook.com/groups/1445374475482583/?locale=th_TH',
#   'description': '28 thg 6, 2024 — ✡️SAMSUNG A245F KG MDM UNLOCK DONE✓ ✡️SEND YOUR ORDER INBOX REMOTELY WORK ========================================== @highlight #highlights2024',
#   'website': 'Facebook'},
#  {'title': 'eMMC-UFS VIP✔️✔️ Easy Jtag Mipi tester Medusa pro Ufi',
#   'link': 'https://www.facebook.com/groups/eloygc/?locale=th_TH',
#   'description': 'Translate by API: PLEASE SELECT TWO DISTINCT LANGUAGES\nOriginal: 15 thg 9, 2024 — ... MDM Sin Relock ✓Xiaomi Admin de Ti ✓Método MDM ... **✓ 2° Semana: Pandora Tool y Samsung** - Desbloqueo Unisoc y MTK, Seguridades Samsung, iPhone Bypass.',
#   'website': 'Facebook'},
#  {'title': 'Translate by API: Blognone | IT news, mobile technology, games, security, open...\nOriginal: Blognone | ข่าวไอที เทคโนโลยี มือถือ เกม ความปลอดภัย โอเพน ...',
#   'link': 'https://www.blognone.com/node?page=47&k=man%20sucking%20shemale%20cock',
#   'description': 'Translate by API: 6 thg 8, 2024 — Samsung starts the main line 12GB LPDDR5X RAM and 16GB at a thin 0.65 mm... MDM. Node Thumbnail. The server of the company Mobile Guardian, a mobile device provider...\nOriginal: 6 thg 8, 2024 — Samsung เริ่มสายการผลิตหลักแรม LPDDR5X 12GB และ 16GB ที่บาง 0.65 มิลลิเมตร ... MDM. Node Thumbnail. เซิร์ฟเวอร์ของบริษัท Mobile Guardian ผู้ให้บริการ mobile device ...',
#   'website': 'Blognone'},
#  {'title': 'Translate by API: Article Directory\nOriginal: ไดเรกทอรีบทความ',
#   'link': 'https://th.linkedin.com/directory/articles',
#   'description': "Translate by API: 31 thg 5, 2024 — Vulnerabilities in Samsung phones are added to CISA's Must Patch list due to... Master Data management (MDM) · Resignation and data statistics that HR should know...\nOriginal: 31 thg 5, 2024 — ช่องโหว่ในโทรศัพท์ Samsung ถูกเพิ่มในรายการ Must Patch ของ CISA เนื่องจากการ ... Master Data management (MDM) · การ “ลาออก” กับดาต้า สถิติที่ HR ควรรู้ ...",
#   'website': 'LinkedIn'},
#  {'title': 'GSM Crack King',
#   'link': 'https://www.facebook.com/gsm.crack.king/?locale=th_TH',
#   'description': '5 ngày trước — ... MDM Android 14 ✅️MTP Bypass ✅️BROM FRP ✅️MTK Brom Bypass · อาจเป็นรูปภาพ ... BFF Sam Frp Tool V1 ( Beta ) Samsung Frp Unlock Tool Latest Updated ...',
#   'website': 'Facebook'},
#  {'title': 'Unlock Tool Crack Free',
#   'link': 'https://www.facebook.com/groups/unlocktoolscracks/?locale=th_TH',
#   'description': '8 thg 10, 2024 — TFT Unlock Tools 2024 V3.3.0.0 UnlockTool Free ⚡Samsung⚡ Huawei ⚡Update⚡ Downgrade ⚡MDM REMOVE⚡ Reset FRP Download https://www.aligsmlab.com/2024/03/TFT-  ...',
#   'website': 'Facebook'},
#  {'title': 'Easyfixunlocker',
#   'link': 'https://www.facebook.com/nasujon76/?locale=th_TH',
#   'description': '24 thg 7, 2024 — samsung A127F U1-U9 MDM/Knox Unlock File Available paid file whatsapp:+8801836969376 telegram;https://t.me/+n_uqKZW5hig5YWNl ...',
#   'website': 'Facebook'},
#  {'title': 'A Nam Unlock Phone',
#   'link': 'https://www.facebook.com/anamunlockphone/?locale=th_TH',
#   'description': '29 thg 6, 2024 — + Bypass frp all smartphone android chip MTK Qualcomm all smartphone vi teamviewer ver 6.x 7.x 8.x 9 + Fixing “Please Call Me” and MDM policy: Samsung ...',
#   'website': 'Facebook'},
#  {'title': 'Translate by API: Mobile Repair Program MDM FIXTOOL Activation 1 Year Delivery by...\nOriginal: โปรแกรมซ่อมมือถือ MDM FIXTOOL Activation 1ปี จัดส่งทางแช ...',
#   'link': 'https://www.lazada.co.th/products/mdm-fixtool-activation-1-i5330044126.html',
#   'description': '4.000,00 ฿',
#   'website': 'Lazada'},
#  {'title': 'Translate by API: FiX TecH CR Mobile Repair Chiang Rai Unlock Online Wholesale Parts...\nOriginal: FiX TecH CR ซ่อมมือถือเชียงราย ปลดล็อคออนไลน์ ขายส่งอะไหล่ ...',
#   'link': 'http://fixtechcr.lnwshop.com/',
#   'description': 'Translate by API: 6 ngày trảc — models that support monthly unlocks Samsung Finance, Samsung Grab, Samsung... free monthly❗❗ unlocks Note 10 Plus unpaid service charge N975F Bypass MDM No PC free❗❗\nOriginal: 6 ngày trước — รุ่นที่รองรับการปลดล็อครายเดือน Samsung Finance,Samsung Grab,Samsung ... ฟรี❗❗ ปลดล็อคเครื่องรายเดือน Note 10 Plus ค้างชำระค่าบริการ N975F Bypass MDM No PC FREE❗❗',
#   'website': 'LnwShop'},
#  {'title': 'Translate by API: Life Is Fun\nOriginal: Đời Thật Là Vui',
#   'link': 'https://www.facebook.com/DoiThatLaVui/?locale=th_TH',
#   'description': 'Translate by API: 4 days ago — ... Samsung.   Hack Camera installed in the house is the new game of Hackers.   Da Nang has ... kilograms and pieces for guests to bring home. Japanese pork to Vietnam, frozen goods...\nOriginal: 4 ngày trước — ... Samsung. + Hack Camera lắp trong nhà là thú săn mới của Hacker. + Đà Nẵng có ... kg chả miếng cho khách mang về. + Thịt lợn Nhật về Việt Nam, hàng đông ...',
#   'website': 'Facebook'},
#  {'title': 'Translate by API: Wine and Thais. Good things for wine lovers to know.\nOriginal: ไวน์กับคนไทย เรื่องดีๆที่คอไวน์ต้องรู้',
#   'link': 'https://www.wineyou.com/%E0%B8%84%E0%B8%AD%E0%B9%84%E0%B8%A7%E0%B8%99%E0%B9%8C%E0%B8%95%E0%B9%89%E0%B8%AD%E0%B8%87%E0%B8%A3%E0%B8%B9%E0%B9%89/%E0%B9%84%E0%B8%A7%E0%B8%99%E0%B9%8C%E0%B8%81%E0%B8%B1%E0%B8%9A%E0%B8%84%E0%B8%99%E0%B9%84%E0%B8%97%E0%B8%A2/',
#   'description': '28 thg 6, 2024 — planeta-alvi.es/carcasa-rigida-samsung-j5-2017-2629.html ... The weight of the parcel ehappynews.com can be up to 20 kg, and its format must correspond to the ...',
#   'website': 'wineyou.com'},
#  {'title': 'Translate by API: Apprentice members, fellow teachers, visiting at home, visiting...\nOriginal: สมาชิก ลูกศิษย์ เพื่อนครู พระคุณเจ้า มาเยี่ยมเยือนที่บ้าน, เที่ยว ...',
#   'link': 'https://www.mahamodo.com/webmaster_special/yymmdd_text/25540520.aspx?id=55',
#   'description': 'Translate by API: 1 thg 10, 2024 —... Kg uses 12 V. 4 batteries, use the moving mooley traction belt (use the chain to sound... samsung xpress m2020 wireless setup https://www.skijanje.hr/hr/skijanje...\nOriginal: 1 thg 10, 2024 — ... Kg ใช้แบตเตอรี่ 12 V. 4 ลูก ใช้สายพานฉุดมูเล่ย์เคลื่อนที่ (ใช้โซ่จะมีเสียง ... samsung xpress m2020 wireless setup https://www.skijanje.hr/hr/skijanje ...',
#   'website': ''},
#  {'title': 'Mobishop - SAMSUNG KG LOCKED PERMANENT REMOVE ...',
#   'link': 'https://www.facebook.com/photo.php?fbid=849046233890261&id=100063546758149&set=a.476205261174362&locale=th_TH',
#   'description': '4 thg 7, 2024 — SAMSUNG KG LOCKED PERMANENT REMOVE No Need Test Mode /Adb/Anything Just Connect Usb redirector with Mtp Mode instant. Services All Androids 8,9,10,11,12,13, ...',
#   'website': 'Facebook'},
#  {'title': 'UPS Zircon ZC-EP 30kVA 3:3p',
#   'link': 'https://modernsave.com/ups-/27262-ups-zircon-zc-ep-30kva-33p.html',
#   'description': '19 thg 6, 2024 — SAMSUNG · SKD · SteelSeries · Syndome · Synology · TP-LINK · Ubiquiti · Unitec · Vertex ... Shipping weight (kg), 371. Standards, Safety, IEC/EN62040-1,IEC/ ...',
#   'website': 'Modernsave'},
#  {'title': '🩷For rent 🩷Condo for rent Modiz Rhyme Ramkamheng, ...',
#   'link': 'https://www.livinginsider.com/livingdetail_en/2203797/%F0%9F%A9%B7For-rent-%F0%9F%A9%B7Condo-for-rent-Modiz-Rhyme-Ramkamheng-Duplex-room-very-beautiful-ready-to-view-the-roo.html',
#   'description': '19.000,00 ฿',
#   'website': 'Livinginsider'},
#  {'title': 'Translate by API: Panasonic Lumix GH7-BIGCamera: a digital camera hub with...\nOriginal: Panasonic Lumix GH7 - BIGCamera : ศูนย์รวมกล้องดิจิตอลที่มี ...',
#   'link': 'https://www.bigcamera.co.th/panasonic-lumix-gh7?srsltid=AfmBOorijn_VpX2mj__NpNtpDb73mWSIUf-a07TYGVyGQQwgxUhzJx-5',
#   'description': 'Translate by API: 75,991.00 ฿ · Out of stock\nOriginal: 75.991,00 ฿ · Hết hàng',
#   'website': 'bigcamera.co.th'},
#  {'title': 'Translate by API: กล้อง Lumix G Mirrorless DC-GH7GA\nOriginal: กล้อง Lumix G Mirrorless DC-GH7GA',
#   'link': 'https://www.panasonic.com/th/consumer/camera-camcorder/lumix-g-camera/lumix-g-mirrorless-camera/dc-gh7ga.html',
#   'description': '79.990,00 ฿',
#   'website': 'Panasonic'},
#  {'title': 'Translate by API: UPS 1000VA VERTIV PSA1000-SOHO\nOriginal: UPS 1000VA VERTIV PSA1000-SOHO',
#   'link': 'https://itexpo.advice.co.th/product/ups-%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B8%AA%E0%B8%B3%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%84%E0%B8%9F-/vertiv/ups-1000va-vertiv-psa1000-soho',
#   'description': '9 thg 7, 2024 — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 13.20 KG. Package Dimension, (W x D x H) : 12.70 x 38.50 x 28.00 cm. Gross ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'ATEN 4 Port HDMI/USB KVM Switch with USB2.0 and Audio',
#   'link': 'https://www.mc.co.th/eshop/4-port-hdmi-kvm-switch/2932-4-port-usb-hdmiaudio-kvm-switch-with-usb20-and-audio.html',
#   'description': 'Translate by API: 3 ngày trảc — 0.53 kg (1.17 lb). Dimensions (L x W x H), 26.23 x 7.68 x 4.40 cm (10.33 x... Samsung Thai Engineer, Railway, International College, Mahidol University, Institute of...\nOriginal: 3 ngày trước — 0.53 kg ( 1.17 lb ). Dimensions (L x W x H), 26.23 x 7.68 x 4.40 cm (10.33 x ... Samsung Thai Engineer การรถไฟ วิทยาลัยนานาชาติ มหาวิทยาลัยมหิดล สถาบัน ...',
#   'website': 'MacroCare'},
#  {'title': 'Translate by API: Action Plan for Fiscal Year 2023\nOriginal: แผนปฏิบัติการ ประจำปีงบประมาณ 2566',
#   'link': 'https://srth.go.th/news/MyResize/9srthplain.pdf',
#   'description': 'Translate by API: 28 thg 6, 2024-... kg. 60.00. 120.00. 58 Secondary and Tertiary Welfare Group. Numbered device... Samsung model MLT-3310ND. 376 cartridges. 390.00. 146,640.00. 47 mission group side Ah...\nOriginal: 28 thg 6, 2024 — ... kg. 60.00. 120.00. 58 กลุ่มภำรกิจด้ำนบริกำรทุติยภูมิและตติยภูมิ. งำนกำยอุปกรณ์ ... Samsung รุ่น MLT-3310ND. 376 ตลับ. 390.00. 146,640.00. 47 กลุ่มภารกิจด้านอ้า ...',
#   'website': ''},
#  {'title': 'Translate by API: MERC-1300W-P Huawei Smart PV Power Optimizer...\nOriginal: MERC-1300W-P ตัวเพิ่มประสิทธิภาพพลังงาน Huawei Smart PV ...',
#   'link': 'https://insidersystem.co.th/product/merc-1300w-p-%E0%B8%95%E0%B8%B1%E0%B8%A7%E0%B9%80%E0%B8%9E%E0%B8%B4%E0%B9%88%E0%B8%A1%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%9E/',
#   'description': '30 thg 5, 2024 — Samsung (1). Intercom (11). Hikvision (11). Apartment Outdoor Station (4) ... 1.0 kg (2.2 lb.) Installation part (optional), PV Module Frame Plate/T-shaped ...',
#   'website': 'insidersystem.co.th'},
#  {'title': 'Translate by API: Brother DCP-T520W Ink Tank Multifunction Printer\nOriginal: เครื่องพิมพ์มัลติฟังก์ชันอิงค์แท็งก์ Brother DCP-T520W',
#   'link': 'https://www.smart-smc.com/Printer_Und_ink_Und_tank_Und_Brother_Und_DCP-T520Witoplanding/5931455c948e6500015bf57a/595077946920f900018ad38e/Products_607d01931af952001224cf2c/5934f9a6948e6500015c0e0e',
#   'description': 'Translate by API: 30 thg 8, 2024 — Samsung · Ricoh · Printer Inkjet · Brother · Canon · HP · Epson · Printer Ink... Net Weight 7.30 KG • Online warranty from Brother 2 years or 30,000 sheets more...\nOriginal: 30 thg 8, 2024 — Samsung · Ricoh · ปริ้นเตอร์อิงค์เจ็ท · Brother · Canon · HP · Epson · หมึกพิมพ์ ... Net Weight 7.30 KG • รับประกันออนไลน์จาก Brother 2 ปี หรือ 30,000แผ่น ขึ้น ...',
#   'website': 'smart-smc.com'},
#  {'title': 'Translate by API: MERC-1100W-P Huawei Smart PV Power Optimizer...\nOriginal: MERC-1100W-P ตัวเพิ่มประสิทธิภาพพลังงาน Huawei Smart PV ...',
#   'link': 'https://insidersystem.co.th/product/merc-1100w-p-%E0%B8%95%E0%B8%B1%E0%B8%A7%E0%B9%80%E0%B8%9E%E0%B8%B4%E0%B9%88%E0%B8%A1%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%9E/',
#   'description': '30 thg 5, 2024 — Samsung (1). Intercom (11). Hikvision (11). Apartment Outdoor Station (4) ... 1.0 kg (2.2 lb.) Installation part (optional), PV Module Frame Plate/T-shaped ...',
#   'website': 'insidersystem.co.th'},
#  {'title': "Translate by API: UPS 1000VA 'SYNDOME' ECO ll 1000i\nOriginal: UPS 1000VA 'SYNDOME' ECO ll 1000i",
#   'link': 'https://itexpo.advice.co.th/product/ups-%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B8%AA%E0%B8%B3%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%84%E0%B8%9F-/syndome/ups-1000va-syndome-eco-ii-1000i',
#   'description': '10 thg 7, 2024 — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 4.50 KG. Package Dimension, (W x D x H) : 15.00 x 33.00 x 20.00 cm. Gross ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'SMIGGLE | Cool stationery & accessories for Kids from ...',
#   'link': 'https://www.central.co.th/en/smiggle',
#   'description': '6 ngày trước — and weight not exceeding 5 kg. To avoid keeping you waiting, we may send ... SAMSUNG, APPLE, NINTENDO, LENOVO, SONY. :: Gift card. :: Home Applicance ...',
#   'website': 'Central Online'},
#  {'title': 'Translate by API: Come back again with an old hot promotion. Redeem Key master...\nOriginal: กลับมาอีกครั้งกับโปรโมชั่นสุดร้อนแรง เก่าแลกใหม่ Key master ...',
#   'link': 'https://pollert.com/product/trade-in-key-master-dp-new-key-master-g3-key-programmer-2024/',
#   'description': '10 thg 7, 2024 — ... Samsung QM6SM6 models. 8. Paid software activation service for Cluster ... 1.5kg (main unit). Dimension, 254mm*174mm*35mm, 270.5mm*165mm*39mm. Functions ...',
#   'website': 'อุตสาหกรรมผลเลิศ'},
#  {'title': 'Translate by API: Notebook (notebook) dell XPS 16 9640 -...\nOriginal: NOTEBOOK (โน้ตบุ๊ค) DELL XPS 16 9640- ...',
#   'link': 'https://www.jib.co.th/web/product/readProduct/67692/NOTEBOOK--%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84--DELL-XPS-16-9640-CXN9640CTO02GTH--PLATINUM-',
#   'description': 'Translate by API: PLEASE SELECT TWO DISTINCT LANGUAGES\nOriginal: 31 thg 5, 2024 — Samsung · Skyworth · Viewsonic · Xiaomi · Zowie · ขาตั้งจอ · Ergonoz · Ergotrend · Anda ... 4.1 kg. Dimension (W/H/D). 466 x 365 x 110 mm. รายละเอียดสินค้า.',
#   'website': 'JIB'},
#  {'title': 'New Key Master G3 Key Programmer 2024 for Car/ HD',
#   'link': 'https://pollert.com/product/new-key-master-g3-key-programmer-2024/',
#   'description': '14.500,00 ฿ - 52.800,00 ฿',
#   'website': 'อุตสาหกรรมผลเลิศ'},
#  {'title': 'Chiang Mai Old City Laundry',
#   'link': 'https://www.chiangmailaundry.com/chiang-mai-old-city-laundry',
#   'description': '7 ngày trước — Are You Tired Of 1 Kg Coffee Beans? 10 Inspirational Ideas To Revive Your ... Samsung Galaxy, OnePlus, Xiaomi, iPhone, iPad. 메이저사이트 순위 says ...',
#   'website': ''},
#  {'title': 'Translate by API: Absen led Wall CPS Series P2.5 (Indoor)\nOriginal: Absen LED Wall CPS Series P2.5 (Indoor)',
#   'link': 'https://www.projector.co.th/h-product-screen/absen-ledwall-cps-series-p25-indoor.html?srsltid=AfmBOop9E8Wrg35Tm6hcp_kxWguRYf_euGRHOVWoaA1IUPfb7X4pSC8w',
#   'description': '26 thg 7, 2024 — Samsung · Sony · ViewSonic · VERTEX · Viewsonic · VIVITEK · InterActive · Short Throw ... Cabinet Weight : 1.75 Kg. รับประกัน 1 ปี Onsite Service. SKU, Absen LED ...',
#   'website': 'Projector Outlet'},
#  {'title': 'NOTEBOOK (โน้ตบุ๊ค) Acer Aspire Go AG15-31P-30EJ Pure ...',
#   'link': 'https://www.thaimartonline.com/product/218276-222796/notebook-%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-acer-aspire-go-ag15-31p-30ej-pure-silver',
#   'description': '30 thg 4, 2024 — THAIMART EXPO 2024 · Thaimart Solar cell · รวมเครื่องเย็นตู้เย็นตู้แช่ · SAMSUNG TV FINANCE PLUS ... Net Weight : 1.7 KG; Warranty : 2 Year By Acer. Acer Aspire Go AG15- ...',
#   'website': 'thaimartonline.com'},
#  {'title': 'Translate by API: USURFACE\nOriginal: UsurfaceⅣ',
#   'link': 'http://www.iodigitech.com/category/214/led-display/unilumin/dooh-creative/usurface%E2%85%B3',
#   'description': '2 thg 9, 2024 — Unlock Ultimate Energy-saving ExperienceUsurfaceIV4/UsurfaceIV6/UsurfaceIV8/UsurfaceIV10 33.5kg/㎡, Die-casting aluminum Immersive Viewing Experience E ...  ...',
#   'website': 'iodigitech'},
#  {'title': 'Translate by API: สมาร์ทโฟน Xiaomi Redmi Note 13 Pro  5G (8/256GB)\nOriginal: สมาร์ทโฟน Xiaomi Redmi Note 13 Pro+ 5G (8/256GB)',
#   'link': 'https://www.wpnmobile.com/product/48918-68210/%E0%B8%AA%E0%B8%A1%E0%B8%B2%E0%B8%A3%E0%B9%8C%E0%B8%97%E0%B9%82%E0%B8%9F%E0%B8%99-xiaomi-redmi-note-13-pro-5g-ram-8gb-rom-256gb',
#   'description': '13.990,00 ฿',
#   'website': 'wpnmobile.com'},
#  {'title': 'Translate by API: ZTE Nubia Music (4 128GB) Pop Art\nOriginal: ZTE Nubia Music (4+128GB) Pop Art',
#   'link': 'https://itexpo.advice.co.th/product/smartphone/smartphone-zte/zte-nubia-music-4plus128gb-pop-art',
#   'description': '11 thg 7, 2024 — SAMSUNG Smart Watch · Remax Smart Watch. SMART LIFE & IOT. ย้อนกลับ; Smart ... 0.19 KG. Package Dimension, (W x D x H) : 8.80 x 18.00 x 5.40 cm. Gross Weight ...',
#   'website': 'Advice IT Expo'},
#  {'title': 'Translate by API: Adata RAM SODIMM 8 GB DDR4/3200 16Chip Notebook RAM...\nOriginal: Adata RAM SODIMM 8 GB DDR4/3200 16Chip แรมโน้ตบุ๊ค ...',
#   'link': 'https://techwarehouse.co.th/product/adata-ram-sodimm-8-gb-ddr4-3200-16chip-%E0%B9%81%E0%B8%A3%E0%B8%A1%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B9%81%E0%B8%97%E0%B9%89/',
#   'description': 'Translate by API: 24 thg 7, 2024-Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic... Gross Weight 0.03 KG. Warranty terms. 1.If the product has...\nOriginal: 24 thg 7, 2024 — Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic ... Gross Weight 0.03 KG. เงื่อนไขการรับประกัน. 1.หากสินค้ามี ...',
#   'website': 'TechWarehouse.co.th'},
#  {'title': 'Translate by API: Adata RAM SODIMM 32 GB DDR4/3200 16Chip Notebook RAM...\nOriginal: Adata RAM SODIMM 32 GB DDR4/3200 16Chip แรมโน้ตบุ๊ค ...',
#   'link': 'https://techwarehouse.co.th/product/adata-ram-sodimm-32-gb-ddr4-3200-16chip-%E0%B9%81%E0%B8%A3%E0%B8%A1%E0%B9%82%E0%B8%99%E0%B9%89%E0%B8%95%E0%B8%9A%E0%B8%B8%E0%B9%8A%E0%B8%84-%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B9%81%E0%B8%97%E0%B9%89/',
#   'description': 'Translate by API: 25 thg 7, 2024 — Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic... Gross Weight 0.05 KG.เงื่อนไขการรับประกัน. 1.หากสินค้ามี...\nOriginal: 25 thg 7, 2024 — Samsung (59), SanDisk (205), Scotch (14), Seagate (76), Sennheiser (25), Seuic ... Gross Weight 0.05 KG. เงื่อนไขการรับประกัน. 1.หากสินค้ามี ...',
#   'website': 'TechWarehouse.co.th'},
#  {'title': 'Translate by API: Onkyo Home Theater Audio Prices\nOriginal: ราคา เครื่องเสียง Onkyo โฮมเธียเตอร์',
#   'link': 'https://www.priceza.com/s/%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%AA%E0%B8%B5%E0%B8%A2%E0%B8%87-onkyo-%E0%B9%82%E0%B8%AE%E0%B8%A1%E0%B9%80%E0%B8%98%E0%B8%B5%E0%B8%A2%E0%B9%80%E0%B8%95%E0%B8%AD%E0%B8%A3%E0%B9%8C',
#   'description': 'Translate by API: 5 ngày trÃ © c —... kg speaker specifications Speaker Type (Front) 2-Way bass-reflex, 12 cm... home theater jvc kit Sony audio kit Sony home theater kit Yamaha home theater kit...\nOriginal: 5 ngày trước — ... kg SPEAKER SPECIFICATIONS Speaker Type (Front) 2-Way bass-reflex, 12 cm ... ชุดโฮมเธียเตอร์jvc ชุดเครื่องเสียง Sony ชุดโฮมเธียเตอร์ Sony ชุดโฮมเธียเตอร์ Yamaha  ...',
#   'website': 'Priceza'},
#  {'title': 'Translate by API: Nuc Celeron Check latest price, cheap price, current price\nOriginal: Nuc Celeron เช็คราคาล่าสุด ราคาถูก ราคาปัจจุบัน',
#   'link': 'https://www.priceza.com/s/%E0%B8%A3%E0%B8%B2%E0%B8%84%E0%B8%B2/nuc-celeron',
#   'description': 'Translate by API: 3 days ago — ... KG Package Dimension (W x D x H) : 17.50 x 16.50 x 10.00 cm Gross ... Rtx 3060 การ์ดจอมือสอง Rtx 3060 Notebook Samsung Gtx 1070 Gtx 1050 Gtx 1080 ...\nOriginal: 3 ngày trước — ... KG Package Dimension (W x D x H) : 17.50 x 16.50 x 10.00 cm Gross ... Rtx 3060 การ์ดจอมือสอง Rtx 3060 Notebook Samsung Gtx 1070 Gtx 1050 Gtx 1080 ...',
#   'website': 'Priceza'},
#  {'title': 'Public Girls Sen. Sec.School Old Rajpura',
#   'link': 'https://www.facebook.com/groups/1067172696657946/?locale=th_TH',
#   'description': "28 thg 9, 2024 — ... Samsung #Phone A51 & A71 with Rs.700/- & 11 #EMI's on Bajaj Finserv Card ... Web Designing | #PHP | HR | Marketing | Finance | #Digital_Marketing | SEO/SMO | ...",
#   'website': 'Facebook'}]

# %%
len(google_links)
# Out:
# 43

# %% [markdown]
# ### Save data

# %%
COL_TYPE = 'Type'
COL_LINK = 'Link'
COL_TITLE = 'Title'
COL_DES = 'Short description'
COL_CONTENT = 'Web content'
COL_SUMMARY = 'Summary'

# %%
data = []

for i, link in enumerate(google_links):
    row = {
        COL_TYPE:'google',
        COL_LINK: link["link"],
        COL_TITLE: link["title"],
        COL_DES: link["description"]
    }
    data.append(row)

# %%
len(google_links)
# Out:
# 43

# %%
import os
import pandas as pd
from datetime import datetime
try:
    today = datetime.today().date()
    file_path = f'..//output//output_{today}.xlsx'
    sheet_name = f'google_{today}'

    columns = [COL_TYPE, COL_LINK, COL_TITLE, COL_DES]
    df = pd.DataFrame(data, columns=columns)

    # Check file exist, delete old sheet before add new sheet
    if os.path.exists(file_path):
        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='new') as writer:
            if sheet_name in writer.book.sheetnames:
                writer.book.remove(writer.book[sheet_name])
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    logger.info(f'Exported {len(data)} data successful')
except Exception as e:
    logger.error(f'Save data fail: {e}')
