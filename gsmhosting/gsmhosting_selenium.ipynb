# %% [markdown]
# ### Import

# %%
import os
import sys
import re
import datetime
import importlib
import pandas as pd
from time import sleep
from time import strptime
from datetime import datetime
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Logger

# %%
# Run file logger.py to create logger object with prefix 'gsm'
with open('../common/logger.py') as f:
    exec(f.read())
logger = get_logger(name='gsm')
logger.info('Start crawl gsm-forum')

# %%
# Import a module from another directory
def get_module(folder_name, file_name):
    module_name = file_name.split('.')[0]
    module_path = os.path.join(os.getcwd(), '..', folder_name, file_name)
    spec = importlib.util.spec_from_file_location(module_name, module_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
try:
    driver_module = get_module('common', 'web_driver.py')
    get_driver = driver_module.get_driver
    driver = get_driver()
except Exception as e:
    logger.error(f'Import web driver fail: {e}')

# %% [markdown]
# ### Crawl selenium

# %%
# Go to "Product Support Sections" category on GSM-forum
try:
    driver.get("https://forum.gsmhosting.com/vbb/f209/")
except Exception as e:
    logger.error(f'Init driver fail: {e}')
    sys.exit()

# %%
topic_products = []
try:
    product_links = driver.find_elements(By.CLASS_NAME, "alt1Active")
    for link in product_links:
        a_tag = link.find_element(By.TAG_NAME, "a")
        title = link.text
        href = a_tag.get_attribute("href")

        topic_products.append({'title': title, 'link':href})  
except Exception as e:
    logger.error(f'Crawl selenium: {e}')

# %%
DAY = 1
MONTH = 7
YEAR = 2024
KEY_WORDS = ["unlock", "hack", "samsung", "s2", "flip", "fold", "knox"]

# %%
def get_products_from_topic(driver, link):
    products = []
    driver.get(link['link'])
    print(link['title'])

    rows = driver.find_elements(By.XPATH, "//*[contains(@id, 'thread_title')]")
    times = driver.find_elements(By.CSS_SELECTOR, "div.smallfont[style*='text-align:right; white-space:nowrap']")

    for i, (row, time) in enumerate(zip(rows, times)):
        title = row.text
        link = row.get_attribute('href')
        creatAt = time.text 

        pattern = r'(\d{2}-\d{2}-\d{4})'
        match = re.search(pattern, time.text)
        if match:
            creatAt = match.group(1)
        else:
            creatAt = None

        if(creatAt != None): 
            products.append({'title': row.text, 'link':link, 'creatAt': creatAt})

    month_str = str(MONTH).zfill(2)
    day_str = str(DAY).zfill(2)
    year_str = str(YEAR)
    deadline = month_str + '-' + day_str + '-' + year_str

    product_links_by_deadline = [item for item in products if strptime(item['creatAt'], '%m-%d-%Y') >= strptime(deadline, '%m-%d-%Y')]
    product_links_by_keywords = [item for item in product_links_by_deadline if any(keyword in item['title'].lower() for keyword in KEY_WORDS)]

    for i, thread_link in enumerate(product_links_by_keywords):
        print(f"Link {i+1}: {thread_link['title']} \n{thread_link['link']} \n{thread_link['creatAt']}\n")

    return product_links_by_keywords

# %%
driver.implicitly_wait(20)

# %%
total_products = []
try: 
    for link in (topic_products):
        total_products += get_products_from_topic(driver, link)

except Exception as e:
    logger.error(f'Get all product: {e}')
# Out:
# AMT-dongle
# ART (Android Root Tool)
# Link 1: Samsung M215F Binary 3 FRP Remove via Test Mode method
# https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# 07-21-2024
#
# Android Multi Tool (AMT)
# 7ICE Team
# Mkey - Modem Unlock Key
# Avengers Box
# Link 1: Avengers Box / UMT Pro Samsung Module v0.6 Released - [08/10/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-6-released-08-10-2024-a-3341252/
# 10-08-2024
#
# Link 2: Avengers Box / UMT Pro Samsung Module v0.5 Released - [07/10/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-5-released-07-10-2024-a-3340904/
# 10-19-2024
#
# Link 3: Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# 08-14-2024
#
# Link 4: Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# 08-11-2024
#
# Link 5: Mobicel Legend Pro SimUnlock Done
# https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# 07-31-2024
#
# Chimera Tool
# Link 1: ⭐️24/10/2024⭐️Vivo Exynos Support and Samsung Qualcomm Improvements
# https://forum.gsmhosting.com/vbb/f898/24-10-2024-vivo-exynos-support-samsung-qualcomm-improvements-2819592/
# 10-30-2024
#
# Link 2: 🔥Samsung Update Week 3/3🔥: +138 Exynos devices! IMEI Repair & Read/Write/Patch Cert
# https://forum.gsmhosting.com/vbb/f898/samsung-update-week-3-3-138-exynos-devices-imei-repair-read-write-patch-cert-3205835/
# 10-29-2024
#
# Link 3: ⭐️13/06/2024⭐️New Exynos Models (9945/8845) - No Root, Any Bit, Any Version, Any Knox
# https://forum.gsmhosting.com/vbb/f898/13-06-2024-new-exynos-models-9945-8845-no-root-any-bit-any-version-any-knox-3312270/
# 08-01-2024
#
# Link 4: Help unlocking Sam J737A Bit 8
# https://forum.gsmhosting.com/vbb/f898/help-unlocking-sam-j737a-bit-8-a-3345414/
# 10-31-2024
#
# Cheetah Tool Products
# Link 1: Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# 09-16-2024
#
# Link 2: Samsung G780G FRP??
# https://forum.gsmhosting.com/vbb/f1146/samsung-g780g-frp-3343168/
# 10-17-2024
#
# Link 3: Samsung SM-N778F Note 10lite
# https://forum.gsmhosting.com/vbb/f1146/samsung-sm-n778f-note-10lite-3341594/
# 10-10-2024
#
# Link 4: Blu G73 unlock fail Spectrum
# https://forum.gsmhosting.com/vbb/f1146/blu-g73-unlock-fail-spectrum-3337114/
# 09-17-2024
#
# Link 5: All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# 09-07-2024
#
# Link 6: Samsung A236E U6 FRP
# https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# 09-07-2024
#
# DC Unlocker
# Link 1: Xiaomi bootloader unlock tool
# https://forum.gsmhosting.com/vbb/f1004/xiaomi-bootloader-unlock-tool-3337265/
# 09-18-2024
#
# Eagle Eye
# Easy-Jtag / Easy-Jtag Plus
# The official support section. You can ask here your question and get answer regarding using Easy-Jtag / Easy-Jtag Plus.
# Link 1: Samsung S134DL Isp pinouts needed
# https://forum.gsmhosting.com/vbb/f672/samsung-s134dl-isp-pinouts-needed-3337588/
# 10-01-2024
#
# EFT Dongle
# Link 1: ★=★=★Successfully Unlocked & Repaired & Translating Phones By EFT Dongle★=★=★
# https://forum.gsmhosting.com/vbb/f1014/successfully-unlocked-repaired-translating-phones-eft-dongle-2214526/
# 11-01-2024
#
# Link 2: Tcl 9029w unlock
# https://forum.gsmhosting.com/vbb/f1014/tcl-9029w-unlock-3345091/
# 10-29-2024
#
# EME Mobile Tool (EMT)
# Official Support Section by EmeGSM Team
# Link 1: Hi team haw bout unlock passcod wthout losing data for new mode [ANSWERED]
# https://forum.gsmhosting.com/vbb/f1107/hi-team-haw-bout-unlock-passcod-wthout-losing-data-new-mode-answered-3336839/
# 09-15-2024
#
# FuriousGold
# FuriouS GOLD Support Area | Powered by FuriousTeam
# Link 1: FuriousGold Successfully Unlocked / Repaired / Flashed Phones !!!
# https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# 10-22-2024
#
# Link 2: Need help for TCL T509k unlock network
# https://forum.gsmhosting.com/vbb/f272/need-help-tcl-t509k-unlock-network-3345521/
# 11-01-2024
#
# Link 3: Tcl t509a unlock error
# https://forum.gsmhosting.com/vbb/f272/tcl-t509a-unlock-error-3344805/
# 10-30-2024
#
# Link 4: vortex Z23 unlock failed [SOLVED]
# https://forum.gsmhosting.com/vbb/f272/vortex-z23-unlock-failed-solved-3336514/
# 10-22-2024
#
# Link 5: Tcl 9137w unlock done
# https://forum.gsmhosting.com/vbb/f272/tcl-9137w-unlock-done-3344258/
# 10-21-2024
#
# Link 6: Unlock altice s25 possible with furious?
# https://forum.gsmhosting.com/vbb/f272/unlock-altice-s25-possible-furious-3272137/
# 10-14-2024
#
# GSM Shield Box
# Link 1: [30-08-24] GSMShield Qualcomm 3.6 - Xiaomi Auth, Samsung KG Bypass...
# https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# 08-30-2024
#
# Link 2: samsung a037 (a03s) frp bypass done
# https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# 08-29-2024
#
# GSMServer Products
# Medusa SigmaKey
# Smart-Clip 2
# HUA Team Products
# HUA Box HDE Tool
# HUA GOLD
# HYDRA TOOL
# Link 1: Samsung A11 FRP Bypass Test point
# https://forum.gsmhosting.com/vbb/f1065/samsung-a11-frp-bypass-test-point-3343446/
# 10-17-2024
#
# Infinity-Box
# BB5 Easy Service Tool (BEST) Nokia Dongle
# Link 1: zte 9046 unlock failed
# https://forum.gsmhosting.com/vbb/f296/zte-9046-unlock-failed-3345417/
# 10-31-2024
#
# MFC Team Products
# iBUS Tools For Apple Watch iPOWER X & iREWORK Station
# MFC Dongle (iMFC)
# NCK Team products
# Mutli Unlocking Tool with Standalone Calculation.
# Avengers Box NCK Box Premium v2
# Octopus/Octoplus
# Octoplus FRP Tool Octoplus Huawei Tool
# Octopus LG/Octoplus LG Octopus Samsung/Octoplus Samsung
# Octoplus JTAG Octopus/Octoplus Suite
# Pandora’s box
# Pandora’s box spanish
# Link 1: Nokia TA-1369 Stuck On Fastboot After Network Unlock
# https://forum.gsmhosting.com/vbb/f1110/nokia-ta-1369-stuck-fastboot-after-network-unlock-3344905/
# 10-31-2024
#
# TFM-Tool
# Link 1: TFM Tool Pro QC has been added with more Samsung 123 Models/Bit
# https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# 08-08-2024
#
# Link 2: Samsung server off or on
# https://forum.gsmhosting.com/vbb/f1119/samsung-server-off-3340930/
# 10-07-2024
#
# Link 3: Samsung Frp Help
# https://forum.gsmhosting.com/vbb/f1119/samsung-frp-help-3340353/
# 10-05-2024
#
# RIFF Box Team
# RIFFBOX
# Saras Boxes
# Twister , UFS3, Tornado Ufs2 , n-Box
# UFST
# Ultimate Multi Tool Box
# Multi GSM & CDMA Box
# Link 1: [15-10-24] UMTv2/UMTPro QcFire v11.0 - Honor 50 Pro, S24 Ultra, ZFold 6 and more...
# https://forum.gsmhosting.com/vbb/f970/15-10-24-umtv2-umtpro-qcfire-v11-0-honor-50-pro-s24-ultra-zfold-6-more-3342766/
# 10-26-2024
#
# Link 2: Vivo y75 frp unlock failed umt mtk
# https://forum.gsmhosting.com/vbb/f970/vivo-y75-frp-unlock-failed-umt-mtk-3344784/
# 10-24-2024
#
# UnlockTool
# Link 1: ★★★ Post All Successfully Story Repaired Phones by UnlockTool ★★★
# https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# 11-02-2024
#
# Link 2: UnlockTool-2024.10.30.0 Released Auto Update-Added Samsung New Bit
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-10-30-0-released-auto-update-added-samsung-new-bit-3345281/
# 11-02-2024
#
# Link 3: Unlocktool License Data [Username] Incorrect Or Other Login Issue Post Here
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-license-data-username-incorrect-other-login-issue-post-here-3087626/
# 10-29-2024
#
# Link 4: Test Report | Xiaomi Sidelode Unlock | Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# 10-25-2024
#
# Link 5: Resellers are Most Welcome ! www.unlocktool.org
# https://forum.gsmhosting.com/vbb/f1112/resellers-most-welcome-www-unlocktool-org-3017831/
# 10-23-2024
#
# Link 6: Guide Video Fix Error Status Code 401 Proxy ! Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# 09-28-2024
#
# Link 7: Updates - 18/09/2024 | UnlockTool Add New 30+ Models
# https://forum.gsmhosting.com/vbb/f1112/updates-18-09-2024-unlocktool-add-new-30-models-3337336/
# 09-19-2024
#
# Link 8: UnlockTool-2024.04.08.0 Released Update
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-04-08-0-released-update-3295756/
# 11-02-2024
#
# Link 9: unlock tool adb error
# https://forum.gsmhosting.com/vbb/f1112/unlock-tool-adb-error-3129324/
# 11-01-2024
#
# Link 10: virus report in unlocktool . CHECK ADMINS
# https://forum.gsmhosting.com/vbb/f1112/virus-report-unlocktool-check-admins-3296711/
# 10-31-2024
#
# Link 11: Samsung Tab T595 U4 with DRK Problem !!! How to repair!!!!
# https://forum.gsmhosting.com/vbb/f1112/samsung-tab-t595-u4-drk-problem-how-repair-3345426/
# 10-31-2024
#
# Link 12: Apple TAB iPad Pro 9.7 inch IOS 16.7.10 Icloud bypass done with Unlocktool
# https://forum.gsmhosting.com/vbb/f1112/apple-tab-ipad-pro-9-7-inch-ios-16-7-10-icloud-bypass-done-unlocktool-3345139/
# 10-31-2024
#
# Uni-Android Tool - UAT PRO
# Link 1: SAMSUNG galaxy s7 g930f flashing
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345322/
# 10-31-2024
#
# Link 2: SAMSUNG galaxy s7 g930f flashing
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345321/
# 10-31-2024
#
# Link 3: Samsung A14 (A145R) FRP lock
# https://forum.gsmhosting.com/vbb/f1019/samsung-a14-a145r-frp-lock-3345070/
# 10-28-2024
#
# Link 4: SAMSUNG TAB A8 (T295F) Reset FRP Done...
# https://forum.gsmhosting.com/vbb/f1019/samsung-tab-a8-t295f-reset-frp-done-3343655/
# 10-18-2024
#
# Link 5: SAMSUNG galaxy j7 prime frp reset perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-j7-prime-frp-reset-perfect-3342691/
# 10-14-2024
#
# Link 6: Samsung a34 5g a346e frp remove done with odin mode by uat tool pro bestunlockite
# https://forum.gsmhosting.com/vbb/f1019/samsung-a34-5g-a346e-frp-remove-done-odin-mode-uat-tool-pro-bestunlockite-3341631/
# 10-10-2024
#
# Link 7: SAMSUNG m307f u4 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-m307f-u4-flashing-perfect-3341524/
# 10-09-2024
#
# Z3X-Team Products
# Pandora’s box by Z3X-Team Z3X-JTAG
# Link 1: Samsung Tool Pro 45.14. Small fix and improvements.
# https://forum.gsmhosting.com/vbb/f453/samsung-tool-pro-45-14-small-fix-improvements-3186907/
# 10-27-2024
#
# Link 2: Post here successfully job with Z3X-BOX Samsung (2018-2022)
# https://forum.gsmhosting.com/vbb/f453/post-here-successfully-job-z3x-box-samsung-2018-2022-a-2514647/
# 10-22-2024
#
# Link 3: Samsung Combination flash files requests ONLY here
# https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# 08-06-2024
#
# Link 4: Samsung Tab T595 U4 with DRK Problem !!! How to repair!!!! [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-tab-t595-u4-drk-problem-how-repair-answered-3345428/
# 11-01-2024
#
# Link 5: Need help unlocking J737A Bit 8 [Answered]
# https://forum.gsmhosting.com/vbb/f453/need-help-unlocking-j737a-bit-8-answered-3345316/
# 10-31-2024
#
# Link 6: G965f mck unlock but nck not unlock [Answered]
# https://forum.gsmhosting.com/vbb/f453/g965f-mck-unlock-but-nck-not-unlock-answered-3345125/
# 10-30-2024
#
# Link 7: S20 G980f patch cert not working question. [Solved]
# https://forum.gsmhosting.com/vbb/f453/s20-g980f-patch-cert-not-working-question-solved-3345130/
# 10-30-2024
#
# Link 8: A107f unlock error
# https://forum.gsmhosting.com/vbb/f453/a107f-unlock-error-3344869/
# 10-25-2024
#
# Link 9: Wave 575 (GT-S5750) unlocked successfully [Done]
# https://forum.gsmhosting.com/vbb/f453/wave-575-gt-s5750-unlocked-successfully-done-1208218/
# 10-22-2024
#
# Link 10: Samsung a105fn region lock remove failed [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a105fn-region-lock-remove-failed-answered-3344000/
# 10-19-2024
#
# Link 11: A205u failing to unlock.help please [Answered]
# https://forum.gsmhosting.com/vbb/f453/a205u-failing-unlock-help-please-answered-3343813/
# 10-18-2024
#
# Link 12: lg k41s not unlocked credit take [Answered]
# https://forum.gsmhosting.com/vbb/f453/lg-k41s-not-unlocked-credit-take-answered-3343470/
# 10-17-2024
#
# 0
# Samsung M215F Binary 3 FRP Remove via Test Mode method
# https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# 07-21-2024
#
# 1
# Avengers Box / UMT Pro Samsung Module v0.6 Released - [08/10/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-6-released-08-10-2024-a-3341252/
# 10-08-2024
#
# 2
# Avengers Box / UMT Pro Samsung Module v0.5 Released - [07/10/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-5-released-07-10-2024-a-3340904/
# 10-19-2024
#
# 3
# Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# 08-14-2024
#
# 4
# Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]
# https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# 08-11-2024
#
# 5
# Mobicel Legend Pro SimUnlock Done
# https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# 07-31-2024
#
# 6
# ⭐️24/10/2024⭐️Vivo Exynos Support and Samsung Qualcomm Improvements
# https://forum.gsmhosting.com/vbb/f898/24-10-2024-vivo-exynos-support-samsung-qualcomm-improvements-2819592/
# 10-30-2024
#
# 7
# 🔥Samsung Update Week 3/3🔥: +138 Exynos devices! IMEI Repair & Read/Write/Patch Cert
# https://forum.gsmhosting.com/vbb/f898/samsung-update-week-3-3-138-exynos-devices-imei-repair-read-write-patch-cert-3205835/
# 10-29-2024
#
# 8
# ⭐️13/06/2024⭐️New Exynos Models (9945/8845) - No Root, Any Bit, Any Version, Any Knox
# https://forum.gsmhosting.com/vbb/f898/13-06-2024-new-exynos-models-9945-8845-no-root-any-bit-any-version-any-knox-3312270/
# 08-01-2024
#
# 9
# Help unlocking Sam J737A Bit 8
# https://forum.gsmhosting.com/vbb/f898/help-unlocking-sam-j737a-bit-8-a-3345414/
# 10-31-2024
#
# 10
# Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# 09-16-2024
#
# 11
# Samsung G780G FRP??
# https://forum.gsmhosting.com/vbb/f1146/samsung-g780g-frp-3343168/
# 10-17-2024
#
# 12
# Samsung SM-N778F Note 10lite
# https://forum.gsmhosting.com/vbb/f1146/samsung-sm-n778f-note-10lite-3341594/
# 10-10-2024
#
# 13
# Blu G73 unlock fail Spectrum
# https://forum.gsmhosting.com/vbb/f1146/blu-g73-unlock-fail-spectrum-3337114/
# 09-17-2024
#
# 14
# All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro
# https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# 09-07-2024
#
# 15
# Samsung A236E U6 FRP
# https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# 09-07-2024
#
# 16
# Xiaomi bootloader unlock tool
# https://forum.gsmhosting.com/vbb/f1004/xiaomi-bootloader-unlock-tool-3337265/
# 09-18-2024
#
# 17
# Samsung S134DL Isp pinouts needed
# https://forum.gsmhosting.com/vbb/f672/samsung-s134dl-isp-pinouts-needed-3337588/
# 10-01-2024
#
# 18
# ★=★=★Successfully Unlocked & Repaired & Translating Phones By EFT Dongle★=★=★
# https://forum.gsmhosting.com/vbb/f1014/successfully-unlocked-repaired-translating-phones-eft-dongle-2214526/
# 11-01-2024
#
# 19
# Tcl 9029w unlock
# https://forum.gsmhosting.com/vbb/f1014/tcl-9029w-unlock-3345091/
# 10-29-2024
#
# 20
# Hi team haw bout unlock passcod wthout losing data for new mode [ANSWERED]
# https://forum.gsmhosting.com/vbb/f1107/hi-team-haw-bout-unlock-passcod-wthout-losing-data-new-mode-answered-3336839/
# 09-15-2024
#
# 21
# FuriousGold Successfully Unlocked / Repaired / Flashed Phones !!!
# https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# 10-22-2024
#
# 22
# Need help for TCL T509k unlock network
# https://forum.gsmhosting.com/vbb/f272/need-help-tcl-t509k-unlock-network-3345521/
# 11-01-2024
#
# 23
# Tcl t509a unlock error
# https://forum.gsmhosting.com/vbb/f272/tcl-t509a-unlock-error-3344805/
# 10-30-2024
#
# 24
# vortex Z23 unlock failed [SOLVED]
# https://forum.gsmhosting.com/vbb/f272/vortex-z23-unlock-failed-solved-3336514/
# 10-22-2024
#
# 25
# Tcl 9137w unlock done
# https://forum.gsmhosting.com/vbb/f272/tcl-9137w-unlock-done-3344258/
# 10-21-2024
#
# 26
# Unlock altice s25 possible with furious?
# https://forum.gsmhosting.com/vbb/f272/unlock-altice-s25-possible-furious-3272137/
# 10-14-2024
#
# 27
# [30-08-24] GSMShield Qualcomm 3.6 - Xiaomi Auth, Samsung KG Bypass...
# https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# 08-30-2024
#
# 28
# samsung a037 (a03s) frp bypass done
# https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# 08-29-2024
#
# 29
# Samsung A11 FRP Bypass Test point
# https://forum.gsmhosting.com/vbb/f1065/samsung-a11-frp-bypass-test-point-3343446/
# 10-17-2024
#
# 30
# zte 9046 unlock failed
# https://forum.gsmhosting.com/vbb/f296/zte-9046-unlock-failed-3345417/
# 10-31-2024
#
# 31
# Nokia TA-1369 Stuck On Fastboot After Network Unlock
# https://forum.gsmhosting.com/vbb/f1110/nokia-ta-1369-stuck-fastboot-after-network-unlock-3344905/
# 10-31-2024
#
# 32
# TFM Tool Pro QC has been added with more Samsung 123 Models/Bit
# https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# 08-08-2024
#
# 33
# Samsung server off or on
# https://forum.gsmhosting.com/vbb/f1119/samsung-server-off-3340930/
# 10-07-2024
#
# 34
# Samsung Frp Help
# https://forum.gsmhosting.com/vbb/f1119/samsung-frp-help-3340353/
# 10-05-2024
#
# 35
# [15-10-24] UMTv2/UMTPro QcFire v11.0 - Honor 50 Pro, S24 Ultra, ZFold 6 and more...
# https://forum.gsmhosting.com/vbb/f970/15-10-24-umtv2-umtpro-qcfire-v11-0-honor-50-pro-s24-ultra-zfold-6-more-3342766/
# 10-26-2024
#
# 36
# Vivo y75 frp unlock failed umt mtk
# https://forum.gsmhosting.com/vbb/f970/vivo-y75-frp-unlock-failed-umt-mtk-3344784/
# 10-24-2024
#
# 37
# ★★★ Post All Successfully Story Repaired Phones by UnlockTool ★★★
# https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# 11-02-2024
#
# 38
# UnlockTool-2024.10.30.0 Released Auto Update-Added Samsung New Bit
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-10-30-0-released-auto-update-added-samsung-new-bit-3345281/
# 11-02-2024
#
# 39
# Unlocktool License Data [Username] Incorrect Or Other Login Issue Post Here
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-license-data-username-incorrect-other-login-issue-post-here-3087626/
# 10-29-2024
#
# 40
# Test Report | Xiaomi Sidelode Unlock | Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# 10-25-2024
#
# 41
# Resellers are Most Welcome ! www.unlocktool.org
# https://forum.gsmhosting.com/vbb/f1112/resellers-most-welcome-www-unlocktool-org-3017831/
# 10-23-2024
#
# 42
# Guide Video Fix Error Status Code 401 Proxy ! Unlock Tool
# https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# 09-28-2024
#
# 43
# Updates - 18/09/2024 | UnlockTool Add New 30+ Models
# https://forum.gsmhosting.com/vbb/f1112/updates-18-09-2024-unlocktool-add-new-30-models-3337336/
# 09-19-2024
#
# 44
# UnlockTool-2024.04.08.0 Released Update
# https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-04-08-0-released-update-3295756/
# 11-02-2024
#
# 45
# unlock tool adb error
# https://forum.gsmhosting.com/vbb/f1112/unlock-tool-adb-error-3129324/
# 11-01-2024
#
# 46
# virus report in unlocktool . CHECK ADMINS
# https://forum.gsmhosting.com/vbb/f1112/virus-report-unlocktool-check-admins-3296711/
# 10-31-2024
#
# 47
# Samsung Tab T595 U4 with DRK Problem !!! How to repair!!!!
# https://forum.gsmhosting.com/vbb/f1112/samsung-tab-t595-u4-drk-problem-how-repair-3345426/
# 10-31-2024
#
# 48
# Apple TAB iPad Pro 9.7 inch IOS 16.7.10 Icloud bypass done with Unlocktool
# https://forum.gsmhosting.com/vbb/f1112/apple-tab-ipad-pro-9-7-inch-ios-16-7-10-icloud-bypass-done-unlocktool-3345139/
# 10-31-2024
#
# 49
# SAMSUNG galaxy s7 g930f flashing
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345322/
# 10-31-2024
#
# 50
# SAMSUNG galaxy s7 g930f flashing
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345321/
# 10-31-2024
#
# 51
# Samsung A14 (A145R) FRP lock
# https://forum.gsmhosting.com/vbb/f1019/samsung-a14-a145r-frp-lock-3345070/
# 10-28-2024
#
# 52
# SAMSUNG TAB A8 (T295F) Reset FRP Done...
# https://forum.gsmhosting.com/vbb/f1019/samsung-tab-a8-t295f-reset-frp-done-3343655/
# 10-18-2024
#
# 53
# SAMSUNG galaxy j7 prime frp reset perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-j7-prime-frp-reset-perfect-3342691/
# 10-14-2024
#
# 54
# Samsung a34 5g a346e frp remove done with odin mode by uat tool pro bestunlockite
# https://forum.gsmhosting.com/vbb/f1019/samsung-a34-5g-a346e-frp-remove-done-odin-mode-uat-tool-pro-bestunlockite-3341631/
# 10-10-2024
#
# 55
# SAMSUNG m307f u4 flashing perfect
# https://forum.gsmhosting.com/vbb/f1019/samsung-m307f-u4-flashing-perfect-3341524/
# 10-09-2024
#
# 56
# Samsung Tool Pro 45.14. Small fix and improvements.
# https://forum.gsmhosting.com/vbb/f453/samsung-tool-pro-45-14-small-fix-improvements-3186907/
# 10-27-2024
#
# 57
# Post here successfully job with Z3X-BOX Samsung (2018-2022)
# https://forum.gsmhosting.com/vbb/f453/post-here-successfully-job-z3x-box-samsung-2018-2022-a-2514647/
# 10-22-2024
#
# 58
# Samsung Combination flash files requests ONLY here
# https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# 08-06-2024
#
# 59
# Samsung Tab T595 U4 with DRK Problem !!! How to repair!!!! [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-tab-t595-u4-drk-problem-how-repair-answered-3345428/
# 11-01-2024
#
# 60
# Need help unlocking J737A Bit 8 [Answered]
# https://forum.gsmhosting.com/vbb/f453/need-help-unlocking-j737a-bit-8-answered-3345316/
# 10-31-2024
#
# 61
# G965f mck unlock but nck not unlock [Answered]
# https://forum.gsmhosting.com/vbb/f453/g965f-mck-unlock-but-nck-not-unlock-answered-3345125/
# 10-30-2024
#
# 62
# S20 G980f patch cert not working question. [Solved]
# https://forum.gsmhosting.com/vbb/f453/s20-g980f-patch-cert-not-working-question-solved-3345130/
# 10-30-2024
#
# 63
# A107f unlock error
# https://forum.gsmhosting.com/vbb/f453/a107f-unlock-error-3344869/
# 10-25-2024
#
# 64
# Wave 575 (GT-S5750) unlocked successfully [Done]
# https://forum.gsmhosting.com/vbb/f453/wave-575-gt-s5750-unlocked-successfully-done-1208218/
# 10-22-2024
#
# 65
# Samsung a105fn region lock remove failed [Answered]
# https://forum.gsmhosting.com/vbb/f453/samsung-a105fn-region-lock-remove-failed-answered-3344000/
# 10-19-2024
#
# 66
# A205u failing to unlock.help please [Answered]
# https://forum.gsmhosting.com/vbb/f453/a205u-failing-unlock-help-please-answered-3343813/
# 10-18-2024
#
# 67
# lg k41s not unlocked credit take [Answered]
# https://forum.gsmhosting.com/vbb/f453/lg-k41s-not-unlocked-credit-take-answered-3343470/
# 10-17-2024

# %% [markdown]
# ### Get comment

# %%
# Retrieves the first 5 earliest comments from a topic.
# including navigating to the last page of comments if necessary.
# driver: Selenium WebDriver instance.
# url: URL of the topic.
# Returns list_answers: List of the first 5 earliest comments.
def get_comments_by_link(driver, url=''):
    driver.get(url)

    # Navigate to the last page of comments (earliest comments)
    try:
        last_page_a = driver.find_element(By.XPATH, "//a[@class='smallfont' and contains(text(), 'Last ')]")
        last_page_a.click()
        sleep(3)
    except Exception:
        print("Only 1 page of comments found")

    # Retrieve the last 5 div elements with an id starting with 'post...'
    comment_divs = driver.find_elements(By.CSS_SELECTOR, "table[id^='post']:nth-last-of-type(-n+5)")
    
    # Get the content of the 5 comments
    comments = []
    for cmt_container in reversed(comment_divs):
        container_id = cmt_container.get_attribute("id")    # ex: post14872555
        comment_id = container_id[4:]                       # ex: 14872555

        content = cmt_container.find_element(By.ID, f"post_message_{comment_id}").text
        comments.append(content)

    return comments

# %%
comments = []
try:
    for i, post in enumerate(total_products):
        print(f"Post {i}: {post['link']}")
        comments.append(get_comments_by_link(driver, post['link']))
except Exception as e:
    logger.error(f'Get data by link: {e}')
# Out:
# Thread 0: https://forum.gsmhosting.com/vbb/f1134/samsung-m215f-binary-3-frp-remove-via-test-mode-method-3321538/
# Only 1 page of comments found
# Thread 1: https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-6-released-08-10-2024-a-3341252/
# Only 1 page of comments found
# Thread 2: https://forum.gsmhosting.com/vbb/f820/avengers-box-umt-pro-samsung-module-v0-5-released-07-10-2024-a-3340904/
# Only 1 page of comments found
# Thread 3: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/
# Only 1 page of comments found
# Thread 4: https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/
# Only 1 page of comments found
# Thread 5: https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/
# Only 1 page of comments found
# Thread 6: https://forum.gsmhosting.com/vbb/f898/24-10-2024-vivo-exynos-support-samsung-qualcomm-improvements-2819592/
# Thread 7: https://forum.gsmhosting.com/vbb/f898/samsung-update-week-3-3-138-exynos-devices-imei-repair-read-write-patch-cert-3205835/
# Thread 8: https://forum.gsmhosting.com/vbb/f898/13-06-2024-new-exynos-models-9945-8845-no-root-any-bit-any-version-any-knox-3312270/
# Only 1 page of comments found
# Thread 9: https://forum.gsmhosting.com/vbb/f898/help-unlocking-sam-j737a-bit-8-a-3345414/
# Only 1 page of comments found
# Thread 10: https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/
# Only 1 page of comments found
# Thread 11: https://forum.gsmhosting.com/vbb/f1146/samsung-g780g-frp-3343168/
# Only 1 page of comments found
# Thread 12: https://forum.gsmhosting.com/vbb/f1146/samsung-sm-n778f-note-10lite-3341594/
# Only 1 page of comments found
# Thread 13: https://forum.gsmhosting.com/vbb/f1146/blu-g73-unlock-fail-spectrum-3337114/
# Only 1 page of comments found
# Thread 14: https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/
# Only 1 page of comments found
# Thread 15: https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/
# Only 1 page of comments found
# Thread 16: https://forum.gsmhosting.com/vbb/f1004/xiaomi-bootloader-unlock-tool-3337265/
# Only 1 page of comments found
# Thread 17: https://forum.gsmhosting.com/vbb/f672/samsung-s134dl-isp-pinouts-needed-3337588/
# Only 1 page of comments found
# Thread 18: https://forum.gsmhosting.com/vbb/f1014/successfully-unlocked-repaired-translating-phones-eft-dongle-2214526/
# Thread 19: https://forum.gsmhosting.com/vbb/f1014/tcl-9029w-unlock-3345091/
# Only 1 page of comments found
# Thread 20: https://forum.gsmhosting.com/vbb/f1107/hi-team-haw-bout-unlock-passcod-wthout-losing-data-new-mode-answered-3336839/
# Only 1 page of comments found
# Thread 21: https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/
# Thread 22: https://forum.gsmhosting.com/vbb/f272/need-help-tcl-t509k-unlock-network-3345521/
# Only 1 page of comments found
# Thread 23: https://forum.gsmhosting.com/vbb/f272/tcl-t509a-unlock-error-3344805/
# Only 1 page of comments found
# Thread 24: https://forum.gsmhosting.com/vbb/f272/vortex-z23-unlock-failed-solved-3336514/
# Only 1 page of comments found
# Thread 25: https://forum.gsmhosting.com/vbb/f272/tcl-9137w-unlock-done-3344258/
# Only 1 page of comments found
# Thread 26: https://forum.gsmhosting.com/vbb/f272/unlock-altice-s25-possible-furious-3272137/
# Only 1 page of comments found
# Thread 27: https://forum.gsmhosting.com/vbb/f1087/30-08-24-gsmshield-qualcomm-3-6-xiaomi-auth-samsung-kg-bypass-3332823/
# Only 1 page of comments found
# Thread 28: https://forum.gsmhosting.com/vbb/f1087/samsung-a037-a03s-frp-bypass-done-3332770/
# Only 1 page of comments found
# Thread 29: https://forum.gsmhosting.com/vbb/f1065/samsung-a11-frp-bypass-test-point-3343446/
# Only 1 page of comments found
# Thread 30: https://forum.gsmhosting.com/vbb/f296/zte-9046-unlock-failed-3345417/
# Only 1 page of comments found
# Thread 31: https://forum.gsmhosting.com/vbb/f1110/nokia-ta-1369-stuck-fastboot-after-network-unlock-3344905/
# Only 1 page of comments found
# Thread 32: https://forum.gsmhosting.com/vbb/f1119/tfm-tool-pro-qc-has-been-added-more-samsung-123-models-bit-3320960/
# Only 1 page of comments found
# Thread 33: https://forum.gsmhosting.com/vbb/f1119/samsung-server-off-3340930/
# Only 1 page of comments found
# Thread 34: https://forum.gsmhosting.com/vbb/f1119/samsung-frp-help-3340353/
# Only 1 page of comments found
# Thread 35: https://forum.gsmhosting.com/vbb/f970/15-10-24-umtv2-umtpro-qcfire-v11-0-honor-50-pro-s24-ultra-zfold-6-more-3342766/
# Only 1 page of comments found
# Thread 36: https://forum.gsmhosting.com/vbb/f970/vivo-y75-frp-unlock-failed-umt-mtk-3344784/
# Only 1 page of comments found
# Thread 37: https://forum.gsmhosting.com/vbb/f1112/post-all-successfully-story-repaired-phones-unlocktool-2960341/
# Thread 38: https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-10-30-0-released-auto-update-added-samsung-new-bit-3345281/
# Only 1 page of comments found
# Thread 39: https://forum.gsmhosting.com/vbb/f1112/unlocktool-license-data-username-incorrect-other-login-issue-post-here-3087626/
# Thread 40: https://forum.gsmhosting.com/vbb/f1112/test-report-xiaomi-sidelode-unlock-unlock-tool-3085099/
# Only 1 page of comments found
# Thread 41: https://forum.gsmhosting.com/vbb/f1112/resellers-most-welcome-www-unlocktool-org-3017831/
# Only 1 page of comments found
# Thread 42: https://forum.gsmhosting.com/vbb/f1112/guide-video-fix-error-status-code-401-proxy-unlock-tool-3304882/
# Only 1 page of comments found
# Thread 43: https://forum.gsmhosting.com/vbb/f1112/updates-18-09-2024-unlocktool-add-new-30-models-3337336/
# Only 1 page of comments found
# Thread 44: https://forum.gsmhosting.com/vbb/f1112/unlocktool-2024-04-08-0-released-update-3295756/
# Only 1 page of comments found
# Thread 45: https://forum.gsmhosting.com/vbb/f1112/unlock-tool-adb-error-3129324/
# Only 1 page of comments found
# Thread 46: https://forum.gsmhosting.com/vbb/f1112/virus-report-unlocktool-check-admins-3296711/
# Only 1 page of comments found
# Thread 47: https://forum.gsmhosting.com/vbb/f1112/samsung-tab-t595-u4-drk-problem-how-repair-3345426/
# Only 1 page of comments found
# Thread 48: https://forum.gsmhosting.com/vbb/f1112/apple-tab-ipad-pro-9-7-inch-ios-16-7-10-icloud-bypass-done-unlocktool-3345139/
# Only 1 page of comments found
# Thread 49: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345322/
# Only 1 page of comments found
# Thread 50: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-s7-g930f-flashing-3345321/
# Only 1 page of comments found
# Thread 51: https://forum.gsmhosting.com/vbb/f1019/samsung-a14-a145r-frp-lock-3345070/
# Only 1 page of comments found
# Thread 52: https://forum.gsmhosting.com/vbb/f1019/samsung-tab-a8-t295f-reset-frp-done-3343655/
# Only 1 page of comments found
# Thread 53: https://forum.gsmhosting.com/vbb/f1019/samsung-galaxy-j7-prime-frp-reset-perfect-3342691/
# Only 1 page of comments found
# Thread 54: https://forum.gsmhosting.com/vbb/f1019/samsung-a34-5g-a346e-frp-remove-done-odin-mode-uat-tool-pro-bestunlockite-3341631/
# Only 1 page of comments found
# Thread 55: https://forum.gsmhosting.com/vbb/f1019/samsung-m307f-u4-flashing-perfect-3341524/
# Only 1 page of comments found
# Thread 56: https://forum.gsmhosting.com/vbb/f453/samsung-tool-pro-45-14-small-fix-improvements-3186907/
# Thread 57: https://forum.gsmhosting.com/vbb/f453/post-here-successfully-job-z3x-box-samsung-2018-2022-a-2514647/
# Thread 58: https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/
# Thread 59: https://forum.gsmhosting.com/vbb/f453/samsung-tab-t595-u4-drk-problem-how-repair-answered-3345428/
# Only 1 page of comments found
# Thread 60: https://forum.gsmhosting.com/vbb/f453/need-help-unlocking-j737a-bit-8-answered-3345316/

# %%
COL_TYPE = 'Type'
COL_LINK = 'Link'
COL_PUBLISHED = 'Published at'
COL_TITLE = 'Title'
COL_CONTENT = 'Content'
COL_SUMMARY = 'Summary'

# %%
# collect data
MIN_WORDS = 20
data_output = []

for i, post in enumerate(total_products):
    comment = ''.join(comments[i][0:5])
    row = {
        COL_TYPE:'gsm',
        COL_LINK: post["link"],
        COL_PUBLISHED: post["creatAt"], 
        COL_TITLE: post["title"], 
        COL_CONTENT: comment
    }
    if len(comment) >= MIN_WORDS:
        data_output.append(row)

# %%
comments
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
driver.quit()

# %% [markdown]
# ### Genai

# %%
genai_module = get_module('common', 'genai.py')
Genai = genai_module.Genai

# %%
genai = Genai()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 genai = Genai()
#
# File l:\Hack\Auto-Scanning-Tool\gsmhosting\..\common\genai.py:75, in Genai.__init__(self)
#      72 password = PASSWORD
#      74 user_ip = self.driver.find_element(By.ID, 'userNameInput')
# ---> 75 password_ip = self.driver.find_element(By.ID, 'passwordInput')
#      76 login_btn = self.driver.find_element(By.ID, 'submitButton')
#      78 user_ip.send_keys(username)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     300 trimmed = self._trim_large_entries(params)
#     301 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302 return self._request(command_info[0], url, body=data)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     319     body = None
#     321 if self.keep_alive:
# --> 322     response = self._conn.request(method, url, body=body, headers=headers)
#     323     statuscode = response.status
#     324 else:
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\vansy.le\AppData\Local\Programs\Python\Python312\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
data_output
# Out:
# [{'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/',
#   'Published at': '08-14-2024',
#   'Title': 'Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]',
#   'Content': 'Added Samsung models\nGalaxy A52 SM-A525M BIT6\nGalaxy Z Flip6 5G SM-F741B BIT1\nGalaxy Z Fold 5G SM-F946B BIT3\nGalaxy S21 FE 5G SM-G990U BITC\nGalaxy S21 FE SM-G990U2 BITA\nGalaxy S22 Ultra 5G SM-S908E BITA\nGalaxy S23 Ultra 5G SM-S918B BIT6\nGalaxy S24 Ultra 5G SM-S928B BIT3\nGalaxy S24 Ultra 5G SM-S928N BIT2\nGalaxy A05s SM-A057F BIT3\nGalaxy S21 FE 5G SM-G990B2 BIT7\nGalaxy S21 5G SM-G991U BIT10\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT6\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT3\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT4\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT5\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L\nGalaxy Note 10+ SM-N975U BIT8\nGalaxy S22 Ultra 5G SM-S908U BIT6\nGalaxy Tab A7 10.4 (2020) SM-T500 BIT8\nGalaxy J6 Plus SM-J610G BIT3\nGalaxy M01 SM-M015G BIT5\nGalaxy M11 SM-M115F BIT3\n\n- Read info in edl normal & download mode,\n- Reset frp in edl mode,\n- Reset userdata in edl mode.\n\nAdded Flashing in download mode using normal tar.md5 firmware.\nAdded read info in download mode (display partitions info).\nAdded read phone info and frp state info in normal mode.\n\n\n\nStill Don’t have NCK ?\n\nDo you have UMT?\n\nNow you can activation NCK Box Premium v2 on UMT Cards\nso you can use it with out shipping costs without limits\n\nOfficial Website:\n\nAvengers Box\nUMT Pro\n\n\nOfficial Shop:\nhttps://fastunlocking.com/shop/en/\n\n\nPayments by\nCredit Card via Stripe gateway\nPaypal\nCredit Card via Paypal\nCredit Card via Google Pay\nCredit Card via Apple Pay\n\n\n\nDownload From Support Area\n\n\nOR\n\nhttps://drive.google.com/file/d/1U6D...usp=drive_link\n\nPassword for Zip:\n\nNckTeam'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/',
#   'Published at': '08-11-2024',
#   'Title': 'Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]',
#   'Content': 'Samsung\nGalaxy A05s - SM-A05F (Bit 4)\nGalaxy Z Flip4 - SM-F721U (U/U1/W) (BIT6)\nGalaxy Z Flip5 - SM-F731B_DS (BIT2)\nGalaxy Z Flip5 - SM-F731U1 (U/U1/W) (BIT4)\nGalaxy Z Fold5 - SM-F946B_DS (BIT2)\nGalaxy Z Fold5 - SM-F946U (U/U1/W) (BIT4)\nGalaxy Z Fold 6 - SM-F956U (U/U1/W) (BIT1)\nGalaxy S23 - SM-S911U (U/U1/W) (BIT4)\nGalaxy S23+ - SM-S916B_DS (BIT5)\nGalaxy S23 - SM-S916U (U/U1/W) (BIT4)\nGalaxy S23 Ultra SM-S918U (U/U1/W) (BIT4)\nGalaxy S24 - SM-S921U (U/U1/W) (BIT3)\nGalaxy S24+ - SM-S926U (U/U1/W) (BIT3)\nGalaxy S24 Ultra - SM-S928U (U/U1/W) (BIT3)\nGalaxy A71 SM-A716U/W Bit B\nGalaxy A01 (SM-A015M) BIT5\nGalaxy A11 (SM-A115M) BIT3\nGalaxy A23 (SM-A235M) BIT4\nGalaxy S22 Ultra 5G (SM-S908E) BIT8\nGalaxy S10 Lite SM-G770F BIT9\n\nReset FRP in EDL mode\nFormat Userdata in FRP mode\n\nFixed reset Samsung MTK FRP in download mode mode.\nAdded Read phone info and partitions info on download mode.\nBug fixes.\n\n\nOfficial Website:\n\nAvengers Box\nUMT Pro\n\n\nOfficial Shop:\nhttps://fastunlocking.com/shop/en/\n\n\nPayments by\nCredit Card via Stripe gateway\nPaypal\nCredit Card via Paypal\nCredit Card via Google Pay\nCredit Card via Apple Pay\n\n\n\nDownload From Support Area\n\n\nOR\n\nhttps://drive.google.com/file/d/1RB8...usp=drive_link\n\nPassword for Zip:\n\nNckTeamUmt is allway good update but samsung exynos frp NOT updete please... exynos updete...thx..\n\n\n\nBro...\n\nZishanm...Fixed reset Samsung MTK FRP in download mode mode.\n\nis there new way to reset may security patch?Add samsung A715f Bit BAlways good update UMT team'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/',
#   'Published at': '07-31-2024',
#   'Title': 'Mobicel Legend Pro SimUnlock Done',
#   'Content': 'Code:\nSELECTED: SC9863A\nACTION:  SimUnlock\nStart Detect phone.\nPhone must be off(you can service this phone without battery also).\nLong press "VOL -"+ "VOL +" key while inserting usb cable.\nKeep key untill boot complete.\nDetected: SPRD U2S Diag (COM5)\nSending payload, keep boot key untill loader start.\nExploiting phone.....\nSending preloader 1\nSending preloader 2\nSending FDL 1.....\nSending FDL 2.....\nNew flash metod detected.\n[5f] 440A23 [5e] 9188D8\nUID: A0XS0B_6_17_88\nFileSystem: EMMC\nRead partition info is supported by loader.\n***************\n[S]Manufacturer: Mobicel\n[S]Brand: Mobicel\n[S]Device: Legend_Pro_LTE\n[S]Model: Legend Pro LTE\nBuild ID: RP1A.201005.001\nCPU arhitecture: armeabi-v7a\nBuild product name: s9863a1h10_go_32b\nBuild description: Mobicel_Legend_Pro_LTE_DS_T_L_V01_20220614 11 RP1A.201005.001 25442 release-keys\nBoard: Legend_Pro_LTE\nBuild Id: RP1A.201005.001\nAndroid Release: 11\nAndroid Version: RP1A.201005.001 release-keys\nSecurity patch: 2022-05-05\nCPU NAME: SC9863A\nSN: 5064041265071905\nFound [l_fixnv1_a] [l_fixnv1_a] Size to download: 2 MB\nReading: l_fixnv1_a 200000\nLength: 100000 chk: 6253 calculated chk: 6252 calculated chk_32: 6253\nIMEI 1: 352594560613172\nIMEI 2: 352594560613180\nIMEI 3: 867400020316638\nIMEI 4: 867400020316646\nSimlock Type: 3\n \nSimlock Status:\nSIMLOCK: ACTIVE\nNETWORK SUBNET: INACTIVE\nSP LOCK: INACTIVE\nCORPORATE: INACTIVE\nUSER LOCK: INACTIVE\n[3]Simlock Type: 0  0\n[352594560613172] Unlock code: 87316483\n[352594560613180] Unlock code: 87316493\nWarning, this is factory key, some opperators can modify factory key.\nReading: prodnv\nReading: miscdata\nReading: l_fixnv1_a\nReading: l_fixnv2_a\nReading: l_fixnv1_b\nReading: l_fixnv2_b\nBackup saved to: C:\\Avengers\\spreadtrum_module\\spreadtrum_module_backup_folder\\flashmode_security_backup\\SC9863A_Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_l_fixnv1_a_nvram_backup.tar\nPhone have empty sign array, can be empty efuse or erased nv.\nStart write unlock, wait...\n[l_runtimenv1]Format OK.\n[l_runtimenv2]Format OK.\nWrite[0]\nWrite[1]\n[can take 0-10 sec]Wait untill phone restart.\nExe version: Avengers Unisoc Module 2.3.1\nLog saved:\nC:\\Avengers\\spreadtrum_module\\spreadtrum_module_backup_folder\\Saved_Logs\\Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_sim_unlock_phone.txt\nTotal Time: 00:01:29\nDone.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/26-09-2024-samsung-qualcomm-exynos-unisoc-improvements-2819592/',
#   'Published at': '09-27-2024',
#   'Title': '⭐️26/09/2024⭐️Samsung (Qualcomm, Exynos) and Unisoc improvements',
#   'Content': "Samsung (Qualcomm, Exynos) and Unisoc improvements\n\n\n\nSamsung Exynos Improvements\nFixed a bug when reading exceptionally large PITs from EUB mode.\nNew models were added to be supported from EUB mode:\nSamsung Galaxy Tab S6 Lite (SM-P625)\nSamsung Galaxy A35 5G (SM-S356V)\nSamsung Galaxy A35 5G (SM-A356N)\nSamsung Galaxy Tab S9 FE Plus 5G (SM-X616N)\n\nAvailable procedures (may vary device to device): Restore / Store Backup, Unlock / Relock Bootloader, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Set KnoxGuard State, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset, Patch KnoxGuard, Get Info, Reset Battery Status.\n\n\nSamsung Improvements\n\nWe've added the Network Factory Reset (Online) procedure for the following new Japanese au KDDI models via ADB mode:\nSamsung Galaxy S23 FE 5G (SCG24)\nSamsung Galaxy S24 Ultra (SCG26)\n\n\nSamsung Qualcomm Improvements\n\nMore new programmers have arrived for Samsung Qualcomm.\n\nThe following models and BIT versions are supported:\nSamsung Galaxy Z Fold3 5G (SM-F926B) BIT8\nSamsung Galaxy A52s 5G (SM-A528B) BIT9\nSamsung Galaxy A71 (SM-A715F) BITB\nSamsung Galaxy S9 (SM-G960U) BIT9\nSamsung Galaxy S22 5G (SM-S901E) BITA\nSamsung Galaxy A70s (SM-A707F) BIT3\nSamsung Galaxy M40 (SM-M405F) BIT2\nSamsung Galaxy S20 FE (SM-G780G) BITC\nSamsung Galaxy S10 (SM-G973U) BIT9\nSamsung Galaxy Note10+ 5G (SM-N976U) BIT6\nSamsung Galaxy S23+ 5G (SM-S916N) BIT4\n\nOn the devices above, the following procedures are now available: Factory Reset, Remove FRP, Get Info, Remove FMM, Remove MDM, Repair Boot, Root, Repair Serial, CSC Change, Remove Knoxguard (*), Reset Battery Status.\n\n*: The solution works until the February 2024 security update.\n\n\nUnisoc Improvements\n\nWe made the Repair IMEI procedure safer by identifying further device details that would make the procedure unable to run properly. In these cases, the Repair IMEI procedure is disabled.\n\n\nSoftware version: 40.74.0946\nRelease date: 26 september 2024\n\n\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comwhat an unique update..\nnow this is what we called update.\nthanks team\n\none question\nCode:\nOppo EDL mode flash – ofp, ops files are now supported\nlatest .ofp supported? or only oldthanks chimera team....keep it* up-\n\ndid u support root android 9\n\nwhat mtk device did u support for rooting??The phone is in an invalid state, please reconnect the USB cable and reboot it manually!\n\nWorkID: 92626404good update, next update remember to surport samsung andriod 9pie frp unlocking ;;;;;"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/',
#   'Published at': '08-25-2024',
#   'Title': '⭐️01/08/2024⭐️Samsung Read Codes solution and Qualcomm Improvements',
#   'Content': "Samsung Read Codes solution and Qualcomm Improvements\n\nEnhanced Samsung solution with updated Read Codes procedure for 150 Samsung models\n\nWe are excited to announce that the updated Read Codes procedure is now compatible with more firmware versions than ever(*). This method does not require root access or device disassembly, making it more convenient for you. Please note that the device must have a Knox warranty status of 0, as the procedure will not work if the warranty is voided.\n\nThe updated Read Codes procedure is supported for the following models:\nSamsung Galaxy A04s (SM-A047F, SM-A047M)\nSamsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M)\nSamsung Galaxy A12 Nacho (SM-A127F, SM-A127M)\nSamsung Galaxy A13 (SM-A135F, SM-A135M)\nSamsung Galaxy A14 (SM-A145F, SM-A145M, SM-A145FB, SM-A145MB)\nSamsung Galaxy A2 Core (SM-A260F, SM-A260G)\nSamsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205YN)\nSamsung Galaxy A20e (SM-A202F)\nSamsung Galaxy A21s (SM-A217F, SM-A217M)\nSamsung Galaxy A3 (2016) (SM-A310F, SM-A310M, SM-A310Y)\nSamsung Galaxy A3 (2017) (SM-A320F, SM-A320FL, SM-A320Y)\nSamsung Galaxy A30 (SM-A305F, SM-A305FN, SM-A305G, SM-A305GN, SM-A305GT, SM-A305YN)\nSamsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)\nSamsung Galaxy A33 5G (SM-A336B, SM-A336E, SM-A336M)\nSamsung Galaxy A40 (SM-A405F, SM-A405FM, SM-A405FN)\nSamsung Galaxy A50 (SM-A505F, SM-A505FM, SM-A505FN, SM-A505G, SM-A505GN, SM-A505GT, SM-A505YN)\nSamsung Galaxy A50s (SM-A507FN)\nSamsung Galaxy A51 (SM-A515F)\nSamsung Galaxy A51 5G (SM-A516B)\nSamsung Galaxy A53 5G (SM-A536B, SM-A536E)\nSamsung Galaxy A5 (2016) (SM-A510F, SM-A510M, SM-A510Y)\nSamsung Galaxy A5 (2017) (SM-A520F)\nSamsung Galaxy A6 (2018) (SM-A600F, SM-A600FN, SM-A600G, SM-A600GN)\nSamsung Galaxy A7 (2016) (SM-A710F, SM-A710M, SM-A710Y)\nSamsung Galaxy A7 (2017) (SM-A720F)\nSamsung Galaxy A7 (2018) (SM-A750F, SM-A750FN, SM-A750G, SM-A750GN)\nSamsung Galaxy A71 5G (SM-A716B)\nSamsung Galaxy A8 (2018) (SM-A530F)\nSamsung Galaxy A8+ (2018) (SM-A730F)\nSamsung Galaxy F12 (SM-F127G)\nSamsung Galaxy F13 (SM-E135F)\nSamsung Galaxy F34 (SM-E346B)\nSamsung Galaxy F41 (SM-F415F)\nSamsung Galaxy F62 (SM-E625F)\nSamsung Galaxy J2 Dash (SM-J260A, SM-J260AZ, SM-J260F, SM-J260G, SM-J260M)\nSamsung Galaxy J3 (2017) (SM-J330F, SM-J330FN, SM-J330G, SM-J330L)\nSamsung Galaxy J3 Emerge (SM-J327A, SM-J327AZ)\nSamsung Galaxy J4 (SM-J400F, SM-J400G, SM-J400M)\nSamsung Galaxy J5 (2017) (SM-J530F, SM-J530FM, SM-J530G, SM-J530GM, SM-J530Y, SM-J530YM)\nSamsung Galaxy J5 Prime (SM-G570F, SM-G570M, SM-G570Y)\nSamsung Galaxy J7 Prime (SM-G610F, SM-G610M, SM-G610Y)\nSamsung Galaxy J7 Prime 2 (SM-G611F, SM-G611FF, SM-G611M, SM-G611MT)\nSamsung Galaxy M12 (SM-M127F, SM-M127G)\nSamsung Galaxy M13 (SM-M135F, SM-M135FU, SM-M135M)\nSamsung Galaxy M33 5G (SM-M336B, SM-M336BU)\nSamsung Galaxy M34 5G (SM-M346B, SM-M346B1, SM-M346B2)\nSamsung Galaxy S10 (SM-G973F)\nSamsung Galaxy S10+ (SM-G975F)\nSamsung Galaxy S10 5G (SM-G977B)\nSamsung Galaxy S10e (SM-G970F)\nSamsung Galaxy S20 (SM-G980F)\nSamsung Galaxy S20 5G (SM-G981B)\nSamsung Galaxy S20 FE (SM-G780F)\nSamsung Galaxy S20+ (SM-G985F)\nSamsung Galaxy S20+ 5G (SM-G986B)\nSamsung Galaxy S20 Ultra 5G (SM-G988B)\nSamsung Galaxy S21 5G (SM-G991B)\nSamsung Galaxy S21 FE 5G (SM-G990E)\nSamsung Galaxy S21 Ultra 5G (SM-G998B)\nSamsung Galaxy S21+ 5G (SM-G996B)\nSamsung Galaxy S7 (SM-G930F)\nSamsung Galaxy S7 Edge (SM-G935F)\nSamsung Galaxy S8 (SM-G950F)\nSamsung Galaxy S8+ (SM-G955F)\nSamsung Galaxy S9 (SM-G960F)\nSamsung Galaxy S9+ (SM-G965F)\nSamsung Galaxy XCover 4 (SM-G390F, SM-G390Y)\nSamsung Galaxy XCover 4s (SM-G398FN)\nSamsung Galaxy XCover 5 (SM-G525F)\nSamsung Galaxy XCover FieldPro (SM-G889F, SM-G889G, SM-G889YB)\nSamsung Galaxy XCover Pro (SM-G715FN)\n\nSamsung Qualcomm Improvements\n\nMore new programmers have arrived for Samsung Qualcomm.\n\nThe following models and BIT versions are supported:\nSamsung Galaxy Z Fold 5 ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/',
#   'Published at': '08-08-2024',
#   'Title': '⭐️17/05/2024⭐️Samsung: New Exynos & QComm models + Remove MDM Fix',
#   'Content': "Samsung: New Exynos & QComm models + Remove MDM Fix\n\nMore new programmers have arrived for Samsung Qualcomm. The following models and BIT versions are supported:\nSamsung Galaxy A02s (SM-A025M BIT8)\nSamsung Galaxy A20s 2019 (SM-A207F BIT5)\nSamsung Galaxy A20s 2019 (SM-A207M BIT4)\nSamsung Galaxy A23 (SM-A235M BIT5)\nSamsung Galaxy S23 Ultra 5G (SM-S918B BIT4)\nSamsung Galaxy S22 Ultra 5G (SM-S908E BIT8)\n\nSamsung Exynos\n\nThe following new models were added to be supported from EUB mode:\nSamsung Galaxy A54 5G (SCG21)\nSamsung Galaxy Tab S9 FE Plus 5G (SCT22)\nSamsung Galaxy Tab A 8.4 2020 (SM-T307U)\n\nAvailable procedures: Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (*), Unlock / Relock Bootloader (**) For more detailed information, please visit our Supported models page.\n\n*: if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.\n**: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.\n\n\nBugfixes\nFixed a bug in Remove MDM procedure which could cause application crashes for Samsung Exynos devices\n\nSoftware version: 39.42.1216\nRelease date: 17 may 2024\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comYou make life easy for us King of Exynos\n\nBest Regards | YobaThanks for the useful and fast updates Samsung A12 (A127) please added Switch to EUB procedure ( from ODIN mode)after frp remove its struck eub mode, how to exit eub modeDear User,\n\n\n\n\nPlease run a Repair Boot/ Unbrick on the device and it will boot into normal mode.\n\n\nRegards,\nChimeraTeam\n\n\n\nQuote:\nOriginally Posted by cellcare prasad\nafter frp remove its struck eub mode, how to exit eub mode"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/',
#   'Published at': '08-01-2024',
#   'Title': '⭐️02/05/2024⭐️Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit/Version/Knox',
#   'Content': "New Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit, Any Version, Any Knox\n\n\n\nWe haven't finished yet! This time we're thrilled to introduce support for\nExynos 7884\nExynos 7884B\nExynos 7885\nExynos 7904\n\nThis solution is similar to our previous Exynos update in that it uses the EUB mode* to communicate with the device.\n\n\nThe following devices are supported:\nSamsung Galaxy A10e (SM-A102N, SM-A102U, SM-A102U1, SM-A102W, SM-S102DL)\nSamsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M, SM-A105N)\nSamsung Galaxy A20e (SM-A202F, SCV46)\nSamsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205S, SM-A205W, SM-A205YN, SM-S205DL)\nSamsung Galaxy A30 (SM-A3050, SM-A3058, SM-A305F, SM-A305FN, SM-A305GT, SM-A305N, SM-A305YN, SCV43)\nSamsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)\nSamsung Galaxy A40 (SM-A405FM SM-A405FN, SM-A405S)\nSamsung Galaxy A8 2018 (SM-A530F, SM-A530W)\nSamsung Galaxy A7 2018 (SM-A750C, SM-A750F, SM-A750FN, SM-A750N)\nSamsung Galaxy Xcover 4 (SM-G398FN)\nSamsung Galaxy J7 Duo (SM-J720F, SM-J720M)\nSamsung Galaxy M10s (SM-M107F)\nSamsung Galaxy M20 (SM-M205G, SM-M205M)\nSamsung Galaxy M30 (SM-M305F, SM-M305M)\nSamsung Galaxy Tab A 8.0 2019 (SM-P205)\nSamsung Galaxy Tab A 10.1 2019 (SM-T515, SM-T515N)\nSamsung Galaxy Tab A 10.1 2019 LTE (SM-T517, SM-T517P)\n\nAvailable procedures:Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (**), Unlock / Relock Bootloader (***)\n\n\nFor more detailed information, please visit our Supported models page.\n\nIf you'd like to see this working check out our videos:\nRepair Serial\n... or our two YouTube channel where you can find various educational content: ChimeraTool and ChimeraToolES.\n\n\n\n*: In most cases, it's necessary to disassemble the phone and use hardware-testpoints to put the phone into EUB mode. Visit our guides here and our Test Point Database to learn more.\n**:if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.\n***: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.\n\n\n\n\nSoftware version: 39.27.1420\nRelease date: 02 may 2024\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comchimera KING samsung tool\nvery nicechimera is best tool in gsm markitPlease add remove mdm lock on A042F via preloader mode in next update...you are the best and yes you are the king of samsung tools go ahead.\n\nHer is the successful auto-detect and remove log of FRP S21 5G G991B U9\nCode:\n Chimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02 \nIdentify\nConnecting to the phone...\nGathering information...\nPreparing phone...\nDownloading required files...\nProcessing files...\nCommunicating with the phone...\nRebooting\nThis may take a while. \nBe patient! Do NOT disconnect the phone! \nSuccessfully finished. \nFinished at local time: [05.02.24 11:08:35] \nWorkID: 274074432\nCode:\nChimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02 \nPrinting phone history\n\nAuto Detect\n5/2/2024\n8:13\nAM\n\nFRP Remove\nSuccessfully finished. \nFinished at local time: [05.02.24 11:08:50] \nWorkID: 274074529"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/samsung-galaxy-a11-sm-a115f-frp-s6-12-remove-done-test-point-3339180/',
#   'Published at': '09-28-2024',
#   'Title': 'Samsung Galaxy A11 SM-A115F FRP S6 12 REMOVE DONE TEST POINT',
#   'Content': 'Code:\nChimera Mobile Phone Utility version: 40.74.0946 @ 2024-09-27\nDelete FRP partition\nClearing FRP lock\nSuccessfully finished.\nFinished at local time: [09.27.24 17:59:44]\nWorkID: 310126452'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/samsung-tab-a9-x110-u3-frp-3339095/',
#   'Published at': '09-27-2024',
#   'Title': 'samsung tab a9 x110 u3 frp',
#   'Content': 'a9 x110 binary 3 frp not workingDear User,\n\n\nUnfortunately, we do not have a solution to remove the FRP from this device.\n\n\nRegards,\nChimeraTeam\n\n\n\nQuote:\nOriginally Posted by raoul plus\na9 x110 binary 3 frp not working'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/',
#   'Published at': '09-16-2024',
#   'Title': 'Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro',
#   'Content': 'Teclast P40HD (UNISOC Tiger T606)\nFRP Done with Cheetah Tool ProA03 Core (A032F)\n\nMdm Payjoy remved sucessfully.\n\nWaiting for device...\nConnecting port: SPRD U2S Diag (COM9)\nSoc Type : #SC9863A\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Okay\n\nAnalysis Security... Okay\n\nGetting Device info... Okay\n● Model Name: SM-A032F\n● Product Name: a3corexx\n● Manufacturer: samsung\n● Android Version: 12\n● Security Patch: 2023-05-01\n● Build ID: SP1A.210812.016\n● Display ID: SP1A.210812.016.A032FXXU3BWF2\n● Build Date: Mon Jun 19 21:28:03 KST 2023\n● Build: A032FXXU3BWF2\nGetting Storage info... Okay\n● Device Internal Storage: 24.92 GB\n● Userdata Crypto State: Encrypted?\n\n\nRemove MDM LOCK... Okay\nWipe frp lock... Okay\n\nReboot... Okay\n\n● Total Time Elapsed: 26 secs, 610 msecsAlcatel 9009G Frp Sucessfully Removed\n\n\n\nWaiting for brom usb device...\nDownload port: MediaTek USB Port_V1633 (COM10)\n\nGetting Device... Okay\nHandshake Device... Okay\n● CPU Model: MT6580\nGetting Device Config... Okay\nDetect Security!\nReading bootloader...\nBypass SLA Protection...\nBypass sec protection... Okay\nDump emi config... OkayOkay\n\nSending Loader... Okay\nGetting Chip info... Okay\nGetting device Synchronized... Okay\nInitiate RAM... Okay\nSending DL Config... OkayOkay\n\nEMMC_INFO:\n● EMMC_BOOT1: 4.00 MB\n● EMMC_BOOT2: 4.00 MB\n● EMMC_RPMB: 4.00 MB\n● EMMC_USER: 7.28 GB\n● EMMC_ID: 8801034E4361726420012B0F472F5567\nRAM_INFO:\n● IN_SRAM: 128.00 KB\n● EXT_DRAM: 1.00 GB\n\nSwitch to High Speed Port... Okay\n\nReading Partitions Table... Okay\nGetting Device info... Okay\n● Brand Name: TCL\n● Model Name: 9009G\n● Product Name: 9009G\n● Manufacturer: TCL\n● Android Version: 8.1.0 (Oreo)\n● Security Patch: 2019-06-05\n● Build ID: O11019\n● Build Date: Mon Aug 12 20:11:35 CST 2019\n● Build: vJ65-0\nGetting Storage info... Okay\n● Device Internal Storage: 5.22 GB\n● Userdata Crypto State: Encrypted?\n\nReset FRP Lock... Okay\n\nRebooting... Okay\n\n● Total Time Elapsed: 135 msecs\n\nWorkID: 2733990Mobicel R1 Plus 7731e FRP Remove Done\n\n\nCode:\nWaiting for device... \nConnecting port: SPRD U2S Diag (COM5)\nSoc Type :  #SC7731E\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Okay\n\nAnalysis Security... Okay\n\nGetting Device info... Okay\n ●  Model Name: R1PLUS_1\n ●  Product Name: R1PLUS_1\n ●  Manufacturer: Mobicel\n ●  Android Version: 10 (Android 10)\n ●  Security Patch: 2022-10-05\n ●  Build ID: QP1A.190711.020\n ●  Display ID: Mobicel_R1PLUS_1_DS_T_V14_20221109_MP\n ●  Build Date: Wed Nov  9 11:22:31 CST 2022\n ●  Build: 1667964169\nGetting Storage info... Okay\n ● Device Internal Storage: 11.83 GB\n ● Userdata Crypto State: Encrypted?\n\n\nReset frp lock... Okay\n\nReboot... Okay\n\n ● Total Time Elapsed: 31 secs, 813 msecs\n\nWorkID: 2914083Mobicel MX2 IMEI Repair Done\n\n\nCode:\nWaiting for device... \nConnecting port: SPRD U2S Diag (COM21)\nSoc Type :  #SC7731E\nGetting identity... Okay\nReboot to diag... Okay\nWait for diag device... \nGetting identity... Okay\nRead device info... Okay\n ● Platform Version: MOCORTM_17C_W21.14.6_DEBUG\n ● Project Version: PIKE2_PUB\n ● BASE  Version: FM_BASE_17C_W21.14.6\n ● HW Version: SC7731E_MODEM\n ● 04-10-2021 02: 00\nChecking new imei... Okay\n ●  New IMEI1: 350xxxxxxxxxxxxx\n ●  New IMEI2: 33xxxxxxxxxxxxxx\nRepairing imei... Okay\n\n ● Total Time Elapsed: 17 secs, 950 msecs'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/blu-g73-unlock-fail-spectrum-3337114/',
#   'Published at': '09-17-2024',
#   'Title': 'Blu G73 unlock fail Spectrum',
#   'Content': 'Waiting for device...\nConnecting port: SPRD U2S Diag(COM19)\nSoc Type : #TIGER T606\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Failed\n[PORT ERR] READ TIMED OUTQuote:\nOriginally Posted by hector bermudez\nWaiting for device...\nConnecting port: SPRD U2S Diag(COM19)\nSoc Type : #TIGER T606\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Failed\n[PORT ERR] READ TIMED OUT\nHello dear user\nplease change cpu type and try\nB.R Cheetah team'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/',
#   'Published at': '09-07-2024',
#   'Title': 'All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro',
#   'Content': 'All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro\n\n\n\nhttp://www.youtube.com/watch?v=_cVmDwwGf-Athank you for your shareQualcom all binaries supported brother?'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/',
#   'Published at': '09-07-2024',
#   'Title': 'Samsung A236E U6 FRP',
#   'Content': 'Dear supporters,Samsung A236EXXU6EFXF3 FRP Supported this tool?'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/',
#   'Published at': '09-04-2024',
#   'Title': 'Motorola G04 read network unlock code online?',
#   'Content': 'is Motorola G04 supported for "read network unlock code online?\nI tried but code not foundHello dear user\nwhich carrier?\nB.R Cheetah teamCarrier: Telstra AustraliaQuote:\nOriginally Posted by mtb116\nCarrier: Telstra Australia\nPlease create ticket on cheetah-tool.com\nand post your imei\nwe check your problem\nB.R Cheetah teamTicket created and imei posted on your site'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1004/xiaomi-bootloader-unlock-tool-3337265/',
#   'Published at': '09-18-2024',
#   'Title': 'Xiaomi bootloader unlock tool',
#   'Content': 'I need to unlock my (m190f7i) redmi note7 levender\ncan anybody hlp/guid me on this?Sorry, but we do not support any of Xiaomi devices.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f672/samsung-a71-a715f-frp-done-easyjtag-pinout-3338855/',
#   'Published at': '09-25-2024',
#   'Title': 'Samsung A71 A715f FRp Done EasyJtag PinOut',
#   'Content': "Reset Google FRP v2.0\n\nSearch Google FRP Partition..\nPartition #15 - 'PERSISTENT' is FRP.\nErasing Partition. Please Wait..\nErasing Done\nBackup Saved as: C:\\Users\\E...\\Downloads\\Telegram Desktop\\EFM 1.28 new API\\Backup\\FRP_BACKUP_0x00000A18B000_0x20240925_22 3917.bin\n\n\nReset Google FRP Done"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f672/samsung-s134dl-isp-pinouts-needed-3337588/',
#   'Published at': '09-20-2024',
#   'Title': 'Samsung S134DL Isp pinouts needed',
#   'Content': "Operation: Connect to Z3X EasyJtagPlus (2023)\n\nSetting Interface to EasyJtag2/ISP\nSetting IO Levels to 2.4V\nSetting Frequence to 12 Mhz\nSetting BusWidth to 1 Bit\nCMD Pullup Level: 39 mV\nCMD Active Level: 584 mV\nSetting HS Timing to Enabled\n\nCan't init device. Error: -1. Reason: CMD Timeout Error\n\n\nhello team i need your help on samsung S134DL isp pinoutsQuote:\nOriginally Posted by ellisony\nOperation: Connect to Z3X EasyJtagPlus (2023)\n\nSetting Interface to EasyJtag2/ISP\nSetting IO Levels to 2.4V\nSetting Frequence to 12 Mhz\nSetting BusWidth to 1 Bit\nCMD Pullup Level: 39 mV\nCMD Active Level: 584 mV\nSetting HS Timing to Enabled\n\nCan't init device. Error: -1. Reason: CMD Timeout Error\n\n\nhello team i need your help on samsung S134DL isp pinouts\n\nThis one is done now after big research on isp pinouts"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/successfully-unlocked-repaired-translating-phones-eft-dongle-2214526/',
#   'Published at': '09-28-2024',
#   'Title': '★=★=★Successfully Unlocked & Repaired & Translating Phones By EFT Dongle★=★=★',
#   'Content': 'Hi all gsm members in world Here;\nPlease All Post Successfully Unlocked & Repaired & Translating Phones By\n\nEFT Dongle = Easy-Firmware Team Dongle\n\nIn This ThreadGalaxy Note 5 Sm-n920p add arabic successfullySM-J320V PI2 6.0.1 Successfully Added Arabic Lunguage By EFT Dongle\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBR,\nMohamed AamriSM-G920V PC2 5.1.1 Successfully Added Arabic Lunguage By EFT DongleSM-N920P QA1 6.0.1 Successfully Added Arabic Lunguage By EFT Dongle'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/',
#   'Published at': '08-16-2024',
#   'Title': 'EFT Pro Dongle Update V4.8.1[Added Qualcomm Models for Samsung&MTK Unlock SIM Realme]',
#   'Content': "EFT Pro Dongle Update V4.8.1 Build 001 is released :\n\nWhat's New :\n\n\n[Qualcomm]\n- Added Qualcomm Models for Samsung\n\n★ FRP (Factory Reset Protection)\n★ Factory Reset\n\nSpecific Models:\n\n- SM-A426U BIT6\n- SM-A526U BIT (A)\n- SM-A716U BIT9\n- SM-F711B BIT6\n- SM-F711U BIT6\n- SM-F711U BIT5\n- SM-F721B BIT4\n- SM-F721U BIT3\n- SM-F916U BIT2\n- SM-F926B BIT5\n- SM-F926B BIT4\n- SM-F926U BIT4\n- SM-F936B BIT4\n- SM-F936U BIT3\n- SM-G781U BIT6\n- SM-G781U BIT8\n- SM-G781U BIT9\n- SM-G781V BIT5\n- SM-G781W BIT (C)\n- SM-G781WV BIT (C)\n\n[MTK]\nAdded Unlock SIM for Realme:\nSpecific Models:\n\n- RMP2102\n- RMX3242\n- RMX3286\n- RMX3350\n- RMX3357\n- RMX3381\n- RMX3388\n- RMX3392\n- RMX3393\n- RMX3395\n- RMX3396\n- RMX3430\n- RMX3560\n- RMX3561\n- RMX3562\n- RMX3563\n- RMX3571\n- RMX3572\n- RMX3574\n- RMX3611\n- RMX3612\n- RMX3617\n- RMX3618\n- RMX3619\n- RMX3630\n- RMX3636\n- RMX3686\n- RMX3687\n- RMX3740\n- RMX3741\n- RMX3750\n- RMX3751\n- RMX3771\n- RMX3780\n- RMX3782\n\n\nMore Come Soon ..........\n\n\n\n\nPrevious Version EFT Pro Dongle Feature\n[MTK]\nNew design and Easy menu\nSupport Forced BROM (method 1)\nSupport Forced BROM (method 2)\nSupport Forced BROM without Test Point\nSupport Samsung forced BROM (PIT Method)\nSupport write Huawei (UPDATE APP) firmware\nSupport write Samsung (TAR) firmware\nSupport write Oppo/Realme (OFP) firmware\nSupport write EMMC Dump firmware\nSupport Vivo MT6765 PreLoader\nSupport direct unlock network MTK (BROM)\nSupport (Vivo) Disable MDM lock Supported for (2020 to Up)\nSupport (Vivo) Disable MDM lock Supported for (2019)\nSupport (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)\nSupport (Vivo) Disable demo mode\nSupport (Vivo) Disable orange msg\nSupport (Vivo) Restore orange msg\nUpdate Samsung Disable MDM Lock\nUpdate Samsung change KG\nUpdate Oppo disable MDM lock\nSupport Security 2022/2023 for MTK\nSupport Device for MTK devices\nSupport Device (MTK) Factory Reset/FRP Reset/Write Firmware\nUpdate Write Samsung (TAR) Firmware\nDevice (MTK) Factory Reset/FRP\nFix Tool Dl Image Fail\nReset Frp Lock WriteFile\nProtocol For MTK (V6)\nProtocol MTK Devices Read Info / Flash / Format / FRP\nFree Auth Tecno / Infinix / itel\nSupport Models on V6 Protocol Infinix / Tecno\nAdded Repair IMEI Generic (MT67XX) BROM\nAdded Repair Network Security 2020/2021 BROM\nAdded Repair Network Security 2022 BROM\nAdded Read IMEI\nAdded backup with CID number for MTK operations\nAdded Forced BROM SAMSUNG Download Mode\nAdded OPPO MT6771 Auth Free\nAdded Samsung Auth Free\nSamsung Galaxy Wide5(SM-E426S) Auth Free\nSamsung Galaxy A13 5G(SM-A136) Auth Free\nSamsung Galaxy A22(SM-A225) Auth Free\nSamsung Galaxy F42 (SM-E426)Auth Free\nAdded new DEVICE for mtk protocol (v6)\nUpdate GENERIC MTK V5\nUpdate GENERIC MTK 2023\nAdded META Read Info All MTK CPU\nAdded META Factory Reset All MTK CPU\nAdded META Factory Reset MT62XX\nAdded META Repair IMEI All MTK CPU\nAdded in META Mode ( Infinix - Tecno - Itel ) All Model With Auth\nAdded MTK Preloader\nAdded SAMSUNG Brom Models NEW\nAdded META Read Info\nAdded META Factory Reset Direct (INFINIX-TECNO-ITEL)\nAdded Enable/Disable Backup\nDirect Factory Reset (INFINIX-TECNO-ITEL)\n\n[SPD]\nSupport models apove 200+ model\nFactory reset and FRP Reset\nAdded write PAC firmware for All SPD\nEnter diag mode 2 methods\nRead info and IMEI in diag mode\nFactory reset in Diag mode ALL mode\nAdded RSA AUTH Itel/Tecno/Infinix/Realme and more\nAdded Spd Fix Wireless Test Assistant\nAdded New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC\nRead Info\nReset FRP/Factory Reset\nUnlock Bootloader\nRelock Bootloader\nAdded Info Boot Mode\nAdded Read Flash /Format Disk /Write Disk\nAdded Network Unlock Boot Mode\nAdded Repair IMEI Boot Mode\nAdded Remove MDM Boot Mode\nAdded New Boot SPD V2\nAdded GENERIC SPD V1\n\n[SAMSUNG]\nFix Exynos Boot (Beta)\nBypass Knox Samsung Adb\nBypass Knox Samsung MTP\nRemove FRP Direct (MTP) 2023\nEnable ADB With Call Emerge ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/',
#   'Published at': '08-04-2024',
#   'Title': 'EFT Pro Dongle Update V4.7.9[MTK Update AUTH Server - Xiaomi&Samsung New Model Added]',
#   'Content': "EFT Pro Dongle Update V4.7.9 Build 001 is released :\n\nWhat's New :\n\n\n[MTK]\nUpdate AUTH Server TECNO / INFINIX\n\n★ Read info\n★ FRP\n★ Factory Reset\n★ Flash\n\n\n[Xiaomi]\nAdded Models Qualcomm Xiaomi\n\n★ Reset FRP\n★ Factory Reset\n\nAdded Models Qualcomm Samsung V3 / V4\n\nSM-S908N U4 First in the World\nSM-G970U\nSM-G970U U9\nSM-G970U1 U9\nSM-G970W U9\nSM-G970XU U9\nSM-G975U U9\nSM-G975U1 U9\nSM-G975W U9\nSM-G975XU U9\nSM-G981U U9\nSM-G981U1 U9\nSM-G981W U9\nSM-G981XU U9\nSM-G986U U8\nSM-G986U1 U8\nSM-G986W U8\nSM-G986XU U8\nAdded Models Qualcomm Xiaomi\n\nXiaomi Mi 9 Lite\nXiaomi CC9\nXiaomi CC9 Meitu Edition\nXiaomi Mi 9T\nRedmi K20\nXiaomi Mi CC9 Pro\nXiaomi Mi Note 10\nNote 10 Lite\nXiaomi Mi Note 10 Pro\nXiaomi POCO X2\nXiaomi Redmi K30\nXiaomi Black Shark\nXiaomi Black Shark Helo\nXiaomi Mi 8\nXiaomi Mi 8 Pro\nXiaomi Mi 8 Explorer\nXiaomi Mi Mix 2s\nXiaomi Mi Mix 3\nXiaomi Mi 9\nXiaomi Mi 9T Pro\nXiaomi Mi Mix 3 5G\nXiaomi Black Shark 2\nXiaomi Redmi K20 Pro\nXiaomi Redmi 8\nXiaomi Redmi 8A\nXiaomi Redmi 7A\nXiaomi Mi CC9e\nXiaomi Redmi Note 8\nXiaomi Redmi Note 8T\nXiaomi Mi A3\nXiaomi Black Shark 3\nXiaomi Black Shark 3 Pro\nXiaomi Black Shark 3S\nXiaomi Mi 10 5G\nXiaomi Mi 10 Pro 5G\nXiaomi Mi 10 Ultra\nXiaomi Mi 10T 5G\nXiaomi Mi 10T Pro 5G\nXiaomi POCO F2 Pro\nXiaomi Redmi K30 Pro\nXiaomi Redmi K30S\n\n\n\n\n\n\nPrevious Version EFT Pro Dongle Feature\n[MTK]\nNew design and Easy menu\nSupport Forced BROM (method 1)\nSupport Forced BROM (method 2)\nSupport Forced BROM without Test Point\nSupport Samsung forced BROM (PIT Method)\nSupport write Huawei (UPDATE APP) firmware\nSupport write Samsung (TAR) firmware\nSupport write Oppo/Realme (OFP) firmware\nSupport write EMMC Dump firmware\nSupport Vivo MT6765 PreLoader\nSupport direct unlock network MTK (BROM)\nSupport (Vivo) Disable MDM lock Supported for (2020 to Up)\nSupport (Vivo) Disable MDM lock Supported for (2019)\nSupport (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)\nSupport (Vivo) Disable demo mode\nSupport (Vivo) Disable orange msg\nSupport (Vivo) Restore orange msg\nUpdate Samsung Disable MDM Lock\nUpdate Samsung change KG\nUpdate Oppo disable MDM lock\nSupport Security 2022/2023 for MTK\nSupport Device for MTK devices\nSupport Device (MTK) Factory Reset/FRP Reset/Write Firmware\nUpdate Write Samsung (TAR) Firmware\nDevice (MTK) Factory Reset/FRP\nFix Tool Dl Image Fail\nReset Frp Lock WriteFile\nProtocol For MTK (V6)\nProtocol MTK Devices Read Info / Flash / Format / FRP\nFree Auth Tecno / Infinix / itel\nSupport Models on V6 Protocol Infinix / Tecno\nAdded Repair IMEI Generic (MT67XX) BROM\nAdded Repair Network Security 2020/2021 BROM\nAdded Repair Network Security 2022 BROM\nAdded Read IMEI\nAdded backup with CID number for MTK operations\nAdded Forced BROM SAMSUNG Download Mode\nAdded OPPO MT6771 Auth Free\nAdded Samsung Auth Free\nSamsung Galaxy Wide5(SM-E426S) Auth Free\nSamsung Galaxy A13 5G(SM-A136) Auth Free\nSamsung Galaxy A22(SM-A225) Auth Free\nSamsung Galaxy F42 (SM-E426)Auth Free\nAdded new DEVICE for mtk protocol (v6)\nUpdate GENERIC MTK V5\nUpdate GENERIC MTK 2023\nAdded META Read Info All MTK CPU\nAdded META Factory Reset All MTK CPU\nAdded META Factory Reset MT62XX\nAdded META Repair IMEI All MTK CPU\nAdded in META Mode ( Infinix - Tecno - Itel ) All Model With Auth\nAdded MTK Preloader\nAdded SAMSUNG Brom Models NEW\nAdded META Read Info\nAdded META Factory Reset Direct (INFINIX-TECNO-ITEL)\nAdded Enable/Disable Backup\nDirect Factory Reset (INFINIX-TECNO-ITEL)\n\n[SPD]\nSupport models apove 200+ model\nFactory reset and FRP Reset\nAdded write PAC firmware for All SPD\nEnter diag mode 2 methods\nRead info and IMEI in diag mode\nFactory reset in Diag mode ALL mode\nAdded RSA AUTH Itel/Tecno/Infinix/Realme and more\nAdded Spd Fix Wireless Test Assistant\nAdded New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC\nRead Info\nReset FRP/Factory Reset\nUnlock Bootloader\nRelock Bootloader\nAdded Info Boot Mo ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/samsung-a346e-u8-frp-unlock-done-3338899/',
#   'Published at': '09-26-2024',
#   'Title': 'Samsung A346e u8 frp unlock done',
#   'Content': 'A346e u8 frp unlock done but still locked\nFrp removed after erase manually metadata, persistent, cache and userdata in one operation\n\nCode:\nWaiting For Device Connection... \nUSB PORT: MediaTek DA USB VCOM (Android) (COM35)\nPort: MediaTek DA USB VCOM (Android) (COM35)\nManufacturer: MediaTek Inc.\nRead Partition Table... \nServer ... OK\nGet Partition ... OK\nRead Build Prop Info... \n Device Brand: SAMSUNG\n Build Date: WED JUL 31 10:34:09 KST 2024\n Build Date (UTC): 1722389649\n Build Fingerprint: SAMSUNG/A34XDXX/A34X:12/SP1A.210812.016/A346EXXU8CXG8:USER/RELEASE-KEYS\n Build ID: SP1A.210812.016\n Build Tags: RELEASE-KEYS\n Build Type: USER\n Build Version Incremental: A346EXXU8CXG8\n Build Version Release: 12\n Build Version Release or Codename: 12\n Build Version SDK: 31\nRead Internal Storage Info... OK\nUSERDATA: 105.67 GB\nUSERDATA: ENCRYPTED\nRead Partition Table... \nServer ... OK\nGet Partition ... OK\nChecking calibration data... OK\n  Backup preloader... OK\n  Backup efs... OK\n  Backup sec_efs... OK\n  Backup nvram... OK\n  Backup vbmeta... OK\n  Backup protect1... OK\n  Backup protect2... OK\n  Backup seccfg... OK\n  Backup nvcfg... OK\n  Backup nvdata... OK\n  Backup proinfo... OK\n  Backup md1img... OK\nFormat metadata > Size: 32.00 MB... OK\nFormat persistent > Size: 512.00 KB... OK\nFormat cache > Size: 600.00 MB... OK\nFormat userdata > Size: 105.67 GB... OK\nReboot... OK\nElapsed Time: 20 secs, 375 msecs\nTotal FORMAT Data: 270.95 MB\nOperating speed: 13.30 MB/s'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-v4-6-3-released-translate-adb-android-14-qualcomm-samsung-mtk-3243985/',
#   'Published at': '09-24-2024',
#   'Title': 'EFT Pro Dongle V4.6.3 is Released Translate ADB Android 14 & QUALCOMM & SAMSUNG & MTK',
#   'Content': "EFT Pro Dongle Update V4.6.3 Build 001 is released :\n\nWhat's New :\n\n[MTK]\nAdded Support For New devices\nRead info\nReset frp / Factory Reset\nFlash\nSAMSUNG :\nSamsung MT6833 Auth Free\nSamsung A226b\n\n[Samsung]\nAdd Translate ADB Android 14(First in the world)\nar-EG: Arabic (Egypt)\nes-ES: Spanish (Spain)\nfr-FR: French (France)\nit-IT: Italian (Italy)\nko-KR: Korean (South Korea)\nru-RU: Russian (Russia)\ntr-TR: Turkish (Turkey)\nth-TH: Thai (Thailand)\nfa-IR: Persian (Iran)\nUpdate Translate Adb Android 10/11/12/13\nAdded Remove FRP Direct (MTP, only USA Samsung Phone)\nNo Need EDL\nNo Need Credit\nNo Need Server\nSM-A505U\nSM-A146U\nSM-A135U\nSM-A037U\nSM-F946U\nSM-G998U\nSM-G996U\nSM-G991U\nSM-G990U\nSM-F936U\nSM-F926U\nSM-S918U\nSM-S916U\nSM-S911U\nSM-F731U\nSM-F721U\nSM-F711U\nSM-S908U\nSM-S901U\nSM-G986U\nSM-G988U\nSM-N986U\nSM-N981U\nSM-A515U\n[Apple]\nUpdate Bypass MDM\n[QUALCOMM]\nAdded Support For New Devices\nReset FRP\nFactory Reset\nAdded a New Protocol For More Devices\nFix Old Loader\nSAMSUNG (Test Point or EDL Cable)\nA015 XX\nA015A\nA015AZ\nA015F\nA015G\nA015M\nA015T\nA025F\nA025G\nA025U\nA115A\nA115F\nA115U\nA526U\nA705 XX\nA715 XX\nA716U\nF711U\nF721U BIT3\nF731B BIT1\nF731U BIT1\nF916U BIT2\nF926B BIT4\nF936U BIT3\nF946U BIT1\nG781U BIT6\nG781U BIT8\nG781U BIT9\nG781V BIT5\nG930X BIT5\nG935X BIT5\nG950 BIT2\nG955 BIT2\nG970U BIT7\nG973U BIT7\nG975U BIT7\nG981U BIT2\nG986U BIT2\nG986U BIT7\nG988U BIT2\nG988U BIT7\nG990U BIT9\nG991U BIT4\nG991U BIT5\nG991U BIT8\nG996U BIT4\nG996U BIT5\nG996U BIT8\nG998U BIT4\nG998U BIT5\nG998U BIT8\nN950 BIT2\nN970U BIT7\nN975U BIT7\nN981U BIT2\nN986U BIT2\nN986U BIT5\nS901U BIT3\nS908E BIT7\nS908U BIT3\nS911B BIT3\nS916B BIT3\nS918B BIT3\n\n\n\n\nPrevious Version EFT Pro Dongle Feature\n[MTK]\nNew design and Easy menu\nSupport Forced BROM (method 1)\nSupport Forced BROM (method 2)\nSupport Forced BROM without Test Point\nSupport Samsung forced BROM (PIT Method)\nSupport write Huawei (UPDATE APP) firmware\nSupport write Samsung (TAR) firmware\nSupport write Oppo/Realme (OFP) firmware\nSupport write EMMC Dump firmware\nSupport Vivo MT6765 PreLoader\nSupport direct unlock network MTK (BROM)\nSupport (Vivo) Disable MDM lock Supported for (2020 to Up)\nSupport (Vivo) Disable MDM lock Supported for (2019)\nSupport (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)\nSupport (Vivo) Disable demo mode\nSupport (Vivo) Disable orange msg\nSupport (Vivo) Restore orange msg\nUpdate Samsung Disable MDM Lock\nUpdate Samsung change KG\nUpdate Oppo disable MDM lock\nSupport Security 2022/2023 for MTK\nSupport Device for MTK devices\nSupport Device (MTK) Factory Reset/FRP Reset/Write Firmware\nUpdate Write Samsung (TAR) Firmware\nDevice (MTK) Factory Reset/FRP\nFix Tool Dl Image Fail\nReset Frp Lock WriteFile\nProtocol For MTK (V6)\nProtocol MTK Devices Read Info / Flash / Format / FRP\nFree Auth Tecno / Infinix / itel\nSupport Models on V6 Protocol Infinix / Tecno\n\n[SPD]\nSupport models apove 200+ model\nFactory reset and FRP Reset\nAdded write PAC firmware for All SPD\nEnter diag mode 2 methods\nRead info and IMEI in diag mode\nFactory reset in Diag mode ALL mode\nAdded RSA AUTH Itel/Tecno/Infinix/Realme and more\nAdded Spd Fix Wireless Test Assistant\nAdded New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC\nRead Info\nReset FRP/Factory Reset\nUnlock Bootloader\nRelock Bootloader\n\n[SAMSUNG]\nFix Exynos Boot (Beta)\nBypass Knox Samsung Adb\nBypass Knox Samsung MTP\nRemove FRP Direct (MTP) 2023\nEnable ADB With Call Emergency #0#.\nRemove KG Lock Direct (MTP)\nTranslate ADB Android 13\n\n[Qualcomm]\nEnable Diag Mode Without Root\nAdded New List (Qualcomm New)\nAdded list Service For (Factory Reset /FRP )\nAdded list Service For (Factory Reset Oppo /FRP Oppo )\n-Qualcomm device support automatic loader\n-Support for Qualcomm devices. Select the model\nDevice Support for Qualcomm devices\nDevice (Qualcomm) Factory Reset/FRP\nQualcomm Protocol Update To Su ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1107/hi-team-haw-bout-unlock-passcod-wthout-losing-data-new-mode-answered-3336839/',
#   'Published at': '09-15-2024',
#   'Title': 'Hi team haw bout unlock passcod wthout losing data for new mode [ANSWERED]',
#   'Content': 'Hi team haw bout unlock passcod wthout losing data for new modelQuote:\nOriginally Posted by donia gsm\nHi team haw bout unlock passcod wthout losing data for new model\nHi,\n\nYou can touch me with my skype if that phone unlock screenshot without losing data not supprot yet.\n\nBest Regards\nEmeGSM Team'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f272/furiousgold-successfully-unlocked-repaired-flashed-phones-661803/',
#   'Published at': '07-08-2024',
#   'Title': 'FuriousGold Successfully Unlocked / Repaired / Flashed Phones !!!',
#   'Content': "Post here all your Successfully Unlocked /repaired /flashed Phones Phones By Our Famous Tool make sure to post log or screenshot\n\ndon't keep spamming the board\n\nand by the way we have something called Thanks Buttonunlock -ok with furious\n\nSearching phone ...\n\nMODEL : KU380\nCOMPILED DATE : Dec 5 2007 19:09:00\nRELEASE DATE : Jul 13 2007 08:00:00\nFIRMWARE INFO : KU380-MSM6245-V10a-OCT-19-2007-XX\nIMEI : 3583X00***XX-X\nBLUETOOTH ADDR : 00 1E 75 45 71 FF\n\nMEMORY ID : 0098:00C1\nMEMORY NAME : toshiba_ty9000a800jogg\nMEMORY SIZE : 100MB\n\nPERFORMING OPERATION ...\n\nREADING NV ...\nREADY...\nSW VERSION: [OK] KU380FL-01-V10a-214-04-OCT-19-2007+4\nIMEI: [OK] 3583X00***XX-X\nBLUETOOTH ADDR: [OK] FF7145751E00\nFORMAT: [OK] IDDE OK\n\nKU380 NV FILE VERSION 2 WITH 805 RECORDS.\nWRITING NV ...Shutdown phone...\nStarting service mode\nPress POWER button shortly\nModel: C72 v22 IMEI: 358134001697304\nExploiting....\nShutdown phone...\nPress POWER button shortly\nCan't init boot.\nShutdown phone...\nStarting service mode\nPress POWER button shortly\nCan't init service mode.\nTry to restore Bootcore..\nShutdown phone...\nPress POWER button shortly\nFlashID: 0089:880D\nSet port speed.\nESN: 5E88A2A9\nOTPIMEI: 358134001697304\nMemory size: 32Mb\nRead memory map.\nReading EEFULL.\nIMEI[5009]: 358134001697304\nUnlocking\nWriting back EEFULL\nRestoring Bootcore\nBlock 5121 good(0602) for OTP Imei\nSkey: 53493417 for 358134001697304\nTime elapsed: 81843 ms\nAll done!Searching phone ...\n\nMODEL : KU380\nCOMPILED DATE : Dec 6 2007 00:46:00\nRELEASE DATE : Sep 5 2007 04:00:00\nFIRMWARE INFO : KU380-MSM6245-V10a-SEP-24-2007-XX\nIMEI : 35839001951775-7\nBLUETOOTH ADDR : 00 1F 6B 81 58 C2\n\nMEMORY ID : 0098:00C1\nMEMORY NAME : toshiba_ty9000a800jogg\nMEMORY SIZE : 100MB\n\nPERFORMING OPERATION ...\n\nREADING NV ...\nREADY...\nSW VERSION: [OK] KU380FL-01-V10a-214-01-SEP-24-2007+4\nIMEI: [OK] 35839001951775700\nBLUETOOTH ADDR: [OK] C258816B1F00\nFORMAT: [OK] IDDE ERROR\n\nKU380 NV FILE VERSION 2 WITH 805 RECORDS.\nWRITING NV ...\nRESETTING ...\nTime needed - 00:00:24Press power on !\nStarting communication ...\nLoader version: FuriouSTeaM GSM DEVELOPEMENT\nBaud rate changed ok !\n\nFlash ID: 0001:227E 2000\nFW INFO: 060526n-08.00 VI1.QCI-0.27E TPWVJ\n\nLocks disabled !\nPhone reseted !\nTime needed - 00:01:48\n\nby furious"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f272/tecno-bf6-unlock-3339127/',
#   'Published at': '09-27-2024',
#   'Title': 'TECNO bF6 unlock.',
# ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-tool-pro-45-14-small-fix-improvements-3186907/',
#   'Published at': '09-10-2024',
#   'Title': 'Samsung Tool Pro 45.14. Small fix and improvements.',
#   'Content': 'Samsung Tool Pro 45.14. Small fix and improvements.\n\nImproved Read Codes for:\n\n- A245F, A245M, A245N\n- A3460, A346B, A346E, A346M, A346N\n- M536B, M536S\n\nFixed: patch CERT SM-A137F\n\n\n\nDont forget post BUG reports in correct thread.\n\nCheck supported phones: CHECK MY PHONE\nBug report - HERE\nNew phone adding request - HERE\nCredits price, rules of credits using and resellers - HERE\n\nIMPORTANT:\nDONT POST ANY LOGS OF JOB IN THIS THREAD about done jobe. DONE REPORT post only in thread\nJOBE NOT DONE REPORT - open own thread , post there all details and wait answer from supporters/developers.\nDONT ASK WHEN WILL BE SUPPORTED, ANSWER ASAP - AS SOON AS POSSIBLE\nViolation this rules messages will be deletedhello A235M unlock error 0.12 whats means? its on binary 1hello A245M unlock error 0.12 binary 2please add A042f A045f imei repair z3xPlease add a520f u16 support path certificate'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/',
#   'Published at': '08-06-2024',
#   'Title': 'Samsung Combination flash files requests ONLY here',
#   'Content': 'Please post here requests about Samsung combination flash files for all models ONLY in this THREAD!!\n\nRequests must be in format samsung standart flash file name:\nexample:\n\nN950USQU4CRF3\n\nAll other thread with file samsung combination file request will be deleted without warnings and explanations!!!\n\n\n----------------------------------------\n\nCombination file details, how to check version, date, android version.\n\n\n==============\n\nSample: COMBINATION_OXM_FA80_G960FXXU2ARG2\n\nOXM=CSC build = [OXM]\nFA80=Android version = [Android 8]\nG960F=Phone model = [G960F]\nXXU2= Version and security BIT = [XXU,BIT2]\nARG2= Date of release and revision = [July 2018, revision 2]\n\n==============\n\nFA81=Android 8.1\nFA80=Android 8\nFA70=Android 7\nFA60=Android 6\nFA51=Android 5.1\nFA50=Android 5.0\nFA44=Android 4.4\nFA43=Android 4.3\nFAJP=Android JB\nFTMA=Tizen\n\n=======\n\nO=2015\nP=2016\nQ=2017\nR=2018\n\n=======\n\nA=January\nB=February\nC=March\nD=April\nE=May\nF=June\nG=July\nH=August\nI=September\nJ=October\nK=November\nL=December\n\n=======\n\n1=Revision 1\n2=Revision 2\n3=Revision 3\n4=Revision 4\n5=Revision 5\n6=Revision 6\n7=Revision 7\n8=Revision 8\n9=Revision 9\nA=Revision 10\nB=Revision 11\nC=Revision 12\nD=Revision 13\nE=Revision 14\nF=Revision 15help me a7100 Combination file neededI need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.me too\n........................Quote:\nOriginally Posted by fakeprince_\nI need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.\ncheck you pm to test first\n\nbr'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a202f-not-unlock-error-0-12-answered-3336753/',
#   'Published at': '09-17-2024',
#   'Title': 'Samsung A202F not unlock.. error (0.12) [Answered]',
#   'Content': "is my phone supported to network unlock ?\n\nCode:\nChecking Login and Password... OK\nBalance: 12 crd.\nYou have 12 credit(s) left. This operation takes 5 credits. Attention! In case if phone asking MCK(Freeze, PUK) code, using this method will consume credits twice - first for MCK(Freeze, PUK) code and then for NCK(Network, PIN). Continue?  Yes\nWaiting ADB device... OK\nReading phone info...\nModel: SM-A202F\nAndroid version: 11\nPDA version: A202FXXU5CWF2\nCSC version: A202FOXM5CWF2\nPhone version: A202FXXU5CWF1\nProduct code: SM-A202FZKDDBT\nCSC country code: Germany\nCSC sales code: DBT\nCarrier ID: EVR\nPhone SN: R58xxxxxxxxx\nIMEI: 35xxxxxxxxxxxxxx\nHW version: MP 0.300\nRF cal date: 20190912\nChip name: EXYNOS7884B\nModem board: SHANNON327\nSecurity patch: 2023-05-01\nBoot Warranty bit: 0\nSIM State: ABSENT,ABSENT\nChecking SIM status... OK\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\n\nDone with Samsung Tool PRO v.45.14 [SM-A202F,Read Codes via Server]Hello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1Hello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1Quote:\nOriginally Posted by Z3X\nHello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1\nSir, what about this J330FN, Please refund\n\n\nUNLOCK INSTRUCTIONS:\nUnlocking with original MSL code:\nWarning! Knox warranty must be active (0x00)!\nIf you have it voided (0x01(void)), then you can't unlock this phone with MSL.\n1. Phone must be powered on.\n2. Type *#0808# and select 'DM+ACM+ADB'.\n3. Run dialer and type *#0*# (service mode will appear).\n4. Connect the phone to USB cable, choose correct COM port in port settings.\n5. Press 'Unlock' button.\n6. Paste MSL code in new opened window and press 'OK'.\n\nReading codes using sever ('Diag' algo):\nWarning! Knox warranty must be active (0x00)!\nIf you have it voided (0x01(void)), then you can't unlock this phone using sever.\n1. Power on the phone.\n2. Type *#0808# and select 'DM+MODEM+ADB'.\n3. Connect the phone to PC with USB cable, install drivers if needed.\n4. Press 'Read Codes via server' button, select 'Diag', write your login and password in window if it will appear.\n(Login and password will be saved as default after first input and can be changed in settings)\n\nReading codes using sever ('Upload' algo):\nKnox warranty does not matter.\n1. Power on the phone.\n2. Tap 7 times on 'Build number' in 'Settings'-'About phone' to enable 'Developer options',\ngo to 'Settings'-'Developer options' and enable 'USB debugging'.\n3. Connect the phone to PC with USB cable, install drivers if needed.\n4. Select device in ADB settings.\n5. Press 'Read Codes via server' button, select 'Upload' write your login and password in window if it will appear.\n(Login and ...
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-sm-g985f-root-answered-2988168/',
#   'Published at': '09-12-2024',
#   'Title': 'samsung sm-g985f Root [Answered]',
#   'Content': 'Hello i have a G985FXXU7DUDB_G985FOXM7DUDB_DBT must perform the root procedure Can anyone help meHello. Here detailed manual for magisk root: https://topjohnwu.github.io/Magisk/install.htmlHello how can I root G985F version G985FXXU5BTJ3.Imei null need repaiar.if yes root files send me please\n\nThanksQuote:\nOriginally Posted by TUN10\nHello how can I root G985F version G985FXXU5BTJ3.Imei null need repaiar.if yes root files send me please\n\nThanks\nhttps://topjohnwu.github.io/Magisk/install.html'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/',
#   'Published at': '09-09-2024',
#   'Title': 'Samsung A750FN relocked again [Answered]',
#   'Content': 'hi team\n\na month ago i unlocked A750FNXXU5CTK1 using server credit , after a month later it gets relocked again , pls check it\n\n\n\nCode:\nChecking Login and Password... OK\n Balance: 30 crd.\n You have 30 credit(s) left. This operation takes 5 credits. Continue?  Yes\n Waiting ADB device... OK\n Reading phone info...\n Model: SM-A750FN\n Android version: 10\n PDA version: A750FNXXU5CTK1\n CSC version: A750FNOXM5CTK1\n Phone version: A750FNXXU5CTK1\n Product code: SM-A750FZKNPHE\n CSC country code: SPAIN\n CSC sales code: PHE\n Carrier ID: VDI\n Phone SN: 32009ca84b5c162b\n IMEI: 353329103207813\n HW version: MP0.3\n RF cal date: 20190214\n Chip name: EXYNOS7885\n Modem board: SHANNON327\n Security patch: 2020-11-01\n Boot Warranty bit: 1\n SIM State: ABSENT\n Rebooting phone... OK\n Waiting ADB device... OK\n Waiting for device to become ready... OK\n Checking Super user right... true\n Root version: 23.0:MAGISKSU\n Checking data... OK\n Searching server... OK\n Checking server answer... OK\n Data preparation... OK\n Initialization zTool... OK\n Running zTool, please wait... OK\n Executing 1st step... OK\n Executing 2nd step... OK\n Searching server... OK\n Waiting for server answer... OK\n Unlocking... OK\n Rebooting phone... OKHello. Repeat operation and post result. We will refund double charged credits.its done , took again 5 crd\n\nCode:\nChecking Login and Password... OK\nBalance: 25 crd.\nYou have 25 credit(s) left. This operation takes 5 credits. Continue?  Yes\nWaiting ADB device... OK\nReading phone info...\nModel: SM-A750FN\nAndroid version: 10\nPDA version: A750FNXXU5CTK1\nCSC version: A750FNOXM5CTK1\nPhone version: A750FNXXU5CTK1\nProduct code: SM-A750FZKNVDI\nCSC country code: SPAIN\nCSC sales code: PHE\nCarrier ID: VDI\nPhone SN: 32009ca84b5c162b\nIMEI: 353329103207813\nHW version: MP0.3\nRF cal date: 20190214\nChip name: EXYNOS7885\nModem board: SHANNON327\nSecurity patch: 2020-11-01\nBoot Warranty bit: 1\nSIM State: NETWORK_LOCKED\nChecking Super user right... true\nRoot version: 23.0:MAGISKSU\nChecking data... OK\nSearching server... OK\nChecking server answer... OK\nData preparation... OK\nInitialization zTool... OK\nRunning zTool, please wait... OK\nExecuting 1st step... OK\nExecuting 2nd step... OK\nSearching server... OK\nWaiting for server answer... OK\nUnlocking... OK\nRebooting phone... OK\n\nDone with Samsung Tool PRO v.45.14 [SM-A750FN,Unlock]Refunded. Check account.Quote:\nOriginally Posted by Z3X\nRefunded. Check account.\ntnx for support , z3x team'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/',
#   'Published at': '09-06-2024',
#   'Title': 'sgh x510 help to unlock',
#   'Content': 'hi team\nany help to unlock network\nno read the phone\nEntering TestMode... Fail - Timeout\nRead info - false\ni changed the cable e700 - e850\nno any conection\n\nthanksHello. Are you using correct cable? Try plug battery during connection and hold power button.Quote:\nOriginally Posted by Z3X\nHello. Are you using correct cable? Try plug battery during connection and hold power button.\nthanks\ni do that but the same problemTry to set lower baud. If still same - check cable, check usb jack...'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/',
#   'Published at': '09-01-2024',
#   'Title': 'SAMSUNG A34 SM-A346E imei repair problem [Answered]',
#   'Content': 'Hello Z3X Team a346e samsung imei repair option not support please add lastest model imei repair supporthttps://forum.gsmhosting.com/vbb/f45...hones-1642694/'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/',
#   'Published at': '08-31-2024',
#   'Title': 'A125U Unlock Error [Answered]',
#   'Content': 'Operation: Unlock\nSelected model: SM-A125U\nSoftware version: 45.14\n\nChecking Login and Password... OK\nBalance: 20 crd.\nYou have 20 credit(s) left. This operation takes 5 credits. Continue? Yes\nWaiting ADB device... OK\nReading phone info... OK\nReading IMEI... error(0)\nModel: SM-A125U\nAndroid version: 12\nPDA version: A125USQU6CWG3\nCSC version: A125UOYN6CWG3\nPhone version: A125USQU6CWG3\nProduct code: SM2A125UZKACHA\nCSC country code: USA\nCSC sales code: CHA\nCarrier ID: CHA\nPhone SN: R58T13CXKBM\nIMEI:\nHW version: REV1.0\nRF cal date: 20220128\nChip name: MT6765\nModem board: MT6765\nSecurity patch: 2023-06-01\nBoot Warranty bit: 0\nSIM State: ABSENT\nThis phone has CSC(CHA) and CarrierId(CHA) and unlock is not supported by this method\n\nDone with Samsung Tool PRO v.45.14 [SM-A125U,Unlock]Hello. SPR only supported atm. Use chekphones: https://z3x-team.com/check-your-phone/'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/',
#   'Published at': '08-29-2024',
#   'Title': 'G991u unlock failed [Answered]',
#   'Content': 'Operation: Unlock\nSelected model: SM-G991U\nSoftware version: 45.14\n\nChecking Login and Password... OK\nBalance: 13 crd.\nYou have 13 credit(s) left. This operation takes 5 credits. Continue? Yes\nWaiting ADB device... OK\nReading phone info... OK\nReading IMEI... error(0)\nModel: SM-G991U\nAndroid version: 12\nPDA version: G991USQU5CVIF\nCSC version: G991UOYN5CVIF\nPhone version: G991USQU5CVIF\nProduct code: SM-G991UZAETMB\nCSC country code: USA\nCSC sales code: TMB\nCarrier ID: TMB\nPhone SN: R5CR12736LD\nIMEI:\nHW version: REV1.0\nRF cal date: 2021.01.27\nChip name: SM8350\nModem board: SM8350\nSecurity patch: 2022-10-01\nBoot Warranty bit: 0\nSIM State: NETWORK_LOCKED,LOADED\nThis phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method\n\nDone with Samsung Tool PRO v.45.14 [SM-G991U,Unlock]Hello.\n\nThis phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method\n\nUse checkphones: https://z3x-team.com/check-your-phone/'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/',
#   'Published at': '08-27-2024',
#   'Title': 'S23 plus direct unlock possible? [Answered]',
#   'Content': 'Hello\nI have a s23 plus "s916" with lock attemps over (carrier lock), is possible to direct unlock or reset attemps ? tanksHello. Not possible atm. Use checkphones: https://z3x-team.com/check-your-phone/'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/',
#   'Published at': '08-26-2024',
#   'Title': 'samsung a226b u9 network lock [Answered]',
#   'Content': 'a226bxxs9dxc1 ned unlock network can i do with z3x and how many crd needHello. Currently this bit not supported. Use checkphones: https://z3x-team.com/check-your-phone/'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/',
#   'Published at': '08-25-2024',
#   'Title': 'Please Update samsungtool with New desing [Answered]',
#   'Content': 'Hello, please Update z3x Samsung tool pro with New desing theme, please add New featuresHello. We working on update.'}]

# %% [markdown]
# ### Summary comments

# %%
summaries = []
try:    
    for i, row in enumerate(data_output):
        text = row[COL_CONTENT]
        summary = genai.search(text)        
        summaries.append(summary)
        sleep(1)
        
except Exception as e:
    logger.error(f'Genai summary: {e}')
# Out:
#  0 ==============================================================
# Summary: Samsung has added several new models to its lineup, including the Galaxy A52, Galaxy Z Flip6 5G, Galaxy Z Fold 5G, Galaxy S21 FE 5G, Galaxy S22 Ultra 5G, Galaxy S23 Ultra 5G, Galaxy S24 Ultra 5G, Galaxy A05s, Galaxy S21 FE 5G, Galaxy S21 5G, Galaxy M23Buddy 2 5G 2022, Galaxy Note 10, Galaxy Tab A7 104 2020, Galaxy J6 Plus, Galaxy M01, and Galaxy M11. These models come with various features such as reading information in EDL normal download mode, resetting FRP in EDL mode, resetting user data in EDL mode, flashing in download mode using normal TAR MD5 firmware, displaying partition information in download mode, and reading phone information and FRP state information in normal mode. However, it is important to note that there is still no NCK available at this time. If you have a UMT card, you can now activate NCK Box Premium v2 on it, allowing you to use it without any shipping costs or limitations. For more information, you can visit the official website, Avengers Box, and UMT Pro. Payment options include credit cards through Stripe gateway, PayPal, Google Pay, and Apple Pay. You can also download the necessary files from the support area. The password for the zip file is 'NckTeam'.
#  1 ==============================================================
# Summary: The text focuses on various Samsung products such as the Galaxy A05s, Galaxy Z Flip4, Galaxy Z Flip5, Galaxy Z Fold5, Galaxy S23, Galaxy S24, and more. It also mentions features like formatting user data in FRP mode, fixing reset Samsung MTK FRP in download mode, and adding read phone information and partition information on download mode. The text includes details about payments through different methods like credit card, PayPal, Google Pay, and Apple Pay. Lastly, it highlights the availability of updates from the official website and shop.
#  2 ==============================================================
# Summary: Samsung's SC9863A chipset has been selected for the action of SimUnlock. The phone needs to be turned off before starting the detection process. To initiate the process, long press the volume up and down keys simultaneously while inserting a USB cable. Keep holding the keys until the booting is complete. Once the device is detected as SPRD U2S Diag COM5, the payload will be sent. It is important to maintain the boot key until the loader starts. The new flashing method has been identified with codes 5f 440A23 5e 9188D8. The file system used is EMMC, which supports reading partition information through the loader. The manufacturer is Mobicel, the brand is Mobicel, the device is Legend_Pro_LTE, and the model is Legend Pro LTE. The build ID is RP1A201005001, the CPU architecture is armeabi-v7a, and the build product name is s9863a1h10_go_32b. The build description is Mobicel_Legend_Pro_LTE_DS_T_L_V01_20220614 11 RP1A201005001 25442 releasekeys. The board is Legend_Pro_LTE, the build ID is RP1A201005001, the Android release is 11, and the Android version is RP1A201005001 releasekeys. The security patch is from 20220505, and the CPU name is SC9863A. The serial number is 50640
#  3 ==============================================================
# Summary: Samsung has made improvements to its Exynos chipset by fixing a bug related to reading exceptionally large PITs from EUB mode. It also added support for new models such as the Samsung Galaxy Tab S6 Lite SMP625, Samsung Galaxy A35 5G SMS356V, Samsung Galaxy A35 5G SMA356N, and Samsung Galaxy Tab S9 FE Plus 5G SMX616N. Additionally, Samsung has improved its Qualcomm chipset with more programmers arriving for various models including the Samsung Galaxy Z Fold3 5G SMF926B, Samsung Galaxy A52s 5G SMA528B, Samsung Galaxy A71 SMA715F, Samsung Galaxy S9 SMG960U, and others. Lastly, Unisoc has made the Repair IMEI procedure safer by identifying specific device details that could prevent the procedure from running properly.
#  4 ==============================================================
# Summary: The updated Read Codes procedure has been enhanced for 150 Samsung models, allowing compatibility with more firmware versions without requiring root access or device disassembly. However, the device must have a Knox warranty status of 0 for the procedure to be effective. Supported models include Samsung Galaxy A04s, A10, A12 Nacho, A13, A14, A2 Core, A20, A20e, A21s, A3 2016, A3 2017, A30, A30s, A33 5G, A40, A50, A50s, A51, A51 5G, A53 5G, A5 2016, A5 2017, A6 2018, A7 2016, A7 2017, A7 2018, A71 5G, A8 2018, F12, F13, F34, F41, F62, J2 Dash, J3 2017, J3 Emerge, J4, J5 2017, J5 Prime, J7 Prime, J7 Prime 2, M12, M13, M33 5G, M34 5G, S10, S10 5G, S10e, S20, S20 FE, S20 5G, S20 Ultra 5G, S21 5G, S21 FE 5G, S21 Ultra 5G, S21 5G, S7, S7 Edge, S8, S8 Plus, S9, S9 Plus, XCover 4, XCover 4s, XCover 5, XCover FieldPro, XCover Pro. Additionally, there have been improvements made to Samsung Qualcomm with support for various models and BIT versions including Samsung Galaxy Z Fold 5, Z Flip 5, S23 Ultra, Z Flip4, A23 5G, Note 20 5G, Note 20 Ultra 5G, S21 Ultra 5G, S22 5G. Similarly, Huawei Qualcomm also received updates with support for multiple models such as Honor 80, Enjoy 60x, Mate 50, Mate 50 RS, Nova 10, Nova 10 Pro, Nova 10 SE, Nova 11, Nova 11 Pro, P60, P60 Art. The solution is compatible with most firmware versions up to Android 13 and some Android 14 firmware versions with security patches from August 2023 onwards. For further information, visit their respective webshops, join telegram groups, like them on Facebook, read help documentation, get support, and stay updated with the latest releases.
#  5 ==============================================================
# Summary: Samsung has released new Exynos and Qualcomm models that support various features such as removing MDM fixes. The supported models include the Samsung Galaxy A02s, A20s (2019), A23, S23 Ultra 5G, and S22 Ultra 5G. Additionally, new models like the Samsung Galaxy A54 5G and Tab S9 FE Plus 5G have been added to the list of supported devices. The software version used for these updates is 39421216, with a release date of May 17, 2024. However, there are still some limitations as this is considered a beta feature and does not work on all devices. For more information or assistance, users can visit the official website or join their telegram channel.
#  6 ==============================================================
# Summary: Samsung has announced support for new Exynos chips including Exynos 7884, Exynos 7884B, Exynos 7885, and Exynos 7904. These solutions utilize the EUB mode for communication with the device, similar to their previous Exynos updates. The supported devices include various Samsung Galaxy smartphones such as the A10e, A10, A20e, A20, A30, A30s, A40, A8 (2018), A7 (2018), Xcover 4, J7 Duo, M10s, M20, M30, Tab A 8.0 (2019), Tab A 10.1 (2019), and Tab A 10.1 (2019 LTE). For more information, users can visit the Supported Models page. Additionally, there is a beta feature available for restoring codes which doesn't work on all devices, but the team is actively working towards full support. The software version used is 39271420, released on May 2nd, 2024. Users can also access the web shop, join the telegram group, like them on Facebook, read help documentation, get support, and become a distributor through GSM Easy or GSM Server. Overall, Chimera Tool is considered one of the best tools in the GSM market, and they have successfully removed FRP from an S21 5G G991B U9 using their auto detect feature.
#  7 ==============================================================
# Summary: The code "Chimera Mobile Phone Utility" version 40740946 was used to delete the FRP partition and clear the FRP lock successfully on September 27, 2024. The operation finished at local time 092724 175944 with WorkID 310126452.
#  8 ==============================================================
# Summary: The user is experiencing an issue with their A9 X110 Binary 3 FRP not working and is seeking assistance. However, it seems that there is currently no solution available for removing the FRP from this particular device. The ChimeraTeam has responded to the user's query, acknowledging their predicament but indicating that they are unable to provide a resolution at present.
#  9 ==============================================================
# Summary: Samsung has successfully removed the MDM PAYJOY lock from the Teclast P40HD UNISOC Tiger T606 device using the Cheetah Tool ProA03 Core A032F. The device's internal storage is 2492GB and it runs on Android version 12 with a security patch date of May 1, 2023. Additionally, the manufacturer of the device is Samsung.
#  10 ==============================================================
# Summary: The text is about a process where the user is waiting for a device to connect through the port 'SPRD U2S DiagCOM19'. The SOC type is mentioned as 'TIGER T606' which might be important information related to the device. After verifying the signature, there was an error while sending loaders with a timeout issue. The user is advised to change the CPU type and try again. This information seems relevant to Samsung since it mentions their device and the connection process.
#  11 ==============================================================
# Summary: "Samsung FRP Bypass and Reset using Cheetah Tool Pro is available for all Qualcomm binaries."
#  12 ==============================================================
# Summary: The text is about the support for Samsung A236EXXU6EFXF3 FRP using a specific tool.
#  13 ==============================================================
# Summary: The user is asking if the Motorola G04 is supported for reading the network unlock code online. They have already tried it, but couldn't find the code. The user also mentions that they are using the Telstra carrier in Australia. The Cheetah team suggests creating a ticket on their website to investigate the issue further.
#  14 ==============================================================
# Summary:
#  15 ==============================================================
# Summary: Fail
#  16 ==============================================================
# Summary: Fail
#  17 ==============================================================
# Summary: Fail
#  18 ==============================================================
# Summary: Fail
#  19 ==============================================================
# Summary: Fail
#  20 ==============================================================
# Summary: Fail
#  21 ==============================================================
# Summary: Fail
#  22 ==============================================================
# Summary: Fail
#  23 ==============================================================
# Summary: Fail
#  24 ==============================================================
# Summary: Fail
#  25 ==============================================================
# Summary: Fail
#  26 ==============================================================
# Summary: Fail
#  27 ==============================================================
# Summary: Fail
#  28 ==============================================================
# Summary: Fail
#  29 ==============================================================
# Summary: Fail
#  30 ==============================================================
# Summary: Fail
#  31 ==============================================================
# Summary: Fail
#  32 ==============================================================
# Summary: Fail
#  33 ==============================================================
# Summary: Fail
#  34 ==============================================================
# Summary: Fail
#  35 ==============================================================
# Summary: Fail
#  36 ==============================================================
# Summary: Fail
#  37 ==============================================================
# Summary: Fail
#  38 ==============================================================
# Summary: Fail
#  39 ==============================================================
# Summary: Fail
#  40 ==============================================================
# Summary: Fail
#  41 ==============================================================
# Summary: Fail
#  42 ==============================================================
# Summary: Fail
#  43 ==============================================================
# Summary: Fail
#  44 ==============================================================
# Summary: Fail
#  45 ==============================================================
# Summary: Fail
#  46 ==============================================================
# Summary: Fail
#  47 ==============================================================
# Summary: Fail
#  48 ==============================================================
# Summary: Fail
#  49 ==============================================================
# Summary: Fail
#  50 ==============================================================
# Summary: Fail
#  51 ==============================================================
# Summary: Fail
#  52 ==============================================================
# Summary: Fail
#  53 ==============================================================
# Summary: Fail
#  54 ==============================================================
# Summary: Fail
#  55 ==============================================================
# Summary: Fail
#  56 ==============================================================
# Summary: Fail
#  57 ==============================================================
# Summary: Fail
#  58 ==============================================================
# Summary: Fail
#  59 ==============================================================
# Summary: Fail
#  60 ==============================================================
# Summary: Fail
#  61 ==============================================================
# Summary: Fail
#  62 ==============================================================
# Summary: Fail
#  63 ==============================================================
# Summary: Fail
#  64 ==============================================================
# Summary: Fail
#  65 ==============================================================
# Summary: Fail
#  66 ==============================================================
# Summary: Fail
#  67 ==============================================================
# Summary: Fail
#  68 ==============================================================
# Summary: Fail
#  69 ==============================================================
# Summary: Fail
#  70 ==============================================================
# Summary: Fail

# %%
for i, row in enumerate(data_output):
    if i<len(summaries):
        row[COL_SUMMARY] = ''.join(summaries[i])
    else:
        row[COL_SUMMARY] = ''

# %% [markdown]
# #### Save data

# %%
data_output
# Out:
# [{'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-module-v0-4-released-14-08-2024-a-3328613/',
#   'Published at': '08-14-2024',
#   'Title': 'Avengers Box / UMTPro Samsung Module v0.4 Released - [14/08/2024]',
#   'Content': 'Added Samsung models\nGalaxy A52 SM-A525M BIT6\nGalaxy Z Flip6 5G SM-F741B BIT1\nGalaxy Z Fold 5G SM-F946B BIT3\nGalaxy S21 FE 5G SM-G990U BITC\nGalaxy S21 FE SM-G990U2 BITA\nGalaxy S22 Ultra 5G SM-S908E BITA\nGalaxy S23 Ultra 5G SM-S918B BIT6\nGalaxy S24 Ultra 5G SM-S928B BIT3\nGalaxy S24 Ultra 5G SM-S928N BIT2\nGalaxy A05s SM-A057F BIT3\nGalaxy S21 FE 5G SM-G990B2 BIT7\nGalaxy S21 5G SM-G991U BIT10\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT6\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT3\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT4\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L BIT5\nGalaxy M23(Buddy 2) 5G 2022 SM-M236L\nGalaxy Note 10+ SM-N975U BIT8\nGalaxy S22 Ultra 5G SM-S908U BIT6\nGalaxy Tab A7 10.4 (2020) SM-T500 BIT8\nGalaxy J6 Plus SM-J610G BIT3\nGalaxy M01 SM-M015G BIT5\nGalaxy M11 SM-M115F BIT3\n\n- Read info in edl normal & download mode,\n- Reset frp in edl mode,\n- Reset userdata in edl mode.\n\nAdded Flashing in download mode using normal tar.md5 firmware.\nAdded read info in download mode (display partitions info).\nAdded read phone info and frp state info in normal mode.\n\n\n\nStill Don’t have NCK ?\n\nDo you have UMT?\n\nNow you can activation NCK Box Premium v2 on UMT Cards\nso you can use it with out shipping costs without limits\n\nOfficial Website:\n\nAvengers Box\nUMT Pro\n\n\nOfficial Shop:\nhttps://fastunlocking.com/shop/en/\n\n\nPayments by\nCredit Card via Stripe gateway\nPaypal\nCredit Card via Paypal\nCredit Card via Google Pay\nCredit Card via Apple Pay\n\n\n\nDownload From Support Area\n\n\nOR\n\nhttps://drive.google.com/file/d/1U6D...usp=drive_link\n\nPassword for Zip:\n\nNckTeam',
#   'Summary': "Samsung has added several new models to its lineup, including the Galaxy A52, Galaxy Z Flip6 5G, Galaxy Z Fold 5G, Galaxy S21 FE 5G, Galaxy S22 Ultra 5G, Galaxy S23 Ultra 5G, Galaxy S24 Ultra 5G, Galaxy A05s, Galaxy S21 FE 5G, Galaxy S21 5G, Galaxy M23Buddy 2 5G 2022, Galaxy Note 10, Galaxy Tab A7 104 2020, Galaxy J6 Plus, Galaxy M01, and Galaxy M11. These models come with various features such as reading information in EDL normal download mode, resetting FRP in EDL mode, resetting user data in EDL mode, flashing in download mode using normal TAR MD5 firmware, displaying partition information in download mode, and reading phone information and FRP state information in normal mode. However, it is important to note that there is still no NCK available at this time. If you have a UMT card, you can now activate NCK Box Premium v2 on it, allowing you to use it without any shipping costs or limitations. For more information, you can visit the official website, Avengers Box, and UMT Pro. Payment options include credit cards through Stripe gateway, PayPal, Google Pay, and Apple Pay. You can also download the necessary files from the support area. The password for the zip file is 'NckTeam'."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/avengers-box-umtpro-samsung-tool-v0-3-released-11-08-2024-a-3327543/',
#   'Published at': '08-11-2024',
#   'Title': 'Avengers Box / UMTPro Samsung Tool v0.3 Released - [11/08/2024]',
#   'Content': 'Samsung\nGalaxy A05s - SM-A05F (Bit 4)\nGalaxy Z Flip4 - SM-F721U (U/U1/W) (BIT6)\nGalaxy Z Flip5 - SM-F731B_DS (BIT2)\nGalaxy Z Flip5 - SM-F731U1 (U/U1/W) (BIT4)\nGalaxy Z Fold5 - SM-F946B_DS (BIT2)\nGalaxy Z Fold5 - SM-F946U (U/U1/W) (BIT4)\nGalaxy Z Fold 6 - SM-F956U (U/U1/W) (BIT1)\nGalaxy S23 - SM-S911U (U/U1/W) (BIT4)\nGalaxy S23+ - SM-S916B_DS (BIT5)\nGalaxy S23 - SM-S916U (U/U1/W) (BIT4)\nGalaxy S23 Ultra SM-S918U (U/U1/W) (BIT4)\nGalaxy S24 - SM-S921U (U/U1/W) (BIT3)\nGalaxy S24+ - SM-S926U (U/U1/W) (BIT3)\nGalaxy S24 Ultra - SM-S928U (U/U1/W) (BIT3)\nGalaxy A71 SM-A716U/W Bit B\nGalaxy A01 (SM-A015M) BIT5\nGalaxy A11 (SM-A115M) BIT3\nGalaxy A23 (SM-A235M) BIT4\nGalaxy S22 Ultra 5G (SM-S908E) BIT8\nGalaxy S10 Lite SM-G770F BIT9\n\nReset FRP in EDL mode\nFormat Userdata in FRP mode\n\nFixed reset Samsung MTK FRP in download mode mode.\nAdded Read phone info and partitions info on download mode.\nBug fixes.\n\n\nOfficial Website:\n\nAvengers Box\nUMT Pro\n\n\nOfficial Shop:\nhttps://fastunlocking.com/shop/en/\n\n\nPayments by\nCredit Card via Stripe gateway\nPaypal\nCredit Card via Paypal\nCredit Card via Google Pay\nCredit Card via Apple Pay\n\n\n\nDownload From Support Area\n\n\nOR\n\nhttps://drive.google.com/file/d/1RB8...usp=drive_link\n\nPassword for Zip:\n\nNckTeamUmt is allway good update but samsung exynos frp NOT updete please... exynos updete...thx..\n\n\n\nBro...\n\nZishanm...Fixed reset Samsung MTK FRP in download mode mode.\n\nis there new way to reset may security patch?Add samsung A715f Bit BAlways good update UMT team',
#   'Summary': 'The text focuses on various Samsung products such as the Galaxy A05s, Galaxy Z Flip4, Galaxy Z Flip5, Galaxy Z Fold5, Galaxy S23, Galaxy S24, and more. It also mentions features like formatting user data in FRP mode, fixing reset Samsung MTK FRP in download mode, and adding read phone information and partition information on download mode. The text includes details about payments through different methods like credit card, PayPal, Google Pay, and Apple Pay. Lastly, it highlights the availability of updates from the official website and shop.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f820/mobicel-legend-pro-simunlock-done-3323729/',
#   'Published at': '07-31-2024',
#   'Title': 'Mobicel Legend Pro SimUnlock Done',
#   'Content': 'Code:\nSELECTED: SC9863A\nACTION:  SimUnlock\nStart Detect phone.\nPhone must be off(you can service this phone without battery also).\nLong press "VOL -"+ "VOL +" key while inserting usb cable.\nKeep key untill boot complete.\nDetected: SPRD U2S Diag (COM5)\nSending payload, keep boot key untill loader start.\nExploiting phone.....\nSending preloader 1\nSending preloader 2\nSending FDL 1.....\nSending FDL 2.....\nNew flash metod detected.\n[5f] 440A23 [5e] 9188D8\nUID: A0XS0B_6_17_88\nFileSystem: EMMC\nRead partition info is supported by loader.\n***************\n[S]Manufacturer: Mobicel\n[S]Brand: Mobicel\n[S]Device: Legend_Pro_LTE\n[S]Model: Legend Pro LTE\nBuild ID: RP1A.201005.001\nCPU arhitecture: armeabi-v7a\nBuild product name: s9863a1h10_go_32b\nBuild description: Mobicel_Legend_Pro_LTE_DS_T_L_V01_20220614 11 RP1A.201005.001 25442 release-keys\nBoard: Legend_Pro_LTE\nBuild Id: RP1A.201005.001\nAndroid Release: 11\nAndroid Version: RP1A.201005.001 release-keys\nSecurity patch: 2022-05-05\nCPU NAME: SC9863A\nSN: 5064041265071905\nFound [l_fixnv1_a] [l_fixnv1_a] Size to download: 2 MB\nReading: l_fixnv1_a 200000\nLength: 100000 chk: 6253 calculated chk: 6252 calculated chk_32: 6253\nIMEI 1: 352594560613172\nIMEI 2: 352594560613180\nIMEI 3: 867400020316638\nIMEI 4: 867400020316646\nSimlock Type: 3\n \nSimlock Status:\nSIMLOCK: ACTIVE\nNETWORK SUBNET: INACTIVE\nSP LOCK: INACTIVE\nCORPORATE: INACTIVE\nUSER LOCK: INACTIVE\n[3]Simlock Type: 0  0\n[352594560613172] Unlock code: 87316483\n[352594560613180] Unlock code: 87316493\nWarning, this is factory key, some opperators can modify factory key.\nReading: prodnv\nReading: miscdata\nReading: l_fixnv1_a\nReading: l_fixnv2_a\nReading: l_fixnv1_b\nReading: l_fixnv2_b\nBackup saved to: C:\\Avengers\\spreadtrum_module\\spreadtrum_module_backup_folder\\flashmode_security_backup\\SC9863A_Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_l_fixnv1_a_nvram_backup.tar\nPhone have empty sign array, can be empty efuse or erased nv.\nStart write unlock, wait...\n[l_runtimenv1]Format OK.\n[l_runtimenv2]Format OK.\nWrite[0]\nWrite[1]\n[can take 0-10 sec]Wait untill phone restart.\nExe version: Avengers Unisoc Module 2.3.1\nLog saved:\nC:\\Avengers\\spreadtrum_module\\spreadtrum_module_backup_folder\\Saved_Logs\\Mobicel_RP1A_201005_001_release-keys_352594560613172_352594560613180_sim_unlock_phone.txt\nTotal Time: 00:01:29\nDone.',
#   'Summary': "Samsung's SC9863A chipset has been selected for the action of SimUnlock. The phone needs to be turned off before starting the detection process. To initiate the process, long press the volume up and down keys simultaneously while inserting a USB cable. Keep holding the keys until the booting is complete. Once the device is detected as SPRD U2S Diag COM5, the payload will be sent. It is important to maintain the boot key until the loader starts. The new flashing method has been identified with codes 5f 440A23 5e 9188D8. The file system used is EMMC, which supports reading partition information through the loader. The manufacturer is Mobicel, the brand is Mobicel, the device is Legend_Pro_LTE, and the model is Legend Pro LTE. The build ID is RP1A201005001, the CPU architecture is armeabi-v7a, and the build product name is s9863a1h10_go_32b. The build description is Mobicel_Legend_Pro_LTE_DS_T_L_V01_20220614 11 RP1A201005001 25442 releasekeys. The board is Legend_Pro_LTE, the build ID is RP1A201005001, the Android release is 11, and the Android version is RP1A201005001 releasekeys. The security patch is from 20220505, and the CPU name is SC9863A. The serial number is 50640"},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/26-09-2024-samsung-qualcomm-exynos-unisoc-improvements-2819592/',
#   'Published at': '09-27-2024',
#   'Title': '⭐️26/09/2024⭐️Samsung (Qualcomm, Exynos) and Unisoc improvements',
#   'Content': "Samsung (Qualcomm, Exynos) and Unisoc improvements\n\n\n\nSamsung Exynos Improvements\nFixed a bug when reading exceptionally large PITs from EUB mode.\nNew models were added to be supported from EUB mode:\nSamsung Galaxy Tab S6 Lite (SM-P625)\nSamsung Galaxy A35 5G (SM-S356V)\nSamsung Galaxy A35 5G (SM-A356N)\nSamsung Galaxy Tab S9 FE Plus 5G (SM-X616N)\n\nAvailable procedures (may vary device to device): Restore / Store Backup, Unlock / Relock Bootloader, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Set KnoxGuard State, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset, Patch KnoxGuard, Get Info, Reset Battery Status.\n\n\nSamsung Improvements\n\nWe've added the Network Factory Reset (Online) procedure for the following new Japanese au KDDI models via ADB mode:\nSamsung Galaxy S23 FE 5G (SCG24)\nSamsung Galaxy S24 Ultra (SCG26)\n\n\nSamsung Qualcomm Improvements\n\nMore new programmers have arrived for Samsung Qualcomm.\n\nThe following models and BIT versions are supported:\nSamsung Galaxy Z Fold3 5G (SM-F926B) BIT8\nSamsung Galaxy A52s 5G (SM-A528B) BIT9\nSamsung Galaxy A71 (SM-A715F) BITB\nSamsung Galaxy S9 (SM-G960U) BIT9\nSamsung Galaxy S22 5G (SM-S901E) BITA\nSamsung Galaxy A70s (SM-A707F) BIT3\nSamsung Galaxy M40 (SM-M405F) BIT2\nSamsung Galaxy S20 FE (SM-G780G) BITC\nSamsung Galaxy S10 (SM-G973U) BIT9\nSamsung Galaxy Note10+ 5G (SM-N976U) BIT6\nSamsung Galaxy S23+ 5G (SM-S916N) BIT4\n\nOn the devices above, the following procedures are now available: Factory Reset, Remove FRP, Get Info, Remove FMM, Remove MDM, Repair Boot, Root, Repair Serial, CSC Change, Remove Knoxguard (*), Reset Battery Status.\n\n*: The solution works until the February 2024 security update.\n\n\nUnisoc Improvements\n\nWe made the Repair IMEI procedure safer by identifying further device details that would make the procedure unable to run properly. In these cases, the Repair IMEI procedure is disabled.\n\n\nSoftware version: 40.74.0946\nRelease date: 26 september 2024\n\n\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comwhat an unique update..\nnow this is what we called update.\nthanks team\n\none question\nCode:\nOppo EDL mode flash – ofp, ops files are now supported\nlatest .ofp supported? or only oldthanks chimera team....keep it* up-\n\ndid u support root android 9\n\nwhat mtk device did u support for rooting??The phone is in an invalid state, please reconnect the USB cable and reboot it manually!\n\nWorkID: 92626404good update, next update remember to surport samsung andriod 9pie frp unlocking ;;;;;",
#   'Summary': 'Samsung has made improvements to its Exynos chipset by fixing a bug related to reading exceptionally large PITs from EUB mode. It also added support for new models such as the Samsung Galaxy Tab S6 Lite SMP625, Samsung Galaxy A35 5G SMS356V, Samsung Galaxy A35 5G SMA356N, and Samsung Galaxy Tab S9 FE Plus 5G SMX616N. Additionally, Samsung has improved its Qualcomm chipset with more programmers arriving for various models including the Samsung Galaxy Z Fold3 5G SMF926B, Samsung Galaxy A52s 5G SMA528B, Samsung Galaxy A71 SMA715F, Samsung Galaxy S9 SMG960U, and others. Lastly, Unisoc has made the Repair IMEI procedure safer by identifying specific device details that could prevent the procedure from running properly.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/01-08-2024-samsung-read-codes-solution-qualcomm-improvements-3322327/',
#   'Published at': '08-25-2024',
#   'Title': '⭐️01/08/2024⭐️Samsung Read Codes solution and Qualcomm Improvements',
#   'Content': "Samsung Read Codes solution and Qualcomm Improvements\n\nEnhanced Samsung solution with updated Read Codes procedure for 150 Samsung models\n\nWe are excited to announce that the updated Read Codes procedure is now compatible with more firmware versions than ever(*). This method does not require root access or device disassembly, making it more convenient for you. Please note that the device must have a Knox warranty status of 0, as the procedure will not work if the warranty is voided.\n\nThe updated Read Codes procedure is supported for the following models:\nSamsung Galaxy A04s (SM-A047F, SM-A047M)\nSamsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M)\nSamsung Galaxy A12 Nacho (SM-A127F, SM-A127M)\nSamsung Galaxy A13 (SM-A135F, SM-A135M)\nSamsung Galaxy A14 (SM-A145F, SM-A145M, SM-A145FB, SM-A145MB)\nSamsung Galaxy A2 Core (SM-A260F, SM-A260G)\nSamsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205YN)\nSamsung Galaxy A20e (SM-A202F)\nSamsung Galaxy A21s (SM-A217F, SM-A217M)\nSamsung Galaxy A3 (2016) (SM-A310F, SM-A310M, SM-A310Y)\nSamsung Galaxy A3 (2017) (SM-A320F, SM-A320FL, SM-A320Y)\nSamsung Galaxy A30 (SM-A305F, SM-A305FN, SM-A305G, SM-A305GN, SM-A305GT, SM-A305YN)\nSamsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)\nSamsung Galaxy A33 5G (SM-A336B, SM-A336E, SM-A336M)\nSamsung Galaxy A40 (SM-A405F, SM-A405FM, SM-A405FN)\nSamsung Galaxy A50 (SM-A505F, SM-A505FM, SM-A505FN, SM-A505G, SM-A505GN, SM-A505GT, SM-A505YN)\nSamsung Galaxy A50s (SM-A507FN)\nSamsung Galaxy A51 (SM-A515F)\nSamsung Galaxy A51 5G (SM-A516B)\nSamsung Galaxy A53 5G (SM-A536B, SM-A536E)\nSamsung Galaxy A5 (2016) (SM-A510F, SM-A510M, SM-A510Y)\nSamsung Galaxy A5 (2017) (SM-A520F)\nSamsung Galaxy A6 (2018) (SM-A600F, SM-A600FN, SM-A600G, SM-A600GN)\nSamsung Galaxy A7 (2016) (SM-A710F, SM-A710M, SM-A710Y)\nSamsung Galaxy A7 (2017) (SM-A720F)\nSamsung Galaxy A7 (2018) (SM-A750F, SM-A750FN, SM-A750G, SM-A750GN)\nSamsung Galaxy A71 5G (SM-A716B)\nSamsung Galaxy A8 (2018) (SM-A530F)\nSamsung Galaxy A8+ (2018) (SM-A730F)\nSamsung Galaxy F12 (SM-F127G)\nSamsung Galaxy F13 (SM-E135F)\nSamsung Galaxy F34 (SM-E346B)\nSamsung Galaxy F41 (SM-F415F)\nSamsung Galaxy F62 (SM-E625F)\nSamsung Galaxy J2 Dash (SM-J260A, SM-J260AZ, SM-J260F, SM-J260G, SM-J260M)\nSamsung Galaxy J3 (2017) (SM-J330F, SM-J330FN, SM-J330G, SM-J330L)\nSamsung Galaxy J3 Emerge (SM-J327A, SM-J327AZ)\nSamsung Galaxy J4 (SM-J400F, SM-J400G, SM-J400M)\nSamsung Galaxy J5 (2017) (SM-J530F, SM-J530FM, SM-J530G, SM-J530GM, SM-J530Y, SM-J530YM)\nSamsung Galaxy J5 Prime (SM-G570F, SM-G570M, SM-G570Y)\nSamsung Galaxy J7 Prime (SM-G610F, SM-G610M, SM-G610Y)\nSamsung Galaxy J7 Prime 2 (SM-G611F, SM-G611FF, SM-G611M, SM-G611MT)\nSamsung Galaxy M12 (SM-M127F, SM-M127G)\nSamsung Galaxy M13 (SM-M135F, SM-M135FU, SM-M135M)\nSamsung Galaxy M33 5G (SM-M336B, SM-M336BU)\nSamsung Galaxy M34 5G (SM-M346B, SM-M346B1, SM-M346B2)\nSamsung Galaxy S10 (SM-G973F)\nSamsung Galaxy S10+ (SM-G975F)\nSamsung Galaxy S10 5G (SM-G977B)\nSamsung Galaxy S10e (SM-G970F)\nSamsung Galaxy S20 (SM-G980F)\nSamsung Galaxy S20 5G (SM-G981B)\nSamsung Galaxy S20 FE (SM-G780F)\nSamsung Galaxy S20+ (SM-G985F)\nSamsung Galaxy S20+ 5G (SM-G986B)\nSamsung Galaxy S20 Ultra 5G (SM-G988B)\nSamsung Galaxy S21 5G (SM-G991B)\nSamsung Galaxy S21 FE 5G (SM-G990E)\nSamsung Galaxy S21 Ultra 5G (SM-G998B)\nSamsung Galaxy S21+ 5G (SM-G996B)\nSamsung Galaxy S7 (SM-G930F)\nSamsung Galaxy S7 Edge (SM-G935F)\nSamsung Galaxy S8 (SM-G950F)\nSamsung Galaxy S8+ (SM-G955F)\nSamsung Galaxy S9 (SM-G960F)\nSamsung Galaxy S9+ (SM-G965F)\nSamsung Galaxy XCover 4 (SM-G390F, SM-G390Y)\nSamsung Galaxy XCover 4s (SM-G398FN)\nSamsung Galaxy XCover 5 (SM-G525F)\nSamsung Galaxy XCover FieldPro (SM-G889F, SM-G889G, SM-G889YB)\nSamsung Galaxy XCover Pro (SM-G715FN)\n\nSamsung Qualcomm Improvements\n\nMore new programmers have arrived for Samsung Qualcomm.\n\nThe following models and BIT versions are supported:\nSamsung Galaxy Z Fold 5 ...
#   'Summary': 'The updated Read Codes procedure has been enhanced for 150 Samsung models, allowing compatibility with more firmware versions without requiring root access or device disassembly. However, the device must have a Knox warranty status of 0 for the procedure to be effective. Supported models include Samsung Galaxy A04s, A10, A12 Nacho, A13, A14, A2 Core, A20, A20e, A21s, A3 2016, A3 2017, A30, A30s, A33 5G, A40, A50, A50s, A51, A51 5G, A53 5G, A5 2016, A5 2017, A6 2018, A7 2016, A7 2017, A7 2018, A71 5G, A8 2018, F12, F13, F34, F41, F62, J2 Dash, J3 2017, J3 Emerge, J4, J5 2017, J5 Prime, J7 Prime, J7 Prime 2, M12, M13, M33 5G, M34 5G, S10, S10 5G, S10e, S20, S20 FE, S20 5G, S20 Ultra 5G, S21 5G, S21 FE 5G, S21 Ultra 5G, S21 5G, S7, S7 Edge, S8, S8 Plus, S9, S9 Plus, XCover 4, XCover 4s, XCover 5, XCover FieldPro, XCover Pro. Additionally, there have been improvements made to Samsung Qualcomm with support for various models and BIT versions including Samsung Galaxy Z Fold 5, Z Flip 5, S23 Ultra, Z Flip4, A23 5G, Note 20 5G, Note 20 Ultra 5G, S21 Ultra 5G, S22 5G. Similarly, Huawei Qualcomm also received updates with support for multiple models such as Honor 80, Enjoy 60x, Mate 50, Mate 50 RS, Nova 10, Nova 10 Pro, Nova 10 SE, Nova 11, Nova 11 Pro, P60, P60 Art. The solution is compatible with most firmware versions up to Android 13 and some Android 14 firmware versions with security patches from August 2023 onwards. For further information, visit their respective webshops, join telegram groups, like them on Facebook, read help documentation, get support, and stay updated with the latest releases.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/17-05-2024-samsung-new-exynos-qcomm-models-remove-mdm-fix-3305137/',
#   'Published at': '08-08-2024',
#   'Title': '⭐️17/05/2024⭐️Samsung: New Exynos & QComm models + Remove MDM Fix',
#   'Content': "Samsung: New Exynos & QComm models + Remove MDM Fix\n\nMore new programmers have arrived for Samsung Qualcomm. The following models and BIT versions are supported:\nSamsung Galaxy A02s (SM-A025M BIT8)\nSamsung Galaxy A20s 2019 (SM-A207F BIT5)\nSamsung Galaxy A20s 2019 (SM-A207M BIT4)\nSamsung Galaxy A23 (SM-A235M BIT5)\nSamsung Galaxy S23 Ultra 5G (SM-S918B BIT4)\nSamsung Galaxy S22 Ultra 5G (SM-S908E BIT8)\n\nSamsung Exynos\n\nThe following new models were added to be supported from EUB mode:\nSamsung Galaxy A54 5G (SCG21)\nSamsung Galaxy Tab S9 FE Plus 5G (SCT22)\nSamsung Galaxy Tab A 8.4 2020 (SM-T307U)\n\nAvailable procedures: Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (*), Unlock / Relock Bootloader (**) For more detailed information, please visit our Supported models page.\n\n*: if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.\n**: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.\n\n\nBugfixes\nFixed a bug in Remove MDM procedure which could cause application crashes for Samsung Exynos devices\n\nSoftware version: 39.42.1216\nRelease date: 17 may 2024\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comYou make life easy for us King of Exynos\n\nBest Regards | YobaThanks for the useful and fast updates Samsung A12 (A127) please added Switch to EUB procedure ( from ODIN mode)after frp remove its struck eub mode, how to exit eub modeDear User,\n\n\n\n\nPlease run a Repair Boot/ Unbrick on the device and it will boot into normal mode.\n\n\nRegards,\nChimeraTeam\n\n\n\nQuote:\nOriginally Posted by cellcare prasad\nafter frp remove its struck eub mode, how to exit eub mode",
#   'Summary': 'Samsung has released new Exynos and Qualcomm models that support various features such as removing MDM fixes. The supported models include the Samsung Galaxy A02s, A20s (2019), A23, S23 Ultra 5G, and S22 Ultra 5G. Additionally, new models like the Samsung Galaxy A54 5G and Tab S9 FE Plus 5G have been added to the list of supported devices. The software version used for these updates is 39421216, with a release date of May 17, 2024. However, there are still some limitations as this is considered a beta feature and does not work on all devices. For more information or assistance, users can visit the official website or join their telegram channel.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/02-05-2024-exynos-7884-7884b-7885-7904-54-models-no-root-any-bit-version-knox-3302113/',
#   'Published at': '08-01-2024',
#   'Title': '⭐️02/05/2024⭐️Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit/Version/Knox',
#   'Content': "New Exynos 7884/7884B/7885/7904 - 54 models - No Root, Any Bit, Any Version, Any Knox\n\n\n\nWe haven't finished yet! This time we're thrilled to introduce support for\nExynos 7884\nExynos 7884B\nExynos 7885\nExynos 7904\n\nThis solution is similar to our previous Exynos update in that it uses the EUB mode* to communicate with the device.\n\n\nThe following devices are supported:\nSamsung Galaxy A10e (SM-A102N, SM-A102U, SM-A102U1, SM-A102W, SM-S102DL)\nSamsung Galaxy A10 (SM-A105F, SM-A105FN, SM-A105G, SM-A105M, SM-A105N)\nSamsung Galaxy A20e (SM-A202F, SCV46)\nSamsung Galaxy A20 (SM-A205F, SM-A205FN, SM-A205G, SM-A205GN, SM-A205S, SM-A205W, SM-A205YN, SM-S205DL)\nSamsung Galaxy A30 (SM-A3050, SM-A3058, SM-A305F, SM-A305FN, SM-A305GT, SM-A305N, SM-A305YN, SCV43)\nSamsung Galaxy A30s (SM-A307FN, SM-A307G, SM-A307GN, SM-A307GT)\nSamsung Galaxy A40 (SM-A405FM SM-A405FN, SM-A405S)\nSamsung Galaxy A8 2018 (SM-A530F, SM-A530W)\nSamsung Galaxy A7 2018 (SM-A750C, SM-A750F, SM-A750FN, SM-A750N)\nSamsung Galaxy Xcover 4 (SM-G398FN)\nSamsung Galaxy J7 Duo (SM-J720F, SM-J720M)\nSamsung Galaxy M10s (SM-M107F)\nSamsung Galaxy M20 (SM-M205G, SM-M205M)\nSamsung Galaxy M30 (SM-M305F, SM-M305M)\nSamsung Galaxy Tab A 8.0 2019 (SM-P205)\nSamsung Galaxy Tab A 10.1 2019 (SM-T515, SM-T515N)\nSamsung Galaxy Tab A 10.1 2019 LTE (SM-T517, SM-T517P)\n\nAvailable procedures:Restore / Store Backup, CSC Change, Repair Serial, Factory Reset, Remove FMM, Remove FRP, Knoxguard Remove, Remove Lost Mode, Remove Common Criteria, Remove MDM, Remove Warnings, Restore Security Backup, Read Codes, Network Factory Reset (**), Unlock / Relock Bootloader (***)\n\n\nFor more detailed information, please visit our Supported models page.\n\nIf you'd like to see this working check out our videos:\nRepair Serial\n... or our two YouTube channel where you can find various educational content: ChimeraTool and ChimeraToolES.\n\n\n\n*: In most cases, it's necessary to disassemble the phone and use hardware-testpoints to put the phone into EUB mode. Visit our guides here and our Test Point Database to learn more.\n**:if Read Codes is not available on your device, please try Network Factory Reset (if the procedure button is visible) to achieve the same functionality. There are devices where none is available.\n***: This is a beta feature, and it doesn't work on 100% of the devices, but our team is working on fully supporting the procedure.\n\n\n\n\nSoftware version: 39.27.1420\nRelease date: 02 may 2024\n\n\n\n\nVisit our Webshop: https://chimeratool.com/shop\nJoin our Telegram: https://t.me/chimeratool_offical\nLike us on Facebook: https://www.facebook.com/chimeratool\n\nRead our Help & Documentation: https://chimeratool.com/docs\nGet Support: https://chimeratool.com/contact\n\nGsmEasy Distributor: http://www.imei.us\nGsmServer Distributor: http://www.gsmserver.comchimera KING samsung tool\nvery nicechimera is best tool in gsm markitPlease add remove mdm lock on A042F via preloader mode in next update...you are the best and yes you are the king of samsung tools go ahead.\n\nHer is the successful auto-detect and remove log of FRP S21 5G G991B U9\nCode:\n Chimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02 \nIdentify\nConnecting to the phone...\nGathering information...\nPreparing phone...\nDownloading required files...\nProcessing files...\nCommunicating with the phone...\nRebooting\nThis may take a while. \nBe patient! Do NOT disconnect the phone! \nSuccessfully finished. \nFinished at local time: [05.02.24 11:08:35] \nWorkID: 274074432\nCode:\nChimera Mobile Phone Utility version: 39.25.1235 @ 2024-05-02 \nPrinting phone history\n\nAuto Detect\n5/2/2024\n8:13\nAM\n\nFRP Remove\nSuccessfully finished. \nFinished at local time: [05.02.24 11:08:50] \nWorkID: 274074529",
#   'Summary': "Samsung has announced support for new Exynos chips including Exynos 7884, Exynos 7884B, Exynos 7885, and Exynos 7904. These solutions utilize the EUB mode for communication with the device, similar to their previous Exynos updates. The supported devices include various Samsung Galaxy smartphones such as the A10e, A10, A20e, A20, A30, A30s, A40, A8 (2018), A7 (2018), Xcover 4, J7 Duo, M10s, M20, M30, Tab A 8.0 (2019), Tab A 10.1 (2019), and Tab A 10.1 (2019 LTE). For more information, users can visit the Supported Models page. Additionally, there is a beta feature available for restoring codes which doesn't work on all devices, but the team is actively working towards full support. The software version used is 39271420, released on May 2nd, 2024. Users can also access the web shop, join the telegram group, like them on Facebook, read help documentation, get support, and become a distributor through GSM Easy or GSM Server. Overall, Chimera Tool is considered one of the best tools in the GSM market, and they have successfully removed FRP from an S21 5G G991B U9 using their auto detect feature."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/samsung-galaxy-a11-sm-a115f-frp-s6-12-remove-done-test-point-3339180/',
#   'Published at': '09-28-2024',
#   'Title': 'Samsung Galaxy A11 SM-A115F FRP S6 12 REMOVE DONE TEST POINT',
#   'Content': 'Code:\nChimera Mobile Phone Utility version: 40.74.0946 @ 2024-09-27\nDelete FRP partition\nClearing FRP lock\nSuccessfully finished.\nFinished at local time: [09.27.24 17:59:44]\nWorkID: 310126452',
#   'Summary': 'The code "Chimera Mobile Phone Utility" version 40740946 was used to delete the FRP partition and clear the FRP lock successfully on September 27, 2024. The operation finished at local time 092724 175944 with WorkID 310126452.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f898/samsung-tab-a9-x110-u3-frp-3339095/',
#   'Published at': '09-27-2024',
#   'Title': 'samsung tab a9 x110 u3 frp',
#   'Content': 'a9 x110 binary 3 frp not workingDear User,\n\n\nUnfortunately, we do not have a solution to remove the FRP from this device.\n\n\nRegards,\nChimeraTeam\n\n\n\nQuote:\nOriginally Posted by raoul plus\na9 x110 binary 3 frp not working',
#   'Summary': "The user is experiencing an issue with their A9 X110 Binary 3 FRP not working and is seeking assistance. However, it seems that there is currently no solution available for removing the FRP from this particular device. The ChimeraTeam has responded to the user's query, acknowledging their predicament but indicating that they are unable to provide a resolution at present."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/successfully-flashed-repair-unlocked-phones-cheetah-tool-pro-3236486/',
#   'Published at': '09-16-2024',
#   'Title': 'Successfully Flashed|Repair|Unlocked Phones With Cheetah Tool Pro',
#   'Content': 'Teclast P40HD (UNISOC Tiger T606)\nFRP Done with Cheetah Tool ProA03 Core (A032F)\n\nMdm Payjoy remved sucessfully.\n\nWaiting for device...\nConnecting port: SPRD U2S Diag (COM9)\nSoc Type : #SC9863A\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Okay\n\nAnalysis Security... Okay\n\nGetting Device info... Okay\n● Model Name: SM-A032F\n● Product Name: a3corexx\n● Manufacturer: samsung\n● Android Version: 12\n● Security Patch: 2023-05-01\n● Build ID: SP1A.210812.016\n● Display ID: SP1A.210812.016.A032FXXU3BWF2\n● Build Date: Mon Jun 19 21:28:03 KST 2023\n● Build: A032FXXU3BWF2\nGetting Storage info... Okay\n● Device Internal Storage: 24.92 GB\n● Userdata Crypto State: Encrypted?\n\n\nRemove MDM LOCK... Okay\nWipe frp lock... Okay\n\nReboot... Okay\n\n● Total Time Elapsed: 26 secs, 610 msecsAlcatel 9009G Frp Sucessfully Removed\n\n\n\nWaiting for brom usb device...\nDownload port: MediaTek USB Port_V1633 (COM10)\n\nGetting Device... Okay\nHandshake Device... Okay\n● CPU Model: MT6580\nGetting Device Config... Okay\nDetect Security!\nReading bootloader...\nBypass SLA Protection...\nBypass sec protection... Okay\nDump emi config... OkayOkay\n\nSending Loader... Okay\nGetting Chip info... Okay\nGetting device Synchronized... Okay\nInitiate RAM... Okay\nSending DL Config... OkayOkay\n\nEMMC_INFO:\n● EMMC_BOOT1: 4.00 MB\n● EMMC_BOOT2: 4.00 MB\n● EMMC_RPMB: 4.00 MB\n● EMMC_USER: 7.28 GB\n● EMMC_ID: 8801034E4361726420012B0F472F5567\nRAM_INFO:\n● IN_SRAM: 128.00 KB\n● EXT_DRAM: 1.00 GB\n\nSwitch to High Speed Port... Okay\n\nReading Partitions Table... Okay\nGetting Device info... Okay\n● Brand Name: TCL\n● Model Name: 9009G\n● Product Name: 9009G\n● Manufacturer: TCL\n● Android Version: 8.1.0 (Oreo)\n● Security Patch: 2019-06-05\n● Build ID: O11019\n● Build Date: Mon Aug 12 20:11:35 CST 2019\n● Build: vJ65-0\nGetting Storage info... Okay\n● Device Internal Storage: 5.22 GB\n● Userdata Crypto State: Encrypted?\n\nReset FRP Lock... Okay\n\nRebooting... Okay\n\n● Total Time Elapsed: 135 msecs\n\nWorkID: 2733990Mobicel R1 Plus 7731e FRP Remove Done\n\n\nCode:\nWaiting for device... \nConnecting port: SPRD U2S Diag (COM5)\nSoc Type :  #SC7731E\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Okay\n\nAnalysis Security... Okay\n\nGetting Device info... Okay\n ●  Model Name: R1PLUS_1\n ●  Product Name: R1PLUS_1\n ●  Manufacturer: Mobicel\n ●  Android Version: 10 (Android 10)\n ●  Security Patch: 2022-10-05\n ●  Build ID: QP1A.190711.020\n ●  Display ID: Mobicel_R1PLUS_1_DS_T_V14_20221109_MP\n ●  Build Date: Wed Nov  9 11:22:31 CST 2022\n ●  Build: 1667964169\nGetting Storage info... Okay\n ● Device Internal Storage: 11.83 GB\n ● Userdata Crypto State: Encrypted?\n\n\nReset frp lock... Okay\n\nReboot... Okay\n\n ● Total Time Elapsed: 31 secs, 813 msecs\n\nWorkID: 2914083Mobicel MX2 IMEI Repair Done\n\n\nCode:\nWaiting for device... \nConnecting port: SPRD U2S Diag (COM21)\nSoc Type :  #SC7731E\nGetting identity... Okay\nReboot to diag... Okay\nWait for diag device... \nGetting identity... Okay\nRead device info... Okay\n ● Platform Version: MOCORTM_17C_W21.14.6_DEBUG\n ● Project Version: PIKE2_PUB\n ● BASE  Version: FM_BASE_17C_W21.14.6\n ● HW Version: SC7731E_MODEM\n ● 04-10-2021 02: 00\nChecking new imei... Okay\n ●  New IMEI1: 350xxxxxxxxxxxxx\n ●  New IMEI2: 33xxxxxxxxxxxxxx\nRepairing imei... Okay\n\n ● Total Time Elapsed: 17 secs, 950 msecs',
#   'Summary': "Samsung has successfully removed the MDM PAYJOY lock from the Teclast P40HD UNISOC Tiger T606 device using the Cheetah Tool ProA03 Core A032F. The device's internal storage is 2492GB and it runs on Android version 12 with a security patch date of May 1, 2023. Additionally, the manufacturer of the device is Samsung."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/blu-g73-unlock-fail-spectrum-3337114/',
#   'Published at': '09-17-2024',
#   'Title': 'Blu G73 unlock fail Spectrum',
#   'Content': 'Waiting for device...\nConnecting port: SPRD U2S Diag(COM19)\nSoc Type : #TIGER T606\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Failed\n[PORT ERR] READ TIMED OUTQuote:\nOriginally Posted by hector bermudez\nWaiting for device...\nConnecting port: SPRD U2S Diag(COM19)\nSoc Type : #TIGER T606\nGetting identity... Okay\nHandshaking... Okay\nSending data... Okay\n\nVerify Signature... Okay\nSending Loaders... Failed\n[PORT ERR] READ TIMED OUT\nHello dear user\nplease change cpu type and try\nB.R Cheetah team',
#   'Summary': "The text is about a process where the user is waiting for a device to connect through the port 'SPRD U2S DiagCOM19'. The SOC type is mentioned as 'TIGER T606' which might be important information related to the device. After verifying the signature, there was an error while sending loaders with a timeout issue. The user is advised to change the CPU type and try again. This information seems relevant to Samsung since it mentions their device and the connection process."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/all-samsung-frp-bypass-samsung-frp-reset-cheetah-tool-pro-3293983/',
#   'Published at': '09-07-2024',
#   'Title': 'All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro',
#   'Content': 'All Samsung FRP bypass: Samsung FRP Reset with Cheetah Tool Pro\n\n\n\nhttp://www.youtube.com/watch?v=_cVmDwwGf-Athank you for your shareQualcom all binaries supported brother?',
#   'Summary': '"Samsung FRP Bypass and Reset using Cheetah Tool Pro is available for all Qualcomm binaries."'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/samsung-a236e-u6-frp-3335021/',
#   'Published at': '09-07-2024',
#   'Title': 'Samsung A236E U6 FRP',
#   'Content': 'Dear supporters,Samsung A236EXXU6EFXF3 FRP Supported this tool?',
#   'Summary': 'The text is about the support for Samsung A236EXXU6EFXF3 FRP using a specific tool.'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1146/motorola-g04-read-network-unlock-code-online-3333554/',
#   'Published at': '09-04-2024',
#   'Title': 'Motorola G04 read network unlock code online?',
#   'Content': 'is Motorola G04 supported for "read network unlock code online?\nI tried but code not foundHello dear user\nwhich carrier?\nB.R Cheetah teamCarrier: Telstra AustraliaQuote:\nOriginally Posted by mtb116\nCarrier: Telstra Australia\nPlease create ticket on cheetah-tool.com\nand post your imei\nwe check your problem\nB.R Cheetah teamTicket created and imei posted on your site',
#   'Summary': "The user is asking if the Motorola G04 is supported for reading the network unlock code online. They have already tried it, but couldn't find the code. The user also mentions that they are using the Telstra carrier in Australia. The Cheetah team suggests creating a ticket on their website to investigate the issue further."},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1004/xiaomi-bootloader-unlock-tool-3337265/',
#   'Published at': '09-18-2024',
#   'Title': 'Xiaomi bootloader unlock tool',
#   'Content': 'I need to unlock my (m190f7i) redmi note7 levender\ncan anybody hlp/guid me on this?Sorry, but we do not support any of Xiaomi devices.',
#   'Summary': ''},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f672/samsung-a71-a715f-frp-done-easyjtag-pinout-3338855/',
#   'Published at': '09-25-2024',
#   'Title': 'Samsung A71 A715f FRp Done EasyJtag PinOut',
#   'Content': "Reset Google FRP v2.0\n\nSearch Google FRP Partition..\nPartition #15 - 'PERSISTENT' is FRP.\nErasing Partition. Please Wait..\nErasing Done\nBackup Saved as: C:\\Users\\E...\\Downloads\\Telegram Desktop\\EFM 1.28 new API\\Backup\\FRP_BACKUP_0x00000A18B000_0x20240925_22 3917.bin\n\n\nReset Google FRP Done",
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f672/samsung-s134dl-isp-pinouts-needed-3337588/',
#   'Published at': '09-20-2024',
#   'Title': 'Samsung S134DL Isp pinouts needed',
#   'Content': "Operation: Connect to Z3X EasyJtagPlus (2023)\n\nSetting Interface to EasyJtag2/ISP\nSetting IO Levels to 2.4V\nSetting Frequence to 12 Mhz\nSetting BusWidth to 1 Bit\nCMD Pullup Level: 39 mV\nCMD Active Level: 584 mV\nSetting HS Timing to Enabled\n\nCan't init device. Error: -1. Reason: CMD Timeout Error\n\n\nhello team i need your help on samsung S134DL isp pinoutsQuote:\nOriginally Posted by ellisony\nOperation: Connect to Z3X EasyJtagPlus (2023)\n\nSetting Interface to EasyJtag2/ISP\nSetting IO Levels to 2.4V\nSetting Frequence to 12 Mhz\nSetting BusWidth to 1 Bit\nCMD Pullup Level: 39 mV\nCMD Active Level: 584 mV\nSetting HS Timing to Enabled\n\nCan't init device. Error: -1. Reason: CMD Timeout Error\n\n\nhello team i need your help on samsung S134DL isp pinouts\n\nThis one is done now after big research on isp pinouts",
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/successfully-unlocked-repaired-translating-phones-eft-dongle-2214526/',
#   'Published at': '09-28-2024',
#   'Title': '★=★=★Successfully Unlocked & Repaired & Translating Phones By EFT Dongle★=★=★',
#   'Content': 'Hi all gsm members in world Here;\nPlease All Post Successfully Unlocked & Repaired & Translating Phones By\n\nEFT Dongle = Easy-Firmware Team Dongle\n\nIn This ThreadGalaxy Note 5 Sm-n920p add arabic successfullySM-J320V PI2 6.0.1 Successfully Added Arabic Lunguage By EFT Dongle\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBR,\nMohamed AamriSM-G920V PC2 5.1.1 Successfully Added Arabic Lunguage By EFT DongleSM-N920P QA1 6.0.1 Successfully Added Arabic Lunguage By EFT Dongle',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-8-1-added-qualcomm-models-samsung-mtk-unlock-sim-realme-3325761/',
#   'Published at': '08-16-2024',
#   'Title': 'EFT Pro Dongle Update V4.8.1[Added Qualcomm Models for Samsung&MTK Unlock SIM Realme]',
#   'Content': "EFT Pro Dongle Update V4.8.1 Build 001 is released :\n\nWhat's New :\n\n\n[Qualcomm]\n- Added Qualcomm Models for Samsung\n\n★ FRP (Factory Reset Protection)\n★ Factory Reset\n\nSpecific Models:\n\n- SM-A426U BIT6\n- SM-A526U BIT (A)\n- SM-A716U BIT9\n- SM-F711B BIT6\n- SM-F711U BIT6\n- SM-F711U BIT5\n- SM-F721B BIT4\n- SM-F721U BIT3\n- SM-F916U BIT2\n- SM-F926B BIT5\n- SM-F926B BIT4\n- SM-F926U BIT4\n- SM-F936B BIT4\n- SM-F936U BIT3\n- SM-G781U BIT6\n- SM-G781U BIT8\n- SM-G781U BIT9\n- SM-G781V BIT5\n- SM-G781W BIT (C)\n- SM-G781WV BIT (C)\n\n[MTK]\nAdded Unlock SIM for Realme:\nSpecific Models:\n\n- RMP2102\n- RMX3242\n- RMX3286\n- RMX3350\n- RMX3357\n- RMX3381\n- RMX3388\n- RMX3392\n- RMX3393\n- RMX3395\n- RMX3396\n- RMX3430\n- RMX3560\n- RMX3561\n- RMX3562\n- RMX3563\n- RMX3571\n- RMX3572\n- RMX3574\n- RMX3611\n- RMX3612\n- RMX3617\n- RMX3618\n- RMX3619\n- RMX3630\n- RMX3636\n- RMX3686\n- RMX3687\n- RMX3740\n- RMX3741\n- RMX3750\n- RMX3751\n- RMX3771\n- RMX3780\n- RMX3782\n\n\nMore Come Soon ..........\n\n\n\n\nPrevious Version EFT Pro Dongle Feature\n[MTK]\nNew design and Easy menu\nSupport Forced BROM (method 1)\nSupport Forced BROM (method 2)\nSupport Forced BROM without Test Point\nSupport Samsung forced BROM (PIT Method)\nSupport write Huawei (UPDATE APP) firmware\nSupport write Samsung (TAR) firmware\nSupport write Oppo/Realme (OFP) firmware\nSupport write EMMC Dump firmware\nSupport Vivo MT6765 PreLoader\nSupport direct unlock network MTK (BROM)\nSupport (Vivo) Disable MDM lock Supported for (2020 to Up)\nSupport (Vivo) Disable MDM lock Supported for (2019)\nSupport (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)\nSupport (Vivo) Disable demo mode\nSupport (Vivo) Disable orange msg\nSupport (Vivo) Restore orange msg\nUpdate Samsung Disable MDM Lock\nUpdate Samsung change KG\nUpdate Oppo disable MDM lock\nSupport Security 2022/2023 for MTK\nSupport Device for MTK devices\nSupport Device (MTK) Factory Reset/FRP Reset/Write Firmware\nUpdate Write Samsung (TAR) Firmware\nDevice (MTK) Factory Reset/FRP\nFix Tool Dl Image Fail\nReset Frp Lock WriteFile\nProtocol For MTK (V6)\nProtocol MTK Devices Read Info / Flash / Format / FRP\nFree Auth Tecno / Infinix / itel\nSupport Models on V6 Protocol Infinix / Tecno\nAdded Repair IMEI Generic (MT67XX) BROM\nAdded Repair Network Security 2020/2021 BROM\nAdded Repair Network Security 2022 BROM\nAdded Read IMEI\nAdded backup with CID number for MTK operations\nAdded Forced BROM SAMSUNG Download Mode\nAdded OPPO MT6771 Auth Free\nAdded Samsung Auth Free\nSamsung Galaxy Wide5(SM-E426S) Auth Free\nSamsung Galaxy A13 5G(SM-A136) Auth Free\nSamsung Galaxy A22(SM-A225) Auth Free\nSamsung Galaxy F42 (SM-E426)Auth Free\nAdded new DEVICE for mtk protocol (v6)\nUpdate GENERIC MTK V5\nUpdate GENERIC MTK 2023\nAdded META Read Info All MTK CPU\nAdded META Factory Reset All MTK CPU\nAdded META Factory Reset MT62XX\nAdded META Repair IMEI All MTK CPU\nAdded in META Mode ( Infinix - Tecno - Itel ) All Model With Auth\nAdded MTK Preloader\nAdded SAMSUNG Brom Models NEW\nAdded META Read Info\nAdded META Factory Reset Direct (INFINIX-TECNO-ITEL)\nAdded Enable/Disable Backup\nDirect Factory Reset (INFINIX-TECNO-ITEL)\n\n[SPD]\nSupport models apove 200+ model\nFactory reset and FRP Reset\nAdded write PAC firmware for All SPD\nEnter diag mode 2 methods\nRead info and IMEI in diag mode\nFactory reset in Diag mode ALL mode\nAdded RSA AUTH Itel/Tecno/Infinix/Realme and more\nAdded Spd Fix Wireless Test Assistant\nAdded New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC\nRead Info\nReset FRP/Factory Reset\nUnlock Bootloader\nRelock Bootloader\nAdded Info Boot Mode\nAdded Read Flash /Format Disk /Write Disk\nAdded Network Unlock Boot Mode\nAdded Repair IMEI Boot Mode\nAdded Remove MDM Boot Mode\nAdded New Boot SPD V2\nAdded GENERIC SPD V1\n\n[SAMSUNG]\nFix Exynos Boot (Beta)\nBypass Knox Samsung Adb\nBypass Knox Samsung MTP\nRemove FRP Direct (MTP) 2023\nEnable ADB With Call Emerge ...
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/eft-pro-dongle-update-v4-7-9-mtk-update-auth-server-xiaomi-samsung-new-model-added-3313468/',
#   'Published at': '08-04-2024',
#   'Title': 'EFT Pro Dongle Update V4.7.9[MTK Update AUTH Server - Xiaomi&Samsung New Model Added]',
#   'Content': "EFT Pro Dongle Update V4.7.9 Build 001 is released :\n\nWhat's New :\n\n\n[MTK]\nUpdate AUTH Server TECNO / INFINIX\n\n★ Read info\n★ FRP\n★ Factory Reset\n★ Flash\n\n\n[Xiaomi]\nAdded Models Qualcomm Xiaomi\n\n★ Reset FRP\n★ Factory Reset\n\nAdded Models Qualcomm Samsung V3 / V4\n\nSM-S908N U4 First in the World\nSM-G970U\nSM-G970U U9\nSM-G970U1 U9\nSM-G970W U9\nSM-G970XU U9\nSM-G975U U9\nSM-G975U1 U9\nSM-G975W U9\nSM-G975XU U9\nSM-G981U U9\nSM-G981U1 U9\nSM-G981W U9\nSM-G981XU U9\nSM-G986U U8\nSM-G986U1 U8\nSM-G986W U8\nSM-G986XU U8\nAdded Models Qualcomm Xiaomi\n\nXiaomi Mi 9 Lite\nXiaomi CC9\nXiaomi CC9 Meitu Edition\nXiaomi Mi 9T\nRedmi K20\nXiaomi Mi CC9 Pro\nXiaomi Mi Note 10\nNote 10 Lite\nXiaomi Mi Note 10 Pro\nXiaomi POCO X2\nXiaomi Redmi K30\nXiaomi Black Shark\nXiaomi Black Shark Helo\nXiaomi Mi 8\nXiaomi Mi 8 Pro\nXiaomi Mi 8 Explorer\nXiaomi Mi Mix 2s\nXiaomi Mi Mix 3\nXiaomi Mi 9\nXiaomi Mi 9T Pro\nXiaomi Mi Mix 3 5G\nXiaomi Black Shark 2\nXiaomi Redmi K20 Pro\nXiaomi Redmi 8\nXiaomi Redmi 8A\nXiaomi Redmi 7A\nXiaomi Mi CC9e\nXiaomi Redmi Note 8\nXiaomi Redmi Note 8T\nXiaomi Mi A3\nXiaomi Black Shark 3\nXiaomi Black Shark 3 Pro\nXiaomi Black Shark 3S\nXiaomi Mi 10 5G\nXiaomi Mi 10 Pro 5G\nXiaomi Mi 10 Ultra\nXiaomi Mi 10T 5G\nXiaomi Mi 10T Pro 5G\nXiaomi POCO F2 Pro\nXiaomi Redmi K30 Pro\nXiaomi Redmi K30S\n\n\n\n\n\n\nPrevious Version EFT Pro Dongle Feature\n[MTK]\nNew design and Easy menu\nSupport Forced BROM (method 1)\nSupport Forced BROM (method 2)\nSupport Forced BROM without Test Point\nSupport Samsung forced BROM (PIT Method)\nSupport write Huawei (UPDATE APP) firmware\nSupport write Samsung (TAR) firmware\nSupport write Oppo/Realme (OFP) firmware\nSupport write EMMC Dump firmware\nSupport Vivo MT6765 PreLoader\nSupport direct unlock network MTK (BROM)\nSupport (Vivo) Disable MDM lock Supported for (2020 to Up)\nSupport (Vivo) Disable MDM lock Supported for (2019)\nSupport (Vivo) Disable MDM lock Supported for (Y15S PD2140EF)\nSupport (Vivo) Disable demo mode\nSupport (Vivo) Disable orange msg\nSupport (Vivo) Restore orange msg\nUpdate Samsung Disable MDM Lock\nUpdate Samsung change KG\nUpdate Oppo disable MDM lock\nSupport Security 2022/2023 for MTK\nSupport Device for MTK devices\nSupport Device (MTK) Factory Reset/FRP Reset/Write Firmware\nUpdate Write Samsung (TAR) Firmware\nDevice (MTK) Factory Reset/FRP\nFix Tool Dl Image Fail\nReset Frp Lock WriteFile\nProtocol For MTK (V6)\nProtocol MTK Devices Read Info / Flash / Format / FRP\nFree Auth Tecno / Infinix / itel\nSupport Models on V6 Protocol Infinix / Tecno\nAdded Repair IMEI Generic (MT67XX) BROM\nAdded Repair Network Security 2020/2021 BROM\nAdded Repair Network Security 2022 BROM\nAdded Read IMEI\nAdded backup with CID number for MTK operations\nAdded Forced BROM SAMSUNG Download Mode\nAdded OPPO MT6771 Auth Free\nAdded Samsung Auth Free\nSamsung Galaxy Wide5(SM-E426S) Auth Free\nSamsung Galaxy A13 5G(SM-A136) Auth Free\nSamsung Galaxy A22(SM-A225) Auth Free\nSamsung Galaxy F42 (SM-E426)Auth Free\nAdded new DEVICE for mtk protocol (v6)\nUpdate GENERIC MTK V5\nUpdate GENERIC MTK 2023\nAdded META Read Info All MTK CPU\nAdded META Factory Reset All MTK CPU\nAdded META Factory Reset MT62XX\nAdded META Repair IMEI All MTK CPU\nAdded in META Mode ( Infinix - Tecno - Itel ) All Model With Auth\nAdded MTK Preloader\nAdded SAMSUNG Brom Models NEW\nAdded META Read Info\nAdded META Factory Reset Direct (INFINIX-TECNO-ITEL)\nAdded Enable/Disable Backup\nDirect Factory Reset (INFINIX-TECNO-ITEL)\n\n[SPD]\nSupport models apove 200+ model\nFactory reset and FRP Reset\nAdded write PAC firmware for All SPD\nEnter diag mode 2 methods\nRead info and IMEI in diag mode\nFactory reset in Diag mode ALL mode\nAdded RSA AUTH Itel/Tecno/Infinix/Realme and more\nAdded Spd Fix Wireless Test Assistant\nAdded New Device (SPD) Factory reset/FRP Reset/Write Firmware PAC\nRead Info\nReset FRP/Factory Reset\nUnlock Bootloader\nRelock Bootloader\nAdded Info Boot Mo ...
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f1014/samsung-a346e-u8-frp-unlock-done-3338899/',
#   'Published at': '09-26-2024',
# ...
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-tool-pro-45-14-small-fix-improvements-3186907/',
#   'Published at': '09-10-2024',
#   'Title': 'Samsung Tool Pro 45.14. Small fix and improvements.',
#   'Content': 'Samsung Tool Pro 45.14. Small fix and improvements.\n\nImproved Read Codes for:\n\n- A245F, A245M, A245N\n- A3460, A346B, A346E, A346M, A346N\n- M536B, M536S\n\nFixed: patch CERT SM-A137F\n\n\n\nDont forget post BUG reports in correct thread.\n\nCheck supported phones: CHECK MY PHONE\nBug report - HERE\nNew phone adding request - HERE\nCredits price, rules of credits using and resellers - HERE\n\nIMPORTANT:\nDONT POST ANY LOGS OF JOB IN THIS THREAD about done jobe. DONE REPORT post only in thread\nJOBE NOT DONE REPORT - open own thread , post there all details and wait answer from supporters/developers.\nDONT ASK WHEN WILL BE SUPPORTED, ANSWER ASAP - AS SOON AS POSSIBLE\nViolation this rules messages will be deletedhello A235M unlock error 0.12 whats means? its on binary 1hello A245M unlock error 0.12 binary 2please add A042f A045f imei repair z3xPlease add a520f u16 support path certificate',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-combination-flash-files-requests-only-here-584115/',
#   'Published at': '08-06-2024',
#   'Title': 'Samsung Combination flash files requests ONLY here',
#   'Content': 'Please post here requests about Samsung combination flash files for all models ONLY in this THREAD!!\n\nRequests must be in format samsung standart flash file name:\nexample:\n\nN950USQU4CRF3\n\nAll other thread with file samsung combination file request will be deleted without warnings and explanations!!!\n\n\n----------------------------------------\n\nCombination file details, how to check version, date, android version.\n\n\n==============\n\nSample: COMBINATION_OXM_FA80_G960FXXU2ARG2\n\nOXM=CSC build = [OXM]\nFA80=Android version = [Android 8]\nG960F=Phone model = [G960F]\nXXU2= Version and security BIT = [XXU,BIT2]\nARG2= Date of release and revision = [July 2018, revision 2]\n\n==============\n\nFA81=Android 8.1\nFA80=Android 8\nFA70=Android 7\nFA60=Android 6\nFA51=Android 5.1\nFA50=Android 5.0\nFA44=Android 4.4\nFA43=Android 4.3\nFAJP=Android JB\nFTMA=Tizen\n\n=======\n\nO=2015\nP=2016\nQ=2017\nR=2018\n\n=======\n\nA=January\nB=February\nC=March\nD=April\nE=May\nF=June\nG=July\nH=August\nI=September\nJ=October\nK=November\nL=December\n\n=======\n\n1=Revision 1\n2=Revision 2\n3=Revision 3\n4=Revision 4\n5=Revision 5\n6=Revision 6\n7=Revision 7\n8=Revision 8\n9=Revision 9\nA=Revision 10\nB=Revision 11\nC=Revision 12\nD=Revision 13\nE=Revision 14\nF=Revision 15help me a7100 Combination file neededI need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.me too\n........................Quote:\nOriginally Posted by fakeprince_\nI need SM-G6000 combination file please anyone have it please share. I wanna fix the cert of ON 7.\ncheck you pm to test first\n\nbr',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a202f-not-unlock-error-0-12-answered-3336753/',
#   'Published at': '09-17-2024',
#   'Title': 'Samsung A202F not unlock.. error (0.12) [Answered]',
#   'Content': "is my phone supported to network unlock ?\n\nCode:\nChecking Login and Password... OK\nBalance: 12 crd.\nYou have 12 credit(s) left. This operation takes 5 credits. Attention! In case if phone asking MCK(Freeze, PUK) code, using this method will consume credits twice - first for MCK(Freeze, PUK) code and then for NCK(Network, PIN). Continue?  Yes\nWaiting ADB device... OK\nReading phone info...\nModel: SM-A202F\nAndroid version: 11\nPDA version: A202FXXU5CWF2\nCSC version: A202FOXM5CWF2\nPhone version: A202FXXU5CWF1\nProduct code: SM-A202FZKDDBT\nCSC country code: Germany\nCSC sales code: DBT\nCarrier ID: EVR\nPhone SN: R58xxxxxxxxx\nIMEI: 35xxxxxxxxxxxxxx\nHW version: MP 0.300\nRF cal date: 20190912\nChip name: EXYNOS7884B\nModem board: SHANNON327\nSecurity patch: 2023-05-01\nBoot Warranty bit: 0\nSIM State: ABSENT,ABSENT\nChecking SIM status... OK\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\nInitialization zTool... OK\nRunning zTool, please wait... OK\nInitialization... error (0.12)\n\nDone with Samsung Tool PRO v.45.14 [SM-A202F,Read Codes via Server]Hello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1Hello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1Quote:\nOriginally Posted by Z3X\nHello. This bit currently not supported. Use checkphones: https://z3x-team.com/check-your-phone/\n\n\nRead Unlock Codes using credits\n\n5crd\n\nA202FXXS2ASL1, A202FXXS3BTI2, A202FXXS3BTK1, A202FXXU1ASE3, A202FXXU2ASH1, A202FXXU3ASL3, A202FXXU3BTC5, A202FXXU3BTE1, A202FXXU3BTG1, A202FXXU3BTJ1, A202FXXU3BTK1, A202FXXU3BUB1, A202FXXU3CUE8, A202FXXU3CUJ1, A202FXXU3CVC1, A202FXXU3CVG2, A202FXXU4CVK1\nSir, what about this J330FN, Please refund\n\n\nUNLOCK INSTRUCTIONS:\nUnlocking with original MSL code:\nWarning! Knox warranty must be active (0x00)!\nIf you have it voided (0x01(void)), then you can't unlock this phone with MSL.\n1. Phone must be powered on.\n2. Type *#0808# and select 'DM+ACM+ADB'.\n3. Run dialer and type *#0*# (service mode will appear).\n4. Connect the phone to USB cable, choose correct COM port in port settings.\n5. Press 'Unlock' button.\n6. Paste MSL code in new opened window and press 'OK'.\n\nReading codes using sever ('Diag' algo):\nWarning! Knox warranty must be active (0x00)!\nIf you have it voided (0x01(void)), then you can't unlock this phone using sever.\n1. Power on the phone.\n2. Type *#0808# and select 'DM+MODEM+ADB'.\n3. Connect the phone to PC with USB cable, install drivers if needed.\n4. Press 'Read Codes via server' button, select 'Diag', write your login and password in window if it will appear.\n(Login and password will be saved as default after first input and can be changed in settings)\n\nReading codes using sever ('Upload' algo):\nKnox warranty does not matter.\n1. Power on the phone.\n2. Tap 7 times on 'Build number' in 'Settings'-'About phone' to enable 'Developer options',\ngo to 'Settings'-'Developer options' and enable 'USB debugging'.\n3. Connect the phone to PC with USB cable, install drivers if needed.\n4. Select device in ADB settings.\n5. Press 'Read Codes via server' button, select 'Upload' write your login and password in window if it will appear.\n(Login and ...
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-sm-g985f-root-answered-2988168/',
#   'Published at': '09-12-2024',
#   'Title': 'samsung sm-g985f Root [Answered]',
#   'Content': 'Hello i have a G985FXXU7DUDB_G985FOXM7DUDB_DBT must perform the root procedure Can anyone help meHello. Here detailed manual for magisk root: https://topjohnwu.github.io/Magisk/install.htmlHello how can I root G985F version G985FXXU5BTJ3.Imei null need repaiar.if yes root files send me please\n\nThanksQuote:\nOriginally Posted by TUN10\nHello how can I root G985F version G985FXXU5BTJ3.Imei null need repaiar.if yes root files send me please\n\nThanks\nhttps://topjohnwu.github.io/Magisk/install.html',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a750fn-relocked-again-answered-3335412/',
#   'Published at': '09-09-2024',
#   'Title': 'Samsung A750FN relocked again [Answered]',
#   'Content': 'hi team\n\na month ago i unlocked A750FNXXU5CTK1 using server credit , after a month later it gets relocked again , pls check it\n\n\n\nCode:\nChecking Login and Password... OK\n Balance: 30 crd.\n You have 30 credit(s) left. This operation takes 5 credits. Continue?  Yes\n Waiting ADB device... OK\n Reading phone info...\n Model: SM-A750FN\n Android version: 10\n PDA version: A750FNXXU5CTK1\n CSC version: A750FNOXM5CTK1\n Phone version: A750FNXXU5CTK1\n Product code: SM-A750FZKNPHE\n CSC country code: SPAIN\n CSC sales code: PHE\n Carrier ID: VDI\n Phone SN: 32009ca84b5c162b\n IMEI: 353329103207813\n HW version: MP0.3\n RF cal date: 20190214\n Chip name: EXYNOS7885\n Modem board: SHANNON327\n Security patch: 2020-11-01\n Boot Warranty bit: 1\n SIM State: ABSENT\n Rebooting phone... OK\n Waiting ADB device... OK\n Waiting for device to become ready... OK\n Checking Super user right... true\n Root version: 23.0:MAGISKSU\n Checking data... OK\n Searching server... OK\n Checking server answer... OK\n Data preparation... OK\n Initialization zTool... OK\n Running zTool, please wait... OK\n Executing 1st step... OK\n Executing 2nd step... OK\n Searching server... OK\n Waiting for server answer... OK\n Unlocking... OK\n Rebooting phone... OKHello. Repeat operation and post result. We will refund double charged credits.its done , took again 5 crd\n\nCode:\nChecking Login and Password... OK\nBalance: 25 crd.\nYou have 25 credit(s) left. This operation takes 5 credits. Continue?  Yes\nWaiting ADB device... OK\nReading phone info...\nModel: SM-A750FN\nAndroid version: 10\nPDA version: A750FNXXU5CTK1\nCSC version: A750FNOXM5CTK1\nPhone version: A750FNXXU5CTK1\nProduct code: SM-A750FZKNVDI\nCSC country code: SPAIN\nCSC sales code: PHE\nCarrier ID: VDI\nPhone SN: 32009ca84b5c162b\nIMEI: 353329103207813\nHW version: MP0.3\nRF cal date: 20190214\nChip name: EXYNOS7885\nModem board: SHANNON327\nSecurity patch: 2020-11-01\nBoot Warranty bit: 1\nSIM State: NETWORK_LOCKED\nChecking Super user right... true\nRoot version: 23.0:MAGISKSU\nChecking data... OK\nSearching server... OK\nChecking server answer... OK\nData preparation... OK\nInitialization zTool... OK\nRunning zTool, please wait... OK\nExecuting 1st step... OK\nExecuting 2nd step... OK\nSearching server... OK\nWaiting for server answer... OK\nUnlocking... OK\nRebooting phone... OK\n\nDone with Samsung Tool PRO v.45.14 [SM-A750FN,Unlock]Refunded. Check account.Quote:\nOriginally Posted by Z3X\nRefunded. Check account.\ntnx for support , z3x team',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/sgh-x510-help-unlock-3334782/',
#   'Published at': '09-06-2024',
#   'Title': 'sgh x510 help to unlock',
#   'Content': 'hi team\nany help to unlock network\nno read the phone\nEntering TestMode... Fail - Timeout\nRead info - false\ni changed the cable e700 - e850\nno any conection\n\nthanksHello. Are you using correct cable? Try plug battery during connection and hold power button.Quote:\nOriginally Posted by Z3X\nHello. Are you using correct cable? Try plug battery during connection and hold power button.\nthanks\ni do that but the same problemTry to set lower baud. If still same - check cable, check usb jack...',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a34-sm-a346e-imei-repair-problem-answered-3333452/',
#   'Published at': '09-01-2024',
#   'Title': 'SAMSUNG A34 SM-A346E imei repair problem [Answered]',
#   'Content': 'Hello Z3X Team a346e samsung imei repair option not support please add lastest model imei repair supporthttps://forum.gsmhosting.com/vbb/f45...hones-1642694/',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/a125u-unlock-error-answered-3333273/',
#   'Published at': '08-31-2024',
#   'Title': 'A125U Unlock Error [Answered]',
#   'Content': 'Operation: Unlock\nSelected model: SM-A125U\nSoftware version: 45.14\n\nChecking Login and Password... OK\nBalance: 20 crd.\nYou have 20 credit(s) left. This operation takes 5 credits. Continue? Yes\nWaiting ADB device... OK\nReading phone info... OK\nReading IMEI... error(0)\nModel: SM-A125U\nAndroid version: 12\nPDA version: A125USQU6CWG3\nCSC version: A125UOYN6CWG3\nPhone version: A125USQU6CWG3\nProduct code: SM2A125UZKACHA\nCSC country code: USA\nCSC sales code: CHA\nCarrier ID: CHA\nPhone SN: R58T13CXKBM\nIMEI:\nHW version: REV1.0\nRF cal date: 20220128\nChip name: MT6765\nModem board: MT6765\nSecurity patch: 2023-06-01\nBoot Warranty bit: 0\nSIM State: ABSENT\nThis phone has CSC(CHA) and CarrierId(CHA) and unlock is not supported by this method\n\nDone with Samsung Tool PRO v.45.14 [SM-A125U,Unlock]Hello. SPR only supported atm. Use chekphones: https://z3x-team.com/check-your-phone/',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/g991u-unlock-failed-answered-3332806/',
#   'Published at': '08-29-2024',
#   'Title': 'G991u unlock failed [Answered]',
#   'Content': 'Operation: Unlock\nSelected model: SM-G991U\nSoftware version: 45.14\n\nChecking Login and Password... OK\nBalance: 13 crd.\nYou have 13 credit(s) left. This operation takes 5 credits. Continue? Yes\nWaiting ADB device... OK\nReading phone info... OK\nReading IMEI... error(0)\nModel: SM-G991U\nAndroid version: 12\nPDA version: G991USQU5CVIF\nCSC version: G991UOYN5CVIF\nPhone version: G991USQU5CVIF\nProduct code: SM-G991UZAETMB\nCSC country code: USA\nCSC sales code: TMB\nCarrier ID: TMB\nPhone SN: R5CR12736LD\nIMEI:\nHW version: REV1.0\nRF cal date: 2021.01.27\nChip name: SM8350\nModem board: SM8350\nSecurity patch: 2022-10-01\nBoot Warranty bit: 0\nSIM State: NETWORK_LOCKED,LOADED\nThis phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method\n\nDone with Samsung Tool PRO v.45.14 [SM-G991U,Unlock]Hello.\n\nThis phone has CSC(TMB) and CarrierId(TMB) and unlock is not supported by this method\n\nUse checkphones: https://z3x-team.com/check-your-phone/',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/s23-plus-direct-unlock-possible-answered-3332230/',
#   'Published at': '08-27-2024',
#   'Title': 'S23 plus direct unlock possible? [Answered]',
#   'Content': 'Hello\nI have a s23 plus "s916" with lock attemps over (carrier lock), is possible to direct unlock or reset attemps ? tanksHello. Not possible atm. Use checkphones: https://z3x-team.com/check-your-phone/',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/samsung-a226b-u9-network-lock-answered-3332081/',
#   'Published at': '08-26-2024',
#   'Title': 'samsung a226b u9 network lock [Answered]',
#   'Content': 'a226bxxs9dxc1 ned unlock network can i do with z3x and how many crd needHello. Currently this bit not supported. Use checkphones: https://z3x-team.com/check-your-phone/',
#   'Summary': 'Fail'},
#  {'Type': 'gsm',
#   'Link': 'https://forum.gsmhosting.com/vbb/f453/please-update-samsungtool-new-desing-answered-3331723/',
#   'Published at': '08-25-2024',
#   'Title': 'Please Update samsungtool with New desing [Answered]',
#   'Content': 'Hello, please Update z3x Samsung tool pro with New desing theme, please add New featuresHello. We working on update.',
#   'Summary': 'Fail'}]

# %%
try:
    columns = [COL_TYPE, COL_LINK, COL_PUBLISHED, COL_TITLE, COL_CONTENT, COL_SUMMARY]
    df = pd.DataFrame(data_output, columns=columns)

    today = datetime.today().date()
    file_path = f'..//output//output_{today}.xlsx'
    sheet_name = f'gsm_{today}'

    # Check if the file already exists
    if os.path.exists(file_path):
        with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='new') as writer:
            if sheet_name in writer.book.sheetnames:
            # Remove old sheet with same name
                writer.book.remove(writer.book[sheet_name])
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    
    logger.info(f'Export {len(data_output)} data successful')
except Exception as e:
    logger.error(f'Save data fail: {e}')
